# %%
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
import torch.nn.functional as F
from skopt import BayesSearchCV
from skopt.space import Real
from skopt import gp_minimize
import torch.nn as nn
import seaborn as sns
from scipy.optimize import minimize
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import matplotlib as mpl
from skopt.utils import use_named_args
from tqdm import tqdm
import multiprocessing
import threading

# %%
# 设置GPU设备，如果没有可用的GPU，则使用CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

setup_seed(888888)

print(device)
# Out:
# cpu

# %%
# 基础参数
epochs = 400000    # 训练代数
h = 100    # 画图网格密度
N = 100    # 内点配置点数
N1 = 0.01    # 边界点配置点数
n = 1000    # PDE数据点
top_k = 100  # 前n个残差最大的点
num_new_points = 10  # 以圆心生成的n个点
bias = 0.001   # 圆半径

# %%
class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(2, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.net(x)

# %%
# Loss
loss = torch.nn.MSELoss()
# loss = torch.nn.L1Loss()  #MAE
# loss = torch.nn.SmoothL1Loss(beta=1.0)

# 递归求导
def gradients(u, x, order=1):
    if order == 1:
        return torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u),
                                   create_graph=True,
                                   only_inputs=True, )[0]
    else:
        return gradients(gradients(u, x), x, order=order - 1)

# %% [markdown]
# # 区域1（0-0.6）

# %%
def point_1(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True) * 0.55
    y = torch.rand(n, 1, device=device, requires_grad=True)
    return x, y


def l_ugeq_1(u, n=100):
    # u >= 0
    x, y = point_1(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_1(u, n=100, device=device):
    # 等式项损失
    x, y = point_1(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_1(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_1(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %% [markdown]
# # 区域2（0.4-1）

# %%
def point_2(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True) * (1 - 0.45) + 0.45
    y = torch.rand(n, 1, device=device, requires_grad=True)
    return x, y


def l_ugeq_2(u, n=100):
    # u >= 0
    x, y = point_2(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_2(u, n=100, device=device):
    # 等式项损失
    x, y = point_2(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_2(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_2(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %%
# 边界函数构建
def l_boundary1(u): # 上边界
    # 取点
    x = torch.arange(0, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = torch.ones_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    # 计算
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary2(u):  # 右边界
    # 取点
    y = torch.arange(0, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = torch.ones_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    # 计算
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary3(u):  # 左边界
    # 取点
    y = torch.arange(0, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = torch.zeros_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    # 计算
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary4(u):  # 下边界
    # 取点
    x = torch.arange(0, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = torch.zeros_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    # 计算
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

# %% [markdown]
# # 查看情况代码

# %%
def record_loss_and_save_model(u, epoch, maxerror, current_time, h, device):
    """
    每100次迭代记录一次损失并保存模型。

    参数:
    - u: 模型
    - epoch: 当前训练的 epoch 数
    - maxerror: 当前最小的误差
    - current_time: 上一次记录的时间
    - h: 网格划分大小
    - device: 设备
    返回:
    - maxerror: 更新后的最小误差
    - current_time: 更新后的时间
    """
    # 生成网格点
    xc_x = torch.linspace(0, 1, h, device=device)
    xc_y = torch.linspace(0, 1, h, device=device)
    xm, ym = torch.meshgrid(xc_x, xc_y)
    xx = xm.reshape(-1, 1)
    yy = ym.reshape(-1, 1)
    xy = torch.cat([xx, yy], dim=1).to(device)

    # 计算预测值和真实值
    u_pred = u(xy)
    u_real = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy))
    u_error = torch.abs(u_pred - u_real)

    # 计算误差网格
    u_pred_fig = u_pred.reshape(h, h)
    u_real_fig = u_real.reshape(h, h)
    u_error_fig = u_error.reshape(h, h)

    # 计算当前最大绝对误差
    max_abs_error = float(torch.max(u_error))
    print(f"At epoch {epoch}, time_speed: {abs(current_time - time.time()):.2f}s, Max abs error is: {max_abs_error}, best: {maxerror}")
    print('-----------------------------------------------------------------------------------------------------------------------')

    # 如果误差更小，则保存模型
    if max_abs_error < maxerror:
        maxerror = max_abs_error
        torch.save(u.state_dict(), 'weights11.pth')

    # 更新当前时间
    current_time = time.time()

    return maxerror, current_time

# %% [markdown]
# # 区域训练

# %% [markdown]
# ## 区域1（0-0.6）g

# %%
def train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch1):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_1(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_1(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_1(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary

        # 区域交换
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)  # 计算神经网络的预测值
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)  # MSE损失
            total_loss += change_weight * boundary_loss  # 给边界损失较大权重
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"Epoch {epoch}: pde_loss={pde_loss.item()}, JU_loss={JU_loss.item()}, boundary_loss={loss_boundary.item()}")
            # 记录 maxerror 并保存模型
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)

        # 反向传播和优化
        total_loss.backward()
        opt.step()
    
    print("\n训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值")

    # **计算 x=0.4 的 u 值**
    # y_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.02, 0.02, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.01, 0.01, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.005, 0.005, device=device).unsqueeze(1)  # 生成 y=[0, 0.05, ..., 1]
    # y_values = torch.arange(0, 1.002, 0.002, device=device).unsqueeze(1)
    y_values = torch.arange(0, 1.001, 0.001, device=device).unsqueeze(1)
    
    x_values = torch.full_like(y_values, 0.55)  # 创建 x=0.4 的列向量
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)  # 拼接 (x,y)

    # **用 u 计算这些点的值**
    u_values = u(xy_values).detach().cpu().numpy()


    return xy_values, u_values, maxerror

# %% [markdown]
# ## 区域2（0.4-1）g

# %%
def train2(change_weight, weight_pde, weight_JU, weight_boundary, epoch2, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch2):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_2(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_2(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_2(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary
        
        # **如果传入了 xy_values 和 u_values，添加它们作为边界条件
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)  # 计算神经网络的预测值
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)  # MSE损失
            total_loss += change_weight * boundary_loss  # 给边界损失较大权重
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"pde:{pde_loss.item()},JU:{JU_loss.item()},boundary:{loss_boundary.item()}")
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)
        
        # if epoch % 100000 == 0 and epoch != 0:
        #     X, Y = update_dataset(X, Y, inside_loss, x_pde, y_pde, top_k, num_new_points, bias, device)
    
        # 反向传播和优化
        total_loss.backward()
        opt.step()
    
    print("\n训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值")

    # **计算 x=0.6 的 u 值**
    # y_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.02, 0.02, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.01, 0.01, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.005, 0.005, device=device).unsqueeze(1)  # 生成 y=[0, 0.05, ..., 1]
    # y_values = torch.arange(0, 1.002, 0.002, device=device).unsqueeze(1)
    y_values = torch.arange(0, 1.001, 0.001, device=device).unsqueeze(1)
    
    x_values = torch.full_like(y_values, 0.45)  # 创建 x=0.6 的列向量
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)  # 拼接 (x,y)

    # **用 u 计算这些点的值**
    u_values = u(xy_values).detach().cpu().numpy()


    return xy_values, u_values, maxerror

# %% [markdown]
# ## 查看情况

# %%
def record_loss_and_save_model(u, epoch, maxerror, current_time, h, device):
    """
    每100次迭代记录一次损失并保存模型。

    参数:
    - u: 模型
    - epoch: 当前训练的 epoch 数
    - maxerror: 当前最小的误差
    - current_time: 上一次记录的时间
    - h: 网格划分大小
    - device: 设备
    返回:
    - maxerror: 更新后的最小误差
    - current_time: 更新后的时间
    """
    # 生成网格点
    xc_x = torch.linspace(0, 1, h, device=device)
    xc_y = torch.linspace(0, 1, h, device=device)
    xm, ym = torch.meshgrid(xc_x, xc_y)
    xx = xm.reshape(-1, 1)
    yy = ym.reshape(-1, 1)
    xy = torch.cat([xx, yy], dim=1).to(device)

    # 计算预测值和真实值
    u_pred = u(xy)
    u_real = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy))
    u_error = torch.abs(u_pred - u_real)

    # 计算误差网格
    u_pred_fig = u_pred.reshape(h, h)
    u_real_fig = u_real.reshape(h, h)
    u_error_fig = u_error.reshape(h, h)

    # 计算当前最大绝对误差
    max_abs_error = float(torch.max(u_error))
    print(f"At epoch {epoch}, time_speed: {abs(current_time - time.time()):.2f}s, Max abs error is: {max_abs_error}, best: {maxerror}")
    print('-----------------------------------------------------------------------------------------------------------------------')

    # 如果误差更小，则保存模型
    if max_abs_error < maxerror:
        maxerror = max_abs_error
        torch.save(u.state_dict(), 'weights.pth')

    # 更新当前时间
    current_time = time.time()

    return maxerror, current_time

# %% [markdown]
# # 训练

# %%
# Training
u = MLP().to(device)
opt = torch.optim.Adam(params=u.parameters(), lr=0.0001)

# 设置初始权重
weight_pde = 600000
weight_JU = 2000
weight_boundary = 10000000
change_weight = 2000
current_time = time.time()
start_time = time.time()
maxerror = 99999999999
epoch2 = epoch1 = 1001
steps = 2000

for step in range(steps):
    print(f"start to the {step} steps:")
    xy_values, u_values, maxerror = train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time)
    if maxerror < 0.001:
        end_time = time.time()
        print(f"迭代停止步数为：{step+1},时间为：{end_time-start_time}")
        break
    print("*************************************************************train domain 1 finish, start to train domain 2")
    xy_values, u_values, maxerror = train2(change_weight, weight_pde, weight_JU, weight_boundary, epoch2, opt, u, maxerror, current_time)
    if maxerror < 0.001:
        end_time = time.time()
        print(f"迭代停止步数为：{step+1},时间为：{end_time-start_time}")
        break
    print("*************************************************************train domain 2 finish, start to train domain 1")

print("                                                                        END TRAINING")
# Out:
# start to the 0 steps:
# Epoch 100: pde_loss=97.28950500488281, JU_loss=-0.35735878348350525, boundary_loss=0.00980400387197733
# At epoch 100, time_speed: 2.28s, Max abs error is: 0.9415322542190552, best: 99999999999
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=105.69783020019531, JU_loss=-0.6358285546302795, boundary_loss=0.01909598521888256
# At epoch 200, time_speed: 1.62s, Max abs error is: 0.9115333557128906, best: 0.9415322542190552
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=85.01262664794922, JU_loss=-1.0637993812561035, boundary_loss=0.03847844898700714
# At epoch 300, time_speed: 1.69s, Max abs error is: 0.847851574420929, best: 0.9115333557128906
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=71.0123062133789, JU_loss=-2.153860092163086, boundary_loss=0.08895660936832428
# At epoch 400, time_speed: 1.62s, Max abs error is: 0.6713752746582031, best: 0.847851574420929
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=23.538358688354492, JU_loss=-2.7047529220581055, boundary_loss=0.26227453351020813
# At epoch 500, time_speed: 1.61s, Max abs error is: 0.45585203170776367, best: 0.6713752746582031
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=19.795852661132812, JU_loss=-2.158372640609741, boundary_loss=0.21274535357952118
# At epoch 600, time_speed: 1.89s, Max abs error is: 0.5324521660804749, best: 0.45585203170776367
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=7.801219940185547, JU_loss=-2.6804091930389404, boundary_loss=0.10980162024497986
# At epoch 700, time_speed: 1.29s, Max abs error is: 0.4225391745567322, best: 0.45585203170776367
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=2.529088020324707, JU_loss=-3.0720276832580566, boundary_loss=0.08387096226215363
# At epoch 800, time_speed: 1.18s, Max abs error is: 0.3631833791732788, best: 0.4225391745567322
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=1.3997976779937744, JU_loss=-3.8418455123901367, boundary_loss=0.08070646226406097
# At epoch 900, time_speed: 1.10s, Max abs error is: 0.3396341800689697, best: 0.3631833791732788
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.9562113881111145, JU_loss=-3.4319307804107666, boundary_loss=0.0738866776227951
# At epoch 1000, time_speed: 1.21s, Max abs error is: 0.30004677176475525, best: 0.3396341800689697
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2
# pde:1.703593134880066,JU:-3.679511785507202,boundary:0.08225509524345398
# At epoch 100, time_speed: 16.67s, Max abs error is: 0.42049819231033325, best: 0.30004677176475525
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.003888726234436,JU:-2.8318402767181396,boundary:0.0652359277009964
# At epoch 200, time_speed: 1.17s, Max abs error is: 0.35952165722846985, best: 0.30004677176475525
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.6553630232810974,JU:-3.4779107570648193,boundary:0.05691082775592804
# At epoch 300, time_speed: 1.20s, Max abs error is: 0.3275138735771179, best: 0.30004677176475525
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.6892377734184265,JU:-2.761739730834961,boundary:0.0510374940931797
# At epoch 400, time_speed: 1.20s, Max abs error is: 0.2998940348625183, best: 0.30004677176475525
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.5634723901748657,JU:-3.916109561920166,boundary:0.047681525349617004
# At epoch 500, time_speed: 1.32s, Max abs error is: 0.29036974906921387, best: 0.2998940348625183
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.683692991733551,JU:-3.007659912109375,boundary:0.04464463144540787
# At epoch 600, time_speed: 1.19s, Max abs error is: 0.2711511254310608, best: 0.29036974906921387
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.6858594417572021,JU:-3.265730619430542,boundary:0.0426984541118145
# At epoch 700, time_speed: 1.09s, Max abs error is: 0.2584822177886963, best: 0.2711511254310608
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.533927321434021,JU:-3.6867876052856445,boundary:0.041221585124731064
# At epoch 800, time_speed: 1.21s, Max abs error is: 0.24640771746635437, best: 0.2584822177886963
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.43423518538475037,JU:-3.6218247413635254,boundary:0.03946850076317787
# At epoch 900, time_speed: 1.10s, Max abs error is: 0.2451467514038086, best: 0.24640771746635437
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.4309990406036377,JU:-2.201375961303711,boundary:0.03812502324581146
# At epoch 1000, time_speed: 1.10s, Max abs error is: 0.24133765697479248, best: 0.2451467514038086
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1
# start to the 1 steps:
# Epoch 100: pde_loss=0.3068521022796631, JU_loss=-3.687819719314575, boundary_loss=0.04045986756682396
# At epoch 100, time_speed: 28.45s, Max abs error is: 0.24161596596240997, best: 0.24133765697479248
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.32044991850852966, JU_loss=-2.8229024410247803, boundary_loss=0.03926142677664757
# At epoch 200, time_speed: 1.22s, Max abs error is: 0.2329583764076233, best: 0.24133765697479248
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.32667720317840576, JU_loss=-3.59879994392395, boundary_loss=0.03801877051591873
# At epoch 300, time_speed: 1.20s, Max abs error is: 0.22189545631408691, best: 0.2329583764076233
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.2577790915966034, JU_loss=-3.4964380264282227, boundary_loss=0.03711580112576485
# At epoch 400, time_speed: 1.37s, Max abs error is: 0.21496707201004028, best: 0.22189545631408691
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.2642773687839508, JU_loss=-3.256984233856201, boundary_loss=0.035731129348278046
# At epoch 500, time_speed: 1.12s, Max abs error is: 0.20539599657058716, best: 0.21496707201004028
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.15869751572608948, JU_loss=-3.2816057205200195, boundary_loss=0.0342169851064682
# At epoch 600, time_speed: 1.19s, Max abs error is: 0.2039136290550232, best: 0.20539599657058716
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.18835760653018951, JU_loss=-3.5896387100219727, boundary_loss=0.03279295191168785
# At epoch 700, time_speed: 1.13s, Max abs error is: 0.19856785237789154, best: 0.2039136290550232
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.22027532756328583, JU_loss=-4.416118621826172, boundary_loss=0.031326208263635635
# At epoch 800, time_speed: 1.16s, Max abs error is: 0.19393670558929443, best: 0.19856785237789154
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.182121142745018, JU_loss=-2.7677316665649414, boundary_loss=0.029939450323581696
# At epoch 900, time_speed: 1.13s, Max abs error is: 0.19329066574573517, best: 0.19393670558929443
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.18970201909542084, JU_loss=-2.7111101150512695, boundary_loss=0.028296394273638725
# At epoch 1000, time_speed: 1.26s, Max abs error is: 0.18634364008903503, best: 0.19329066574573517
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2
# pde:0.19990356266498566,JU:-3.349148750305176,boundary:0.03189860284328461
# At epoch 100, time_speed: 40.47s, Max abs error is: 0.20165131986141205, best: 0.18634364008903503
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.22150957584381104,JU:-2.6857450008392334,boundary:0.029940621927380562
# At epoch 200, time_speed: 1.37s, Max abs error is: 0.2039240598678589, best: 0.18634364008903503
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.18054473400115967,JU:-3.0991251468658447,boundary:0.028080204501748085
# At epoch 300, time_speed: 1.52s, Max abs error is: 0.20486557483673096, best: 0.18634364008903503
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.13150031864643097,JU:-2.960190773010254,boundary:0.027032209560275078
# At epoch 400, time_speed: 1.28s, Max abs error is: 0.19487009942531586, best: 0.18634364008903503
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.22184693813323975,JU:-4.3836469650268555,boundary:0.025499973446130753
# At epoch 500, time_speed: 1.20s, Max abs error is: 0.1890844702720642, best: 0.18634364008903503
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.12993793189525604,JU:-3.532360553741455,boundary:0.024119725450873375
# At epoch 600, time_speed: 1.12s, Max abs error is: 0.18468333780765533, best: 0.18634364008903503
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.13565638661384583,JU:-3.3105101585388184,boundary:0.022717507556080818
# At epoch 700, time_speed: 1.18s, Max abs error is: 0.1760149747133255, best: 0.18468333780765533
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.17520101368427277,JU:-3.1512415409088135,boundary:0.020925167948007584
# At epoch 800, time_speed: 1.13s, Max abs error is: 0.176096111536026, best: 0.1760149747133255
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.12417756021022797,JU:-2.8396475315093994,boundary:0.019907917827367783
# At epoch 900, time_speed: 1.27s, Max abs error is: 0.16926856338977814, best: 0.1760149747133255
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.12201312929391861,JU:-3.161914587020874,boundary:0.018747765570878983
# At epoch 1000, time_speed: 1.12s, Max abs error is: 0.16235627233982086, best: 0.16926856338977814
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1
# start to the 2 steps:
# Epoch 100: pde_loss=0.20059369504451752, JU_loss=-1.9524482488632202, boundary_loss=0.02120693400502205
# At epoch 100, time_speed: 52.85s, Max abs error is: 0.16796544194221497, best: 0.16235627233982086
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.18232622742652893, JU_loss=-2.499696969985962, boundary_loss=0.020012810826301575
# At epoch 200, time_speed: 1.31s, Max abs error is: 0.16674673557281494, best: 0.16235627233982086
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.1264583170413971, JU_loss=-2.75075101852417, boundary_loss=0.018776124343276024
# At epoch 300, time_speed: 1.19s, Max abs error is: 0.16578000783920288, best: 0.16235627233982086
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.13726286590099335, JU_loss=-2.213606834411621, boundary_loss=0.01763795129954815
# At epoch 400, time_speed: 1.12s, Max abs error is: 0.16797907650470734, best: 0.16235627233982086
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.10079335421323776, JU_loss=-2.7120614051818848, boundary_loss=0.016246702522039413
# At epoch 500, time_speed: 1.11s, Max abs error is: 0.15486937761306763, best: 0.16235627233982086
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.12563972175121307, JU_loss=-2.9377095699310303, boundary_loss=0.015102601610124111
# At epoch 600, time_speed: 1.11s, Max abs error is: 0.15447822213172913, best: 0.15486937761306763
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.119808129966259, JU_loss=-3.627394914627075, boundary_loss=0.013918145559728146
# At epoch 700, time_speed: 1.25s, Max abs error is: 0.14480409026145935, best: 0.15447822213172913
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.11970580369234085, JU_loss=-3.826899766921997, boundary_loss=0.01310184970498085
# At epoch 800, time_speed: 1.41s, Max abs error is: 0.1493854522705078, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.10068181157112122, JU_loss=-2.3713061809539795, boundary_loss=0.01189576555043459
# At epoch 900, time_speed: 1.63s, Max abs error is: 0.17434754967689514, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.12884582579135895, JU_loss=-4.453448295593262, boundary_loss=0.010982073843479156
# At epoch 1000, time_speed: 1.49s, Max abs error is: 0.18826931715011597, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2
# pde:0.17328086495399475,JU:-4.768673896789551,boundary:0.02178536169230938
# At epoch 100, time_speed: 65.75s, Max abs error is: 0.16665339469909668, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.12044251710176468,JU:-3.589984655380249,boundary:0.019733821973204613
# At epoch 200, time_speed: 1.13s, Max abs error is: 0.1698179692029953, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.16047997772693634,JU:-3.4357407093048096,boundary:0.018336882814764977
# At epoch 300, time_speed: 1.26s, Max abs error is: 0.16909213364124298, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.11251737922430038,JU:-4.066714286804199,boundary:0.01724950037896633
# At epoch 400, time_speed: 1.22s, Max abs error is: 0.16662360727787018, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.08447466790676117,JU:-3.350156307220459,boundary:0.016349676996469498
# At epoch 500, time_speed: 1.21s, Max abs error is: 0.16102097928524017, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.08845115453004837,JU:-2.177689790725708,boundary:0.015215928666293621
# At epoch 600, time_speed: 1.18s, Max abs error is: 0.1593838781118393, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.1280549168586731,JU:-3.0666685104370117,boundary:0.014517861418426037
# At epoch 700, time_speed: 1.20s, Max abs error is: 0.14842960238456726, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.08047298341989517,JU:-3.138490676879883,boundary:0.013612956739962101
# At epoch 800, time_speed: 1.21s, Max abs error is: 0.14416411519050598, best: 0.14480409026145935
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.12097644060850143,JU:-3.0341992378234863,boundary:0.013140978291630745
# At epoch 900, time_speed: 1.68s, Max abs error is: 0.14065556228160858, best: 0.14416411519050598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.11192410439252853,JU:-3.530014753341675,boundary:0.012138163670897484
# At epoch 1000, time_speed: 1.70s, Max abs error is: 0.14079616963863373, best: 0.14065556228160858
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1
# start to the 3 steps:
# Epoch 100: pde_loss=0.1469375193119049, JU_loss=-3.1833739280700684, boundary_loss=0.014625214971601963
# At epoch 100, time_speed: 79.08s, Max abs error is: 0.13695117831230164, best: 0.14065556228160858
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.07330399751663208, JU_loss=-2.7998523712158203, boundary_loss=0.013351394794881344
# At epoch 200, time_speed: 1.27s, Max abs error is: 0.14446896314620972, best: 0.13695117831230164
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.1273481547832489, JU_loss=-4.1637067794799805, boundary_loss=0.012751558795571327
# At epoch 300, time_speed: 1.13s, Max abs error is: 0.13740617036819458, best: 0.13695117831230164
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.10715427249670029, JU_loss=-2.2650294303894043, boundary_loss=0.01193856168538332
# At epoch 400, time_speed: 1.27s, Max abs error is: 0.13831886649131775, best: 0.13695117831230164
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.09994813799858093, JU_loss=-3.037977933883667, boundary_loss=0.011278532445430756
# At epoch 500, time_speed: 1.20s, Max abs error is: 0.12397007644176483, best: 0.13695117831230164
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.12768861651420593, JU_loss=-3.388998031616211, boundary_loss=0.010303119197487831
# At epoch 600, time_speed: 1.32s, Max abs error is: 0.12751246988773346, best: 0.12397007644176483
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.12541887164115906, JU_loss=-1.7326186895370483, boundary_loss=0.00953924935311079
# At epoch 700, time_speed: 1.22s, Max abs error is: 0.11997483670711517, best: 0.12397007644176483
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.08340048789978027, JU_loss=-3.291198492050171, boundary_loss=0.008926779963076115
# At epoch 800, time_speed: 1.26s, Max abs error is: 0.11164717376232147, best: 0.11997483670711517
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.06619120389223099, JU_loss=-3.716000556945801, boundary_loss=0.008098232559859753
# At epoch 900, time_speed: 1.20s, Max abs error is: 0.11725717782974243, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.0672542080283165, JU_loss=-2.914271593093872, boundary_loss=0.0074490937404334545
# At epoch 1000, time_speed: 1.31s, Max abs error is: 0.12554234266281128, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2
# pde:0.11461833864450455,JU:-4.548084735870361,boundary:0.014665588736534119
# At epoch 100, time_speed: 91.46s, Max abs error is: 0.14061115682125092, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.10459473729133606,JU:-3.7483794689178467,boundary:0.012986315414309502
# At epoch 200, time_speed: 1.42s, Max abs error is: 0.14040541648864746, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.13836541771888733,JU:-3.3892996311187744,boundary:0.01193374115973711
# At epoch 300, time_speed: 1.89s, Max abs error is: 0.1359245777130127, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.1290493756532669,JU:-2.912607431411743,boundary:0.010767463594675064
# At epoch 400, time_speed: 1.67s, Max abs error is: 0.13263319432735443, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.11389055848121643,JU:-3.4319565296173096,boundary:0.010185802355408669
# At epoch 500, time_speed: 1.61s, Max abs error is: 0.12394595146179199, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0980263352394104,JU:-3.2373883724212646,boundary:0.009316572919487953
# At epoch 600, time_speed: 1.52s, Max abs error is: 0.12109363079071045, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.07352089136838913,JU:-3.327296257019043,boundary:0.00863468274474144
# At epoch 700, time_speed: 1.17s, Max abs error is: 0.11738784611225128, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.08343382179737091,JU:-4.043121814727783,boundary:0.007653252687305212
# At epoch 800, time_speed: 1.10s, Max abs error is: 0.12550777196884155, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0667516216635704,JU:-1.7247015237808228,boundary:0.007132899947464466
# At epoch 900, time_speed: 1.11s, Max abs error is: 0.11036300659179688, best: 0.11164717376232147
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.12541022896766663,JU:-2.3765347003936768,boundary:0.006617075763642788
# At epoch 1000, time_speed: 1.10s, Max abs error is: 0.11249814927577972, best: 0.11036300659179688
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1
# start to the 4 steps:
# Epoch 100: pde_loss=0.13200993835926056, JU_loss=-4.166961669921875, boundary_loss=0.008936905302107334
# At epoch 100, time_speed: 105.45s, Max abs error is: 0.116417296230793, best: 0.11036300659179688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.08058233559131622, JU_loss=-2.8813881874084473, boundary_loss=0.008100300095975399
# At epoch 200, time_speed: 1.13s, Max abs error is: 0.11707701534032822, best: 0.11036300659179688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.08327776193618774, JU_loss=-2.3948066234588623, boundary_loss=0.007198892533779144
# At epoch 300, time_speed: 1.10s, Max abs error is: 0.10584653913974762, best: 0.11036300659179688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.07486365735530853, JU_loss=-2.9382004737854004, boundary_loss=0.006638242397457361
# At epoch 400, time_speed: 1.17s, Max abs error is: 0.10748361796140671, best: 0.10584653913974762
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.10841792076826096, JU_loss=-3.7590949535369873, boundary_loss=0.0057759759947657585
# At epoch 500, time_speed: 1.21s, Max abs error is: 0.10103996843099594, best: 0.10584653913974762
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.07165862619876862, JU_loss=-2.634519100189209, boundary_loss=0.005107121076434851
# At epoch 600, time_speed: 1.10s, Max abs error is: 0.0918402373790741, best: 0.10103996843099594
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.05092529207468033, JU_loss=-2.4683446884155273, boundary_loss=0.00450292369350791
# At epoch 700, time_speed: 1.18s, Max abs error is: 0.09169547259807587, best: 0.0918402373790741
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.05045291408896446, JU_loss=-3.849543809890747, boundary_loss=0.004281157162040472
# At epoch 800, time_speed: 1.12s, Max abs error is: 0.07832665741443634, best: 0.09169547259807587
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.036062922328710556, JU_loss=-3.568314552307129, boundary_loss=0.0035535108763724566
# At epoch 900, time_speed: 1.20s, Max abs error is: 0.08343511819839478, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.035990819334983826, JU_loss=-3.684957981109619, boundary_loss=0.003305085701867938
# At epoch 1000, time_speed: 1.39s, Max abs error is: 0.0856856107711792, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2
# pde:0.09675588458776474,JU:-2.8276238441467285,boundary:0.00835308525711298
# At epoch 100, time_speed: 117.25s, Max abs error is: 0.11628351360559464, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.07559267431497574,JU:-3.4706385135650635,boundary:0.007219713181257248
# At epoch 200, time_speed: 1.11s, Max abs error is: 0.10707417875528336, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0753474310040474,JU:-2.275437593460083,boundary:0.0061485376209020615
# At epoch 300, time_speed: 1.41s, Max abs error is: 0.1064288541674614, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.06276398152112961,JU:-3.315425157546997,boundary:0.005604652687907219
# At epoch 400, time_speed: 1.70s, Max abs error is: 0.09757981449365616, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.084647998213768,JU:-5.28433895111084,boundary:0.004821076989173889
# At epoch 500, time_speed: 1.28s, Max abs error is: 0.09146147221326828, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.07376900315284729,JU:-3.035393476486206,boundary:0.0044397516176104546
# At epoch 600, time_speed: 1.12s, Max abs error is: 0.0881144255399704, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.08197081834077835,JU:-3.8387038707733154,boundary:0.0039600711315870285
# At epoch 700, time_speed: 1.19s, Max abs error is: 0.08179163932800293, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.07087117433547974,JU:-2.70267391204834,boundary:0.0032804806251078844
# At epoch 800, time_speed: 1.31s, Max abs error is: 0.08022914826869965, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0419042743742466,JU:-2.9287869930267334,boundary:0.002995047252625227
# At epoch 900, time_speed: 1.18s, Max abs error is: 0.07727758586406708, best: 0.07832665741443634
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.035816118121147156,JU:-3.280548334121704,boundary:0.002757587004452944
# At epoch 1000, time_speed: 1.13s, Max abs error is: 0.0726531594991684, best: 0.07727758586406708
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1
# start to the 5 steps:
# Epoch 100: pde_loss=0.02741408906877041, JU_loss=-2.668013334274292, boundary_loss=0.003690721932798624
# At epoch 100, time_speed: 129.88s, Max abs error is: 0.07839741557836533, best: 0.0726531594991684
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.03743528202176094, JU_loss=-4.271032810211182, boundary_loss=0.002884653862565756
# At epoch 200, time_speed: 1.19s, Max abs error is: 0.06891860067844391, best: 0.0726531594991684
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.0388462133705616, JU_loss=-3.6968276500701904, boundary_loss=0.002325073815882206
# At epoch 300, time_speed: 1.11s, Max abs error is: 0.06219135969877243, best: 0.06891860067844391
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.04911649599671364, JU_loss=-1.4553905725479126, boundary_loss=0.0018570313695818186
# At epoch 400, time_speed: 1.17s, Max abs error is: 0.05720973014831543, best: 0.06219135969877243
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.037253063172101974, JU_loss=-1.8858314752578735, boundary_loss=0.001426850794814527
# At epoch 500, time_speed: 1.20s, Max abs error is: 0.051936984062194824, best: 0.05720973014831543
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.03447907418012619, JU_loss=-2.00748348236084, boundary_loss=0.0012606717646121979
# At epoch 600, time_speed: 1.10s, Max abs error is: 0.0471770316362381, best: 0.051936984062194824
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.025771893560886383, JU_loss=-3.816077470779419, boundary_loss=0.001078281202353537
# At epoch 700, time_speed: 1.31s, Max abs error is: 0.050525665283203125, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.02522541582584381, JU_loss=-2.3854193687438965, boundary_loss=0.0008688230300322175
# At epoch 800, time_speed: 1.11s, Max abs error is: 0.05217713117599487, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.020663024857640266, JU_loss=-3.109675645828247, boundary_loss=0.0007228344329632819
# At epoch 900, time_speed: 1.10s, Max abs error is: 0.05048328638076782, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.011084025725722313, JU_loss=-3.0351648330688477, boundary_loss=0.0005701356567442417
# At epoch 1000, time_speed: 1.19s, Max abs error is: 0.05430436134338379, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2
# pde:0.06654263287782669,JU:-3.2915048599243164,boundary:0.003245747648179531
# At epoch 100, time_speed: 141.84s, Max abs error is: 0.07248130440711975, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.055083006620407104,JU:-3.7597484588623047,boundary:0.0024012993089854717
# At epoch 200, time_speed: 1.71s, Max abs error is: 0.06687716394662857, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.053878579288721085,JU:-3.6270720958709717,boundary:0.0020190863870084286
# At epoch 300, time_speed: 1.71s, Max abs error is: 0.058526039123535156, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.02705029770731926,JU:-4.376596450805664,boundary:0.0017423366662114859
# At epoch 400, time_speed: 1.90s, Max abs error is: 0.05544697493314743, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.049913376569747925,JU:-1.9256168603897095,boundary:0.001314037013798952
# At epoch 500, time_speed: 1.42s, Max abs error is: 0.054004572331905365, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.023348594084382057,JU:-2.7472689151763916,boundary:0.0011698993621394038
# At epoch 600, time_speed: 1.27s, Max abs error is: 0.04830906540155411, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.016396671533584595,JU:-1.934926152229309,boundary:0.0009421277209185064
# At epoch 700, time_speed: 1.19s, Max abs error is: 0.0480426549911499, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.04307720065116882,JU:-3.378631353378296,boundary:0.0009010587236844003
# At epoch 800, time_speed: 1.14s, Max abs error is: 0.04135865718126297, best: 0.0471770316362381
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.03247009217739105,JU:-2.6457250118255615,boundary:0.0006888261996209621
# At epoch 900, time_speed: 1.19s, Max abs error is: 0.04133746027946472, best: 0.04135865718126297
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.04059606418013573,JU:-2.36562180519104,boundary:0.0005445622373372316
# At epoch 1000, time_speed: 1.21s, Max abs error is: 0.03462561219930649, best: 0.04133746027946472
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1
# start to the 6 steps:
# Epoch 100: pde_loss=0.04575738310813904, JU_loss=-2.306150436401367, boundary_loss=0.00086123903747648
# At epoch 100, time_speed: 155.79s, Max abs error is: 0.036770351231098175, best: 0.03462561219930649
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.015472376719117165, JU_loss=-1.9687057733535767, boundary_loss=0.0006737788789905608
# At epoch 200, time_speed: 1.48s, Max abs error is: 0.03617749363183975, best: 0.03462561219930649
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.026902776211500168, JU_loss=-2.4864914417266846, boundary_loss=0.0004397992161102593
# At epoch 300, time_speed: 1.60s, Max abs error is: 0.036295779049396515, best: 0.03462561219930649
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.012119083665311337, JU_loss=-3.5434980392456055, boundary_loss=0.00036539172288030386
# At epoch 400, time_speed: 1.68s, Max abs error is: 0.03167605400085449, best: 0.03462561219930649
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.007529905531555414, JU_loss=-2.5814764499664307, boundary_loss=0.00031445769127458334
# At epoch 500, time_speed: 1.10s, Max abs error is: 0.032089173793792725, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.010008416138589382, JU_loss=-3.725360155105591, boundary_loss=0.000291376025415957
# At epoch 600, time_speed: 1.11s, Max abs error is: 0.033003270626068115, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.009034045971930027, JU_loss=-3.2821044921875, boundary_loss=0.00028143313829787076
# At epoch 700, time_speed: 1.32s, Max abs error is: 0.03388732671737671, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.009097060188651085, JU_loss=-2.447129726409912, boundary_loss=0.0002258426829939708
# At epoch 800, time_speed: 1.19s, Max abs error is: 0.03521144390106201, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.011518535204231739, JU_loss=-2.3146729469299316, boundary_loss=0.00023112229246180505
# At epoch 900, time_speed: 1.11s, Max abs error is: 0.0328635573387146, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.007948849350214005, JU_loss=-4.337643146514893, boundary_loss=0.00016118516214191914
# At epoch 1000, time_speed: 1.10s, Max abs error is: 0.03424489498138428, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2
# pde:0.015467165969312191,JU:-2.943767786026001,boundary:0.0008445960702374578
# At epoch 100, time_speed: 168.57s, Max abs error is: 0.044091545045375824, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.035566214472055435,JU:-3.837359666824341,boundary:0.000692747300490737
# At epoch 200, time_speed: 1.18s, Max abs error is: 0.03902335464954376, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.018860362470149994,JU:-3.2045793533325195,boundary:0.000505661650095135
# At epoch 300, time_speed: 1.11s, Max abs error is: 0.032096125185489655, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.01626872830092907,JU:-2.1473500728607178,boundary:0.00034889800008386374
# At epoch 400, time_speed: 1.10s, Max abs error is: 0.031037315726280212, best: 0.03167605400085449
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.01653376966714859,JU:-2.8912858963012695,boundary:0.0002924705040641129
# At epoch 500, time_speed: 1.10s, Max abs error is: 0.03133314102888107, best: 0.031037315726280212
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.012859771028161049,JU:-2.764965772628784,boundary:0.00028653882327489555
# At epoch 600, time_speed: 1.23s, Max abs error is: 0.02543928474187851, best: 0.031037315726280212
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.01428151223808527,JU:-4.714799880981445,boundary:0.00019795999105554074
# At epoch 700, time_speed: 1.17s, Max abs error is: 0.025618523359298706, best: 0.02543928474187851
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.013753797858953476,JU:-3.182157516479492,boundary:0.00025018016458489
# At epoch 800, time_speed: 1.09s, Max abs error is: 0.02229495346546173, best: 0.02543928474187851
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.011102531105279922,JU:-2.744210720062256,boundary:0.00014371842553373426
# At epoch 900, time_speed: 1.11s, Max abs error is: 0.023583844304084778, best: 0.02229495346546173
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0081062912940979,JU:-2.7726802825927734,boundary:0.00013108373968861997
# At epoch 1000, time_speed: 1.10s, Max abs error is: 0.01950317621231079, best: 0.02229495346546173
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1
# start to the 7 steps:
# Epoch 100: pde_loss=0.01418043952435255, JU_loss=-2.8964684009552, boundary_loss=0.00019703310681506991
# At epoch 100, time_speed: 179.95s, Max abs error is: 0.02338729053735733, best: 0.01950317621231079
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.018508777022361755, JU_loss=-3.180210590362549, boundary_loss=0.0001751595118548721
# At epoch 200, time_speed: 1.11s, Max abs error is: 0.01422322541475296, best: 0.01950317621231079
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.006950384471565485, JU_loss=-2.8056821823120117, boundary_loss=0.00014253932749852538
# At epoch 300, time_speed: 1.09s, Max abs error is: 0.01585930585861206, best: 0.01422322541475296
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.006023263558745384, JU_loss=-1.9455491304397583, boundary_loss=0.00011760638153646141
# At epoch 400, time_speed: 1.09s, Max abs error is: 0.018974721431732178, best: 0.01422322541475296
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.004178332164883614, JU_loss=-1.9863860607147217, boundary_loss=7.552452007075772e-05
# At epoch 500, time_speed: 1.22s, Max abs error is: 0.020408809185028076, best: 0.01422322541475296
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.0032161762937903404, JU_loss=-2.8968117237091064, boundary_loss=8.60044892760925e-05
# At epoch 600, time_speed: 1.11s, Max abs error is: 0.02410888671875, best: 0.01422322541475296
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.00907082762569189, JU_loss=-2.940883159637451, boundary_loss=5.125230745761655e-05
# At epoch 700, time_speed: 1.16s, Max abs error is: 0.024532973766326904, best: 0.01422322541475296
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.0038254735991358757, JU_loss=-2.694462776184082, boundary_loss=4.3885785999009386e-05
# At epoch 800, time_speed: 1.04s, Max abs error is: 0.026194095611572266, best: 0.01422322541475296
# ...
# At epoch 300, time_speed: 1.13s, Max abs error is: 0.0023313239216804504, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.00010521167132537812, JU_loss=-2.2846007347106934, boundary_loss=5.029577550885733e-06
# At epoch 400, time_speed: 1.18s, Max abs error is: 0.0019162148237228394, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=7.955990440677851e-05, JU_loss=-2.0993525981903076, boundary_loss=4.688359695137478e-06
# At epoch 500, time_speed: 1.20s, Max abs error is: 0.002008967101573944, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.0001873640576377511, JU_loss=-3.1947150230407715, boundary_loss=4.173504294158192e-06
# At epoch 600, time_speed: 1.09s, Max abs error is: 0.0022651702165603638, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.0004346785426605493, JU_loss=-4.988502025604248, boundary_loss=4.9931688408833e-05
# At epoch 700, time_speed: 1.19s, Max abs error is: 0.006752893328666687, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=9.701132512418553e-05, JU_loss=-2.4658875465393066, boundary_loss=1.8811581412592204e-06
# At epoch 800, time_speed: 1.12s, Max abs error is: 0.0012757927179336548, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.00010480950004421175, JU_loss=-3.62857723236084, boundary_loss=1.1131700148325763e-06
# At epoch 900, time_speed: 1.17s, Max abs error is: 0.0013050585985183716, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=8.928534225560725e-05, JU_loss=-4.727705478668213, boundary_loss=2.768150125120883e-06
# At epoch 1000, time_speed: 1.20s, Max abs error is: 0.0020745322108268738, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2
# pde:0.00042568781645968556,JU:-2.560833215713501,boundary:4.164018537267111e-05
# At epoch 100, time_speed: 879.75s, Max abs error is: 0.005051739513874054, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00010981166997225955,JU:-3.2194247245788574,boundary:4.9734139793145005e-06
# At epoch 200, time_speed: 1.11s, Max abs error is: 0.0021939054131507874, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00012237719784025103,JU:-2.2458605766296387,boundary:1.833214810176287e-05
# At epoch 300, time_speed: 1.18s, Max abs error is: 0.004351556301116943, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00012702493404503912,JU:-2.5971875190734863,boundary:5.080712980998214e-06
# At epoch 400, time_speed: 1.11s, Max abs error is: 0.0029583722352981567, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00012928692740388215,JU:-3.867323398590088,boundary:2.432171459076926e-05
# At epoch 500, time_speed: 1.11s, Max abs error is: 0.00479377806186676, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0001872693537734449,JU:-2.4216127395629883,boundary:8.928169336286373e-06
# At epoch 600, time_speed: 1.59s, Max abs error is: 0.0027418136596679688, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00015187225653789937,JU:-3.1705639362335205,boundary:1.3709221093449742e-05
# At epoch 700, time_speed: 1.19s, Max abs error is: 0.003074437379837036, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0003214797761756927,JU:-2.3852365016937256,boundary:8.23970913188532e-06
# At epoch 800, time_speed: 1.13s, Max abs error is: 0.0025908052921295166, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00011687290680129081,JU:-3.9355711936950684,boundary:7.3959467954409774e-06
# At epoch 900, time_speed: 1.19s, Max abs error is: 0.002700813114643097, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00033429800532758236,JU:-3.584132194519043,boundary:3.391232667127042e-06
# At epoch 1000, time_speed: 1.28s, Max abs error is: 0.0021302103996276855, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1
# start to the 36 steps:
# Epoch 100: pde_loss=0.00010345967166358605, JU_loss=-2.6849377155303955, boundary_loss=2.1645000742864795e-06
# At epoch 100, time_speed: 891.85s, Max abs error is: 0.001885443925857544, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=9.899552969727665e-05, JU_loss=-2.6393380165100098, boundary_loss=2.658263611010625e-06
# At epoch 200, time_speed: 1.19s, Max abs error is: 0.0017209053039550781, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.00010378660954302177, JU_loss=-4.13081169128418, boundary_loss=1.1995310842394247e-06
# At epoch 300, time_speed: 1.13s, Max abs error is: 0.0019020214676856995, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.0003276756906416267, JU_loss=-1.8274673223495483, boundary_loss=5.1705206715269014e-05
# At epoch 400, time_speed: 1.28s, Max abs error is: 0.005282014608383179, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.00012668909039348364, JU_loss=-2.3843812942504883, boundary_loss=5.854337359778583e-06
# At epoch 500, time_speed: 1.41s, Max abs error is: 0.0021087154746055603, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=9.096307621803135e-05, JU_loss=-2.545598030090332, boundary_loss=1.6861340554896742e-06
# At epoch 600, time_speed: 1.11s, Max abs error is: 0.0013886243104934692, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.00011375060421414673, JU_loss=-3.172107219696045, boundary_loss=9.97335632746399e-07
# At epoch 700, time_speed: 1.10s, Max abs error is: 0.0013978928327560425, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=7.592354813823476e-05, JU_loss=-3.340956926345825, boundary_loss=9.805678928387351e-06
# At epoch 800, time_speed: 1.28s, Max abs error is: 0.0029101669788360596, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.0001052298175636679, JU_loss=-3.244211196899414, boundary_loss=8.947802143666195e-07
# At epoch 900, time_speed: 1.12s, Max abs error is: 0.001109488308429718, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.000221571623114869, JU_loss=-4.2908172607421875, boundary_loss=1.4490662579191849e-05
# At epoch 1000, time_speed: 1.19s, Max abs error is: 0.0035544559359550476, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2
# pde:0.00012480482109822333,JU:-2.842522382736206,boundary:1.6543850733796717e-06
# At epoch 100, time_speed: 903.85s, Max abs error is: 0.0014642924070358276, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00010910200944636017,JU:-2.8434789180755615,boundary:2.70796717813937e-05
# At epoch 200, time_speed: 1.21s, Max abs error is: 0.0046033188700675964, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00026641946169547737,JU:-2.281888484954834,boundary:1.1637923307716846e-05
# At epoch 300, time_speed: 1.40s, Max abs error is: 0.0033790022134780884, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00015777847147546709,JU:-2.7520205974578857,boundary:2.6289899324183352e-06
# At epoch 400, time_speed: 1.19s, Max abs error is: 0.001807577908039093, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00022486432862933725,JU:-3.0061163902282715,boundary:5.106663593323901e-06
# At epoch 500, time_speed: 1.10s, Max abs error is: 0.002328537404537201, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00011373151210136712,JU:-1.1243647336959839,boundary:5.253062226984184e-06
# At epoch 600, time_speed: 1.21s, Max abs error is: 0.0023021623492240906, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.000469476159196347,JU:-3.138699531555176,boundary:1.0522950105951168e-05
# At epoch 700, time_speed: 1.18s, Max abs error is: 0.003277979791164398, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:7.599664968438447e-05,JU:-4.117336750030518,boundary:6.320507281998289e-07
# At epoch 800, time_speed: 1.12s, Max abs error is: 0.0015806928277015686, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00021627065143547952,JU:-4.252476692199707,boundary:2.6565412554191425e-05
# At epoch 900, time_speed: 1.19s, Max abs error is: 0.004476100206375122, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0001427725364919752,JU:-2.1491434574127197,boundary:6.080537332309177e-06
# At epoch 1000, time_speed: 1.19s, Max abs error is: 0.002231590449810028, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1
# start to the 37 steps:
# Epoch 100: pde_loss=9.222532389685512e-05, JU_loss=-3.0407235622406006, boundary_loss=4.8147994675673544e-06
# At epoch 100, time_speed: 915.85s, Max abs error is: 0.0021130964159965515, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.0001160898245871067, JU_loss=-3.1816494464874268, boundary_loss=1.4094839571043849e-05
# At epoch 200, time_speed: 1.33s, Max abs error is: 0.0033286064863204956, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.00010514212772250175, JU_loss=-3.2101242542266846, boundary_loss=1.6593693317190628e-06
# At epoch 300, time_speed: 1.17s, Max abs error is: 0.0019281506538391113, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=6.996142474235967e-05, JU_loss=-4.206132888793945, boundary_loss=1.7597876649233513e-06
# At epoch 400, time_speed: 1.19s, Max abs error is: 0.0011984705924987793, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.00013303618470672518, JU_loss=-3.1498653888702393, boundary_loss=1.1585130778257735e-05
# At epoch 500, time_speed: 1.41s, Max abs error is: 0.0037320032715797424, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.00012417927791830152, JU_loss=-3.1953089237213135, boundary_loss=1.1602166978263995e-06
# At epoch 600, time_speed: 1.11s, Max abs error is: 0.0014327093958854675, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=8.675749268149957e-05, JU_loss=-2.624782085418701, boundary_loss=5.656607982018613e-07
# At epoch 700, time_speed: 1.18s, Max abs error is: 0.0009096264839172363, best: 0.001001216471195221
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.00013528665294870734, JU_loss=-2.148691415786743, boundary_loss=9.168465112452395e-06
# At epoch 800, time_speed: 1.20s, Max abs error is: 0.002626389265060425, best: 0.0009096264839172363
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.0001247685868293047, JU_loss=-2.766097068786621, boundary_loss=1.6171267134268419e-06
# At epoch 900, time_speed: 1.20s, Max abs error is: 0.0014862343668937683, best: 0.0009096264839172363
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.00012148910900577903, JU_loss=-3.0714032649993896, boundary_loss=2.2330370939016575e-06
# At epoch 1000, time_speed: 1.13s, Max abs error is: 0.0018201768398284912, best: 0.0009096264839172363
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# 迭代停止步数为：38,时间为：926.8408286571503
#                                                                         END TRAINING
