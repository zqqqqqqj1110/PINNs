# %%
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
import torch.nn.functional as F
from skopt import BayesSearchCV
from skopt.space import Real
from skopt import gp_minimize
import torch.nn as nn
import seaborn as sns
from scipy.optimize import minimize
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import matplotlib as mpl
from skopt.utils import use_named_args
from tqdm import tqdm
import multiprocessing
import threading

# %%
# 设置GPU设备，如果没有可用的GPU，则使用CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

setup_seed(888888)

print(device)
# Out:
# cpu

# %%
# 基础参数
epochs = 400000    # 训练代数
h = 100    # 画图网格密度
N = 100    # 内点配置点数
N1 = 0.01    # 边界点配置点数
n = 1000    # PDE数据点
top_k = 100  # 前n个残差最大的点
num_new_points = 10  # 以圆心生成的n个点
bias = 0.001   # 圆半径

# %%
class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(2, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.net(x)

# %%
# Loss
loss = torch.nn.MSELoss()

# 递归求导
def gradients(u, x, order=1):
    if order == 1:
        return torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u),
                                   create_graph=True,
                                   only_inputs=True, )[0]
    else:
        return gradients(gradients(u, x), x, order=order - 1)

# %% [markdown]
# # 区域1

# %%
def point_1(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True) * 1.05 - 0.05
    y = torch.rand(n, 1, device=device, requires_grad=True)
    return x, y


def l_ugeq_1(u, n=100):
    # u >= 0
    x, y = point_1(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_1(u, n=100, device=device):
    # 等式项损失
    x, y = point_1(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_1(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_1(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %% [markdown]
# # 区域2（-delta, 1）

# %%
def point_2(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True) * (-1)
    y = torch.rand(n, 1, device=device, requires_grad=True) * 1.05 - 0.05
    return x, y


def l_ugeq_2(u, n=100):
    # u >= 0
    x, y = point_2(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_2(u, n=100, device=device):
    # 等式项损失
    x, y = point_2(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_2(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_2(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %% [markdown]
# # 区域3

# %%
def point_3(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True) * 1.05 - 1  # 生成 (-1, 0.05) 范围内的数
    y = torch.rand(n, 1, device=device, requires_grad=True) - 1  # 生成 (-1, 0) 范围内的数
    return x, y


def l_ugeq_3(u, n=100):
    # u >= 0
    x, y = point_3(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_3(u, n=100, device=device):
    # 等式项损失
    x, y = point_3(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_3(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_3(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %% [markdown]
# # 区域4

# %%
def point_4(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True)  # 生成 (0,1) 范围内的数
    y = torch.rand(n, 1, device=device, requires_grad=True) * 1.05 - 1  # 生成 (-1, 0.05) 范围内的数
    return x, y


def l_ugeq_4(u, n=100):
    # u >= 0
    x, y = point_4(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_4(u, n=100, device=device):
    # 等式项损失
    x, y = point_4(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_4(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_4(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %% [markdown]
# # 边界

# %%
# 边界函数构建
def l_boundary1(u):
    # 下边界
    x = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = -torch.ones_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary2(u):
    # 上边界
    x = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = torch.ones_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary3(u):
    # 左边界
    y = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = -torch.ones_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary4(u):
    # 右边界
    y = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = torch.ones_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)


def l_boundary5(u):
    # y轴
    y = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = torch.zeros_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary6(u):
    # x轴
    x = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = torch.zeros_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

# %% [markdown]
# # 查看情况代码

# %%
def record_loss_and_save_model(u, epoch, maxerror, current_time, h, device):
    """
    每100次迭代记录一次损失并保存模型。

    参数:
    - u: 模型
    - epoch: 当前训练的 epoch 数
    - maxerror: 当前最小的误差
    - current_time: 上一次记录的时间
    - h: 网格划分大小
    - device: 设备
    返回:
    - maxerror: 更新后的最小误差
    - current_time: 更新后的时间
    """
    # 生成网格点
    xc_x = torch.linspace(-1, 1, h, device=device)
    xc_y = torch.linspace(-1, 1, h, device=device)
    xm, ym = torch.meshgrid(xc_x, xc_y)
    xx = xm.reshape(-1, 1)
    yy = ym.reshape(-1, 1)
    xy = torch.cat([xx, yy], dim=1).to(device)

    # 计算预测值和真实值
    u_pred = torch.relu(u(xy))
    u_real = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy))
    u_error = torch.abs(u_pred - u_real)

    # 计算误差网格
    u_pred_fig = u_pred.reshape(h, h)
    u_real_fig = u_real.reshape(h, h)
    u_error_fig = u_error.reshape(h, h)

    # 计算当前最大绝对误差
    max_abs_error = float(torch.max(u_error))
    print(f"At epoch {epoch}, time_speed: {abs(current_time - time.time()):.2f}s, Max abs error is: {max_abs_error}, best: {maxerror}")
    print('-----------------------------------------------------------------------------------------------------------------------')

    # 如果误差更小，则保存模型
    if max_abs_error < maxerror:
        maxerror = max_abs_error
        torch.save(u.state_dict(), 'weights_4D.pth')

    # 更新当前时间
    current_time = time.time()

    return maxerror, current_time

# %% [markdown]
# # 区域训练

# %% [markdown]
# ## 区域1

# %%
def train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch1):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_1(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_1(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_1(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u) + l_boundary5(u) + l_boundary6(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary

        # 区域交换
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)
            total_loss += change_weight * boundary_loss
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"Epoch {epoch}: pde_loss={pde_loss.item()}, JU_loss={JU_loss.item()}, boundary_loss={loss_boundary.item()}")
            # 记录 maxerror 并保存模型
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)

        # 反向传播和优化
        total_loss.backward()
        opt.step()
        
    # **计算 x=-delta 的 u 值**
    y_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1)
    x_values = torch.full_like(y_values, 0 - delta/2)
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)

    # 用 u 计算这些点的值
    u_values = u(xy_values).detach().cpu().numpy()


    return xy_values, u_values, maxerror

# %% [markdown]
# ## 区域2

# %%
def train2(change_weight, weight_pde, weight_JU, weight_boundary, epoch2, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch2):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_2(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_2(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_2(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u) + l_boundary5(u) + l_boundary6(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary
        
        # **如果传入了 xy_values 和 u_values，添加它们作为边界条件
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)  # 计算神经网络的预测值
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)  # MSE损失
            total_loss += change_weight * boundary_loss  # 给边界损失较大权重
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"pde:{pde_loss.item()},JU:{JU_loss.item()},boundary:{loss_boundary.item()}")
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)
        
        # if epoch % 100000 == 0 and epoch != 0:
        #     X, Y = update_dataset(X, Y, inside_loss, x_pde, y_pde, top_k, num_new_points, bias, device)
    
        # 反向传播和优化
        total_loss.backward()
        opt.step()
        
    # **计算 x=+delta 的 u 值**
    x_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1) * (-1)
    y_values = torch.full_like(x_values, 0 - delta/2)  # 创建 x=+delta 的列向量
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)

    # **用 u 计算这些点的值**
    u_values = u(xy_values).detach().cpu().numpy()


    return xy_values, u_values, maxerror

# %% [markdown]
# ## 区域3

# %%
def train3(change_weight, weight_pde, weight_JU, weight_boundary, epoch3, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch1):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_3(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_3(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_3(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u) + l_boundary5(u) + l_boundary6(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary

        # 区域交换
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)
            total_loss += change_weight * boundary_loss
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"Epoch {epoch}: pde_loss={pde_loss.item()}, JU_loss={JU_loss.item()}, boundary_loss={loss_boundary.item()}")
            # 记录 maxerror 并保存模型
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)

        # 反向传播和优化
        total_loss.backward()
        opt.step()

    # **计算 x=-delta 的 u 值**
    y_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1) * (-1)
    x_values = torch.full_like(y_values, 0 + delta/2)  # 创建 x=0.4 的列向量
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)

    # 用 u 计算这些点的值
    u_values = u(xy_values).detach().cpu().numpy()


    return xy_values, u_values, maxerror

# %% [markdown]
# ## 区域4

# %%
def train4(change_weight, weight_pde, weight_JU, weight_boundary, epoch4, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch1):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_4(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_4(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_4(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u) + l_boundary5(u) + l_boundary6(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary

        # 区域交换
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)
            total_loss += change_weight * boundary_loss
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"Epoch {epoch}: pde_loss={pde_loss.item()}, JU_loss={JU_loss.item()}, boundary_loss={loss_boundary.item()}")
            # 记录 maxerror 并保存模型
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)

        # 反向传播和优化
        total_loss.backward()
        opt.step()

    # **计算 x=-delta 的 u 值**
    x_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1)
    y_values = torch.full_like(x_values, 0 + delta/2)  # 创建 x=0.4 的列向量
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)

    # 用 u 计算这些点的值
    u_values = u(xy_values).detach().cpu().numpy()


    return xy_values, u_values, maxerror

# %% [markdown]
# # 训练

# %%
# Training
u = MLP().to(device)
opt = torch.optim.Adam(params=u.parameters(), lr=0.0001)

# 设置初始权重
weight_pde = 6000000000
weight_JU = 2000000
weight_boundary = 1000000000000
change_weight = 2000000
current_time = time.time()
start_time = time.time()
maxerror = 99999999999
epoch4 = epoch3 = epoch2 = epoch1 = 1001
steps = 2000
delta = 0.05

for step in range(steps):
    print(f"start to the {step} steps:")
    xy_values, u_values, maxerror = train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time)
    print("*************************************************************train domain 1 finish, start to train domain 2************************************************************")
    xy_values, u_values, maxerror = train2(change_weight, weight_pde, weight_JU, weight_boundary, epoch2, opt, u, maxerror, current_time)
    print("*************************************************************train domain 2 finish, start to train domain 3************************************************************")
    xy_values, u_values, maxerror = train3(change_weight, weight_pde, weight_JU, weight_boundary, epoch3, opt, u, maxerror, current_time)
    print("*************************************************************train domain 3 finish, start to train domain 4************************************************************")
    xy_values, u_values, maxerror = train4(change_weight, weight_pde, weight_JU, weight_boundary, epoch4, opt, u, maxerror, current_time)
    print("*************************************************************train domain 4 finish, start to train domain 1************************************************************")

print("                                                                        END TRAINING")
# Out:
# start to the 0 steps:
# Epoch 100: pde_loss=87.93449401855469, JU_loss=-0.06045699492096901, boundary_loss=0.002202217001467943
# At epoch 100, time_speed: 2.60s, Max abs error is: 0.9997482299804688, best: 99999999999
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=111.95905303955078, JU_loss=-0.02227233164012432, boundary_loss=0.001293216715566814
# At epoch 200, time_speed: 1.92s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=95.21808624267578, JU_loss=-0.05475008115172386, boundary_loss=0.0010506915859878063
# At epoch 300, time_speed: 1.89s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=75.16072082519531, JU_loss=-0.06735022366046906, boundary_loss=0.0008473586640320718
# At epoch 400, time_speed: 1.89s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=90.58361053466797, JU_loss=-0.06737394630908966, boundary_loss=0.0006911849486641586
# At epoch 500, time_speed: 1.82s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=111.69464874267578, JU_loss=-0.09500370919704437, boundary_loss=0.0006027612253092229
# At epoch 600, time_speed: 1.59s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=109.58743286132812, JU_loss=-0.12163778394460678, boundary_loss=0.0006231400184333324
# At epoch 700, time_speed: 1.51s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=92.7484359741211, JU_loss=-0.19801898300647736, boundary_loss=0.0009607989341020584
# At epoch 800, time_speed: 1.98s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=102.1999282836914, JU_loss=-0.2817118465900421, boundary_loss=0.0023141487035900354
# At epoch 900, time_speed: 1.90s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=87.09632110595703, JU_loss=-0.5945650935173035, boundary_loss=0.007837239652872086
# At epoch 1000, time_speed: 1.92s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:90.874755859375,JU:-0.36107903718948364,boundary:0.013330075889825821
# At epoch 100, time_speed: 21.01s, Max abs error is: 0.9952101111412048, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# pde:72.75223541259766,JU:-0.6254330277442932,boundary:0.02036598138511181
# At epoch 200, time_speed: 1.51s, Max abs error is: 0.9980176687240601, best: 0.9952101111412048
# -----------------------------------------------------------------------------------------------------------------------
# pde:56.9035530090332,JU:-0.8708053827285767,boundary:0.02661886066198349
# At epoch 300, time_speed: 1.28s, Max abs error is: 0.9997482299804688, best: 0.9952101111412048
# -----------------------------------------------------------------------------------------------------------------------
# pde:57.62995529174805,JU:-1.6248631477355957,boundary:0.03384063020348549
# At epoch 400, time_speed: 1.30s, Max abs error is: 0.9997482299804688, best: 0.9952101111412048
# -----------------------------------------------------------------------------------------------------------------------
# pde:31.85635757446289,JU:-1.9737602472305298,boundary:0.04265475273132324
# At epoch 500, time_speed: 1.30s, Max abs error is: 0.9997482299804688, best: 0.9952101111412048
# -----------------------------------------------------------------------------------------------------------------------
# pde:13.051791191101074,JU:-2.093059778213501,boundary:0.05985686928033829
# At epoch 600, time_speed: 1.31s, Max abs error is: 0.9997482299804688, best: 0.9952101111412048
# -----------------------------------------------------------------------------------------------------------------------
# pde:6.879470348358154,JU:-2.3971500396728516,boundary:0.057194821536540985
# At epoch 700, time_speed: 1.30s, Max abs error is: 0.9887008666992188, best: 0.9952101111412048
# -----------------------------------------------------------------------------------------------------------------------
# pde:7.218137264251709,JU:-2.317922592163086,boundary:0.04932260513305664
# At epoch 800, time_speed: 1.38s, Max abs error is: 0.9730558395385742, best: 0.9887008666992188
# -----------------------------------------------------------------------------------------------------------------------
# pde:6.2580976486206055,JU:-2.8206560611724854,boundary:0.045564740896224976
# At epoch 900, time_speed: 1.50s, Max abs error is: 0.946906566619873, best: 0.9730558395385742
# -----------------------------------------------------------------------------------------------------------------------
# pde:6.279491424560547,JU:-2.2014923095703125,boundary:0.04063119366765022
# At epoch 1000, time_speed: 1.31s, Max abs error is: 0.9187694787979126, best: 0.946906566619873
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 2 finish, start to train domain 3*************************************************************
# Epoch 100: pde_loss=41.521785736083984, JU_loss=-1.3489946126937866, boundary_loss=0.028201067820191383
# At epoch 100, time_speed: 34.60s, Max abs error is: 0.8044558763504028, best: 0.9187694787979126
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=16.383647918701172, JU_loss=-2.9535107612609863, boundary_loss=0.03162197023630142
# At epoch 200, time_speed: 1.30s, Max abs error is: 0.8269162774085999, best: 0.8044558763504028
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=8.285246849060059, JU_loss=-2.15683650970459, boundary_loss=0.03545285388827324
# At epoch 300, time_speed: 1.31s, Max abs error is: 0.8213791847229004, best: 0.8044558763504028
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=5.630862236022949, JU_loss=-3.6315932273864746, boundary_loss=0.03021438978612423
# At epoch 400, time_speed: 1.28s, Max abs error is: 0.8103295564651489, best: 0.8044558763504028
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=3.980424165725708, JU_loss=-1.97066068649292, boundary_loss=0.025269512087106705
# At epoch 500, time_speed: 1.40s, Max abs error is: 0.8017675280570984, best: 0.8044558763504028
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=4.02858829498291, JU_loss=-3.010645866394043, boundary_loss=0.020960422232747078
# At epoch 600, time_speed: 1.31s, Max abs error is: 0.7871867418289185, best: 0.8017675280570984
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=2.8618476390838623, JU_loss=-2.2172319889068604, boundary_loss=0.017904488369822502
# At epoch 700, time_speed: 1.52s, Max abs error is: 0.7766944169998169, best: 0.7871867418289185
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=2.846498966217041, JU_loss=-2.737997531890869, boundary_loss=0.015620355494320393
# At epoch 800, time_speed: 1.28s, Max abs error is: 0.7644506692886353, best: 0.7766944169998169
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=2.453339099884033, JU_loss=-2.165973424911499, boundary_loss=0.013486788608133793
# At epoch 900, time_speed: 1.42s, Max abs error is: 0.7515539526939392, best: 0.7644506692886353
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=2.239539623260498, JU_loss=-2.291048765182495, boundary_loss=0.012038463726639748
# At epoch 1000, time_speed: 1.30s, Max abs error is: 0.7367631793022156, best: 0.7515539526939392
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 3 finish, start to train domain 4*************************************************************
# Epoch 100: pde_loss=10.341711044311523, JU_loss=-1.7084646224975586, boundary_loss=0.021872039884328842
# At epoch 100, time_speed: 48.11s, Max abs error is: 0.4822799563407898, best: 0.7367631793022156
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=5.893237113952637, JU_loss=-2.6092450618743896, boundary_loss=0.021326813846826553
# At epoch 200, time_speed: 1.38s, Max abs error is: 0.41091930866241455, best: 0.4822799563407898
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=4.107177734375, JU_loss=-3.010589838027954, boundary_loss=0.018314408138394356
# At epoch 300, time_speed: 1.31s, Max abs error is: 0.3871030807495117, best: 0.41091930866241455
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=4.061260223388672, JU_loss=-2.1843249797821045, boundary_loss=0.016745038330554962
# At epoch 400, time_speed: 1.42s, Max abs error is: 0.3774070143699646, best: 0.3871030807495117
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=4.3547563552856445, JU_loss=-2.6901378631591797, boundary_loss=0.014314983040094376
# At epoch 500, time_speed: 1.68s, Max abs error is: 0.38019245862960815, best: 0.3774070143699646
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=3.1334052085876465, JU_loss=-2.6170785427093506, boundary_loss=0.013292987830936909
# At epoch 600, time_speed: 1.33s, Max abs error is: 0.3759857416152954, best: 0.3774070143699646
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=4.026727199554443, JU_loss=-2.496267795562744, boundary_loss=0.011861640959978104
# At epoch 700, time_speed: 1.30s, Max abs error is: 0.3734767436981201, best: 0.3759857416152954
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=2.220460891723633, JU_loss=-2.4465389251708984, boundary_loss=0.011025453917682171
# At epoch 800, time_speed: 1.30s, Max abs error is: 0.37317705154418945, best: 0.3734767436981201
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=2.889758348464966, JU_loss=-2.8211684226989746, boundary_loss=0.01037854515016079
# At epoch 900, time_speed: 1.30s, Max abs error is: 0.3743079900741577, best: 0.37317705154418945
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=3.1416385173797607, JU_loss=-2.7083706855773926, boundary_loss=0.0096895145252347
# At epoch 1000, time_speed: 1.32s, Max abs error is: 0.3702077269554138, best: 0.37317705154418945
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 4 finish, start to train domain 1*************************************************************
# start to the 1 steps:
# Epoch 100: pde_loss=2.9693007469177246, JU_loss=-1.6580603122711182, boundary_loss=0.01713397540152073
# At epoch 100, time_speed: 61.81s, Max abs error is: 0.2732810974121094, best: 0.3702077269554138
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=2.5845398902893066, JU_loss=-2.9342734813690186, boundary_loss=0.013145987875759602
# At epoch 200, time_speed: 1.60s, Max abs error is: 0.25441139936447144, best: 0.2732810974121094
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=2.3354673385620117, JU_loss=-1.5455610752105713, boundary_loss=0.010811413638293743
# At epoch 300, time_speed: 1.40s, Max abs error is: 0.24179911613464355, best: 0.25441139936447144
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=2.3886444568634033, JU_loss=-3.0534839630126953, boundary_loss=0.009449194185435772
# At epoch 400, time_speed: 1.50s, Max abs error is: 0.23150336742401123, best: 0.24179911613464355
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=1.7413406372070312, JU_loss=-2.6259605884552, boundary_loss=0.008424809202551842
# At epoch 500, time_speed: 1.40s, Max abs error is: 0.21841204166412354, best: 0.23150336742401123
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=1.3810540437698364, JU_loss=-2.075470209121704, boundary_loss=0.007462185807526112
# At epoch 600, time_speed: 1.31s, Max abs error is: 0.2162432074546814, best: 0.21841204166412354
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=1.1202677488327026, JU_loss=-2.7460520267486572, boundary_loss=0.0065841362811625
# At epoch 700, time_speed: 1.47s, Max abs error is: 0.21405357122421265, best: 0.2162432074546814
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.8889296054840088, JU_loss=-1.301376223564148, boundary_loss=0.0059958272613584995
# At epoch 800, time_speed: 1.33s, Max abs error is: 0.22282356023788452, best: 0.21405357122421265
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.9030661582946777, JU_loss=-3.9969351291656494, boundary_loss=0.005365143064409494
# At epoch 900, time_speed: 1.38s, Max abs error is: 0.22864770889282227, best: 0.21405357122421265
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.5187586545944214, JU_loss=-3.8962926864624023, boundary_loss=0.004695698153227568
# At epoch 1000, time_speed: 1.62s, Max abs error is: 0.23660880327224731, best: 0.21405357122421265
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:1.0184539556503296,JU:-1.6227829456329346,boundary:0.006850806530565023
# At epoch 100, time_speed: 76.19s, Max abs error is: 0.18605881929397583, best: 0.21405357122421265
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.9206757545471191,JU:-2.440829038619995,boundary:0.004811009392142296
# At epoch 200, time_speed: 1.43s, Max abs error is: 0.1990373730659485, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.5547682642936707,JU:-2.5790975093841553,boundary:0.0039488025940954685
# At epoch 300, time_speed: 1.39s, Max abs error is: 0.2073114514350891, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.7844260931015015,JU:-1.6167404651641846,boundary:0.0034234824124723673
# At epoch 400, time_speed: 1.39s, Max abs error is: 0.21334487199783325, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.3071283996105194,JU:-2.467674493789673,boundary:0.00309908133931458
# At epoch 500, time_speed: 1.31s, Max abs error is: 0.2169608473777771, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.3293188214302063,JU:-2.703296184539795,boundary:0.0028363338205963373
# At epoch 600, time_speed: 1.32s, Max abs error is: 0.21917545795440674, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.4233951270580292,JU:-2.3798134326934814,boundary:0.002638711594045162
# At epoch 700, time_speed: 1.69s, Max abs error is: 0.21689856052398682, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.18916034698486328,JU:-2.1981327533721924,boundary:0.0025500906631350517
# At epoch 800, time_speed: 1.31s, Max abs error is: 0.21516430377960205, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.17617322504520416,JU:-1.503525972366333,boundary:0.002411593683063984
# At epoch 900, time_speed: 1.31s, Max abs error is: 0.21469050645828247, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.10010144114494324,JU:-2.686983585357666,boundary:0.0022626426070928574
# At epoch 1000, time_speed: 1.38s, Max abs error is: 0.21115124225616455, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 2 finish, start to train domain 3*************************************************************
# Epoch 100: pde_loss=1.1020416021347046, JU_loss=-2.1746556758880615, boundary_loss=0.005902143660932779
# At epoch 100, time_speed: 90.43s, Max abs error is: 0.12697036564350128, best: 0.18605881929397583
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.7431210279464722, JU_loss=-3.2012064456939697, boundary_loss=0.004971595481038094
# At epoch 200, time_speed: 1.31s, Max abs error is: 0.12543094158172607, best: 0.12697036564350128
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.49728164076805115, JU_loss=-3.108875036239624, boundary_loss=0.004309940151870251
# At epoch 300, time_speed: 1.32s, Max abs error is: 0.12178922444581985, best: 0.12543094158172607
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.7328624129295349, JU_loss=-1.7247196435928345, boundary_loss=0.0037809472996741533
# At epoch 400, time_speed: 1.40s, Max abs error is: 0.12280308455228806, best: 0.12178922444581985
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.8525335788726807, JU_loss=-1.3729254007339478, boundary_loss=0.0034347858745604753
# At epoch 500, time_speed: 1.31s, Max abs error is: 0.11495941877365112, best: 0.12178922444581985
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.6690545082092285, JU_loss=-2.295907735824585, boundary_loss=0.0031446251086890697
# At epoch 600, time_speed: 1.33s, Max abs error is: 0.11507892608642578, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.6157687902450562, JU_loss=-2.1683237552642822, boundary_loss=0.002827183809131384
# At epoch 700, time_speed: 1.38s, Max abs error is: 0.12398505210876465, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.4416544735431671, JU_loss=-1.9594098329544067, boundary_loss=0.0026965553406625986
# At epoch 800, time_speed: 1.34s, Max abs error is: 0.13012927770614624, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.2600269615650177, JU_loss=-2.3022124767303467, boundary_loss=0.002520384732633829
# At epoch 900, time_speed: 1.60s, Max abs error is: 0.13743650913238525, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.49864882230758667, JU_loss=-2.302546501159668, boundary_loss=0.002409107983112335
# At epoch 1000, time_speed: 1.36s, Max abs error is: 0.14480245113372803, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 3 finish, start to train domain 4*************************************************************
# Epoch 100: pde_loss=2.097074508666992, JU_loss=-1.1406878232955933, boundary_loss=0.005321302451193333
# At epoch 100, time_speed: 104.21s, Max abs error is: 0.20521262288093567, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=2.1030545234680176, JU_loss=-2.5056207180023193, boundary_loss=0.004938068799674511
# At epoch 200, time_speed: 1.38s, Max abs error is: 0.1998974084854126, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=1.9006015062332153, JU_loss=-2.1833996772766113, boundary_loss=0.004734873306006193
# At epoch 300, time_speed: 1.29s, Max abs error is: 0.19760900735855103, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=1.4357906579971313, JU_loss=-2.03979754447937, boundary_loss=0.004493275657296181
# At epoch 400, time_speed: 1.33s, Max abs error is: 0.19600024819374084, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=2.0635104179382324, JU_loss=-1.459800124168396, boundary_loss=0.004406702239066362
# At epoch 500, time_speed: 1.38s, Max abs error is: 0.19331330060958862, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=1.6013476848602295, JU_loss=-2.401472568511963, boundary_loss=0.004257483407855034
# At epoch 600, time_speed: 1.41s, Max abs error is: 0.19747799634933472, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=1.024975299835205, JU_loss=-1.7380298376083374, boundary_loss=0.004105145577341318
# At epoch 700, time_speed: 1.28s, Max abs error is: 0.20339536666870117, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=1.7475956678390503, JU_loss=-2.2474045753479004, boundary_loss=0.004024540539830923
# At epoch 800, time_speed: 1.32s, Max abs error is: 0.21025383472442627, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=1.3370661735534668, JU_loss=-1.9661675691604614, boundary_loss=0.003908725921064615
# At epoch 900, time_speed: 1.32s, Max abs error is: 0.21401584148406982, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=1.7966951131820679, JU_loss=-2.955641508102417, boundary_loss=0.0038309337105602026
# At epoch 1000, time_speed: 1.35s, Max abs error is: 0.2142103910446167, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 4 finish, start to train domain 1*************************************************************
# start to the 2 steps:
# Epoch 100: pde_loss=0.4903533160686493, JU_loss=-2.0129544734954834, boundary_loss=0.00437720725312829
# At epoch 100, time_speed: 117.61s, Max abs error is: 0.14307832717895508, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.522914707660675, JU_loss=-1.445675253868103, boundary_loss=0.0030472094658762217
# At epoch 200, time_speed: 1.32s, Max abs error is: 0.1296008825302124, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.4840128719806671, JU_loss=-1.3721624612808228, boundary_loss=0.0024652474094182253
# At epoch 300, time_speed: 1.46s, Max abs error is: 0.11845594644546509, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.44935160875320435, JU_loss=-2.986536979675293, boundary_loss=0.002173392102122307
# At epoch 400, time_speed: 1.61s, Max abs error is: 0.10774558782577515, best: 0.11495941877365112
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.2962203323841095, JU_loss=-1.4615600109100342, boundary_loss=0.00189692759886384
# At epoch 500, time_speed: 1.32s, Max abs error is: 0.09742635488510132, best: 0.10774558782577515
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.22954252362251282, JU_loss=-2.5937345027923584, boundary_loss=0.001739586004987359
# At epoch 600, time_speed: 1.48s, Max abs error is: 0.09611755609512329, best: 0.09742635488510132
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.22234435379505157, JU_loss=-1.9270827770233154, boundary_loss=0.0015939695294946432
# At epoch 700, time_speed: 1.91s, Max abs error is: 0.09220975637435913, best: 0.09611755609512329
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.38861289620399475, JU_loss=-3.8186163902282715, boundary_loss=0.0014921968104317784
# At epoch 800, time_speed: 1.99s, Max abs error is: 0.09218072891235352, best: 0.09220975637435913
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.23696158826351166, JU_loss=-2.7233762741088867, boundary_loss=0.0014310837723314762
# At epoch 900, time_speed: 1.92s, Max abs error is: 0.090312659740448, best: 0.09218072891235352
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.21784496307373047, JU_loss=-2.360306978225708, boundary_loss=0.0013357674470171332
# At epoch 1000, time_speed: 2.10s, Max abs error is: 0.09147381782531738, best: 0.090312659740448
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.16504396498203278,JU:-2.6469366550445557,boundary:0.0013232881901785731
# At epoch 100, time_speed: 134.71s, Max abs error is: 0.10142755508422852, best: 0.090312659740448
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.09393610060214996,JU:-2.3853464126586914,boundary:0.0010866820812225342
# At epoch 200, time_speed: 1.79s, Max abs error is: 0.10496240854263306, best: 0.090312659740448
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.16150978207588196,JU:-1.9463855028152466,boundary:0.0009522535256110132
# At epoch 300, time_speed: 1.31s, Max abs error is: 0.10334032773971558, best: 0.090312659740448
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.13496005535125732,JU:-2.403015375137329,boundary:0.0008626264752820134
# At epoch 400, time_speed: 1.99s, Max abs error is: 0.10246682167053223, best: 0.090312659740448
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.07943954318761826,JU:-1.402028203010559,boundary:0.0007824203930795193
# At epoch 500, time_speed: 1.93s, Max abs error is: 0.10153710842132568, best: 0.090312659740448
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.04941911995410919,JU:-1.5506227016448975,boundary:0.0007212701020762324
# At epoch 600, time_speed: 2.18s, Max abs error is: 0.09572303295135498, best: 0.090312659740448
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.09189238399267197,JU:-2.7223615646362305,boundary:0.000665496161673218
# At epoch 700, time_speed: 1.40s, Max abs error is: 0.0957719087600708, best: 0.090312659740448
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.03851250559091568,JU:-1.8499163389205933,boundary:0.0006169633707031608
# At epoch 800, time_speed: 1.30s, Max abs error is: 0.08922970294952393, best: 0.090312659740448
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0856662169098854,JU:-2.6745266914367676,boundary:0.000591831689234823
# At epoch 900, time_speed: 1.29s, Max abs error is: 0.08281266689300537, best: 0.08922970294952393
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.05353587493300438,JU:-2.132141351699829,boundary:0.0005414625047706068
# At epoch 1000, time_speed: 1.42s, Max abs error is: 0.08268022537231445, best: 0.08281266689300537
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 2 finish, start to train domain 3*************************************************************
# Epoch 100: pde_loss=0.30663856863975525, JU_loss=-2.3117482662200928, boundary_loss=0.0016998548526316881
# At epoch 100, time_speed: 150.63s, Max abs error is: 0.08075165748596191, best: 0.08268022537231445
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.2683781683444977, JU_loss=-3.121725082397461, boundary_loss=0.001380672911182046
# At epoch 200, time_speed: 1.37s, Max abs error is: 0.08040572702884674, best: 0.08075165748596191
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.27146920561790466, JU_loss=-1.7872376441955566, boundary_loss=0.0011649634689092636
# At epoch 300, time_speed: 1.60s, Max abs error is: 0.07887071371078491, best: 0.08040572702884674
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.13263262808322906, JU_loss=-1.739656686782837, boundary_loss=0.0010098735801875591
# At epoch 400, time_speed: 1.40s, Max abs error is: 0.07754658907651901, best: 0.07887071371078491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.11985687911510468, JU_loss=-2.4274709224700928, boundary_loss=0.0009485909249633551
# At epoch 500, time_speed: 1.30s, Max abs error is: 0.07446122914552689, best: 0.07754658907651901
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.2957698404788971, JU_loss=-1.559725284576416, boundary_loss=0.0008545526070520282
# At epoch 600, time_speed: 1.30s, Max abs error is: 0.07431163638830185, best: 0.07446122914552689
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.19666077196598053, JU_loss=-1.9322433471679688, boundary_loss=0.0008038352243602276
# At epoch 700, time_speed: 1.39s, Max abs error is: 0.07068964093923569, best: 0.07431163638830185
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.17178086936473846, JU_loss=-2.698411226272583, boundary_loss=0.0008008796721696854
# At epoch 800, time_speed: 1.41s, Max abs error is: 0.06975205987691879, best: 0.07068964093923569
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.1030888557434082, JU_loss=-3.012052297592163, boundary_loss=0.0007228559697978199
# At epoch 900, time_speed: 1.41s, Max abs error is: 0.06974255293607712, best: 0.06975205987691879
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.13370011746883392, JU_loss=-1.4995715618133545, boundary_loss=0.0006844751769676805
# At epoch 1000, time_speed: 1.70s, Max abs error is: 0.06623145192861557, best: 0.06974255293607712
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 3 finish, start to train domain 4*************************************************************
# Epoch 100: pde_loss=0.9030001759529114, JU_loss=-1.1176844835281372, boundary_loss=0.003379181958734989
# At epoch 100, time_speed: 164.92s, Max abs error is: 0.1740584671497345, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.6257452964782715, JU_loss=-2.11044979095459, boundary_loss=0.003024510806426406
# At epoch 200, time_speed: 1.90s, Max abs error is: 0.1651332974433899, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.7604705095291138, JU_loss=-2.637105703353882, boundary_loss=0.0026578856632113457
# At epoch 300, time_speed: 1.89s, Max abs error is: 0.15345889329910278, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.7664711475372314, JU_loss=-1.5050582885742188, boundary_loss=0.002444506622850895
# At epoch 400, time_speed: 1.71s, Max abs error is: 0.15192075073719025, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.6779945492744446, JU_loss=-1.8248412609100342, boundary_loss=0.002300648018717766
# At epoch 500, time_speed: 1.30s, Max abs error is: 0.14082211256027222, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.550203263759613, JU_loss=-2.256430149078369, boundary_loss=0.002052954863756895
# At epoch 600, time_speed: 1.29s, Max abs error is: 0.13567718863487244, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.31987282633781433, JU_loss=-2.784766435623169, boundary_loss=0.0018832688219845295
# At epoch 700, time_speed: 1.60s, Max abs error is: 0.13014155626296997, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.5427160859107971, JU_loss=-2.748701810836792, boundary_loss=0.0016873589484021068
# At epoch 800, time_speed: 1.30s, Max abs error is: 0.12413793802261353, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.3748698830604553, JU_loss=-2.155569076538086, boundary_loss=0.0014816895127296448
# At epoch 900, time_speed: 1.28s, Max abs error is: 0.1158001720905304, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.3045666515827179, JU_loss=-1.97163987159729, boundary_loss=0.0014311574632301927
# At epoch 1000, time_speed: 1.24s, Max abs error is: 0.11005739867687225, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 4 finish, start to train domain 1*************************************************************
# start to the 3 steps:
# Epoch 100: pde_loss=0.2579631507396698, JU_loss=-1.6094142198562622, boundary_loss=0.0011345293605700135
# At epoch 100, time_speed: 179.80s, Max abs error is: 0.10095608234405518, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.22242471575737, JU_loss=-2.251269817352295, boundary_loss=0.0008124960586428642
# At epoch 200, time_speed: 1.29s, Max abs error is: 0.09978026151657104, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.18265719711780548, JU_loss=-2.1291351318359375, boundary_loss=0.0007015345618128777
# At epoch 300, time_speed: 1.30s, Max abs error is: 0.0988190770149231, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.09731005877256393, JU_loss=-2.536404609680176, boundary_loss=0.0005914134089834988
# At epoch 400, time_speed: 1.60s, Max abs error is: 0.09769344329833984, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.1104520857334137, JU_loss=-2.29673433303833, boundary_loss=0.0005222743493504822
# At epoch 500, time_speed: 2.20s, Max abs error is: 0.10053294897079468, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.07771739363670349, JU_loss=-2.0632708072662354, boundary_loss=0.00046691257739439607
# At epoch 600, time_speed: 1.41s, Max abs error is: 0.0992504358291626, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.06711322069168091, JU_loss=-2.5770394802093506, boundary_loss=0.00042215059511363506
# At epoch 700, time_speed: 1.38s, Max abs error is: 0.10073864459991455, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.0979548990726471, JU_loss=-2.475897789001465, boundary_loss=0.0003802507999353111
# At epoch 800, time_speed: 1.33s, Max abs error is: 0.09980833530426025, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.044708382338285446, JU_loss=-1.8999055624008179, boundary_loss=0.0003599879564717412
# At epoch 900, time_speed: 1.40s, Max abs error is: 0.10033923387527466, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.08659818768501282, JU_loss=-1.4712201356887817, boundary_loss=0.00034772115759551525
# At epoch 1000, time_speed: 1.87s, Max abs error is: 0.0964123010635376, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.08023608475923538,JU:-2.506218194961548,boundary:0.00033032710780389607
# At epoch 100, time_speed: 195.90s, Max abs error is: 0.10285192728042603, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.04396935552358627,JU:-1.724086046218872,boundary:0.0002620149462018162
# At epoch 200, time_speed: 1.52s, Max abs error is: 0.10335761308670044, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.06841995567083359,JU:-1.6630353927612305,boundary:0.00022562836238648742
# At epoch 300, time_speed: 1.47s, Max abs error is: 0.0979120135307312, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.056374989449977875,JU:-2.3852243423461914,boundary:0.00022325837926473469
# At epoch 400, time_speed: 1.32s, Max abs error is: 0.08834409713745117, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.05433567985892296,JU:-1.329953670501709,boundary:0.00019475564477033913
# At epoch 500, time_speed: 1.31s, Max abs error is: 0.0830351710319519, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0330314077436924,JU:-2.4872171878814697,boundary:0.00018174853175878525
# At epoch 600, time_speed: 1.31s, Max abs error is: 0.07831734418869019, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.025391297414898872,JU:-1.7914390563964844,boundary:0.00013307348126545548
# At epoch 700, time_speed: 1.28s, Max abs error is: 0.07483744621276855, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.02961241640150547,JU:-2.95210337638855,boundary:0.00013134736218489707
# At epoch 800, time_speed: 1.53s, Max abs error is: 0.06758171319961548, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.03133527189493179,JU:-2.1132214069366455,boundary:0.00011180207366123796
# At epoch 900, time_speed: 1.28s, Max abs error is: 0.064597487449646, best: 0.06623145192861557
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.01819649524986744,JU:-1.891920566558838,boundary:0.00010583562834654003
# At epoch 1000, time_speed: 1.31s, Max abs error is: 0.059803009033203125, best: 0.064597487449646
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 2 finish, start to train domain 3*************************************************************
# Epoch 100: pde_loss=0.16437487304210663, JU_loss=-1.4116936922073364, boundary_loss=0.0003418811538722366
# At epoch 100, time_speed: 210.40s, Max abs error is: 0.03455924987792969, best: 0.059803009033203125
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.09619592875242233, JU_loss=-2.432772159576416, boundary_loss=0.00026170400087721646
# At epoch 200, time_speed: 1.83s, Max abs error is: 0.0322224497795105, best: 0.03455924987792969
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.09599997848272324, JU_loss=-3.4740378856658936, boundary_loss=0.00026492407778277993
# At epoch 300, time_speed: 1.30s, Max abs error is: 0.030322372913360596, best: 0.0322224497795105
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.04902731254696846, JU_loss=-3.6647913455963135, boundary_loss=0.0002019371895585209
# At epoch 400, time_speed: 1.40s, Max abs error is: 0.029232412576675415, best: 0.030322372913360596
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.06329521536827087, JU_loss=-2.164790630340576, boundary_loss=0.00021018533152528107
# At epoch 500, time_speed: 1.30s, Max abs error is: 0.028830677270889282, best: 0.029232412576675415
# -----------------------------------------------------------------------------------------------------------------------
# ...
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.00021273009770084172, JU_loss=-1.6205428838729858, boundary_loss=3.209616181720776e-07
# At epoch 700, time_speed: 1.51s, Max abs error is: 0.0018718838691711426, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.00031735358061268926, JU_loss=-2.4698150157928467, boundary_loss=4.692714412612986e-07
# At epoch 800, time_speed: 2.16s, Max abs error is: 0.0019274353981018066, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.00025351563817821443, JU_loss=-1.9155124425888062, boundary_loss=2.4474069505231455e-05
# At epoch 900, time_speed: 1.72s, Max abs error is: 0.0042563676834106445, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.00024614459834992886, JU_loss=-1.5712703466415405, boundary_loss=6.498363291029818e-06
# At epoch 1000, time_speed: 1.28s, Max abs error is: 0.0016256719827651978, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.0003550187102518976,JU:-2.6465859413146973,boundary:2.1952777728984074e-07
# At epoch 100, time_speed: 5522.42s, Max abs error is: 0.0011583566665649414, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00032725429628044367,JU:-1.8038874864578247,boundary:3.5063740142504685e-06
# At epoch 200, time_speed: 1.29s, Max abs error is: 0.002351820468902588, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00024667830439284444,JU:-1.9041600227355957,boundary:1.058098291650822e-06
# At epoch 300, time_speed: 1.31s, Max abs error is: 0.002430260181427002, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0002932474308181554,JU:-2.0239641666412354,boundary:5.648940941682667e-07
# At epoch 400, time_speed: 1.38s, Max abs error is: 0.002036869525909424, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0003163115761708468,JU:-2.283352851867676,boundary:2.2178241465553583e-07
# At epoch 500, time_speed: 1.42s, Max abs error is: 0.0023503899574279785, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00029113018536008894,JU:-1.5189933776855469,boundary:8.864408300723881e-07
# At epoch 600, time_speed: 1.36s, Max abs error is: 0.0019890666007995605, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00032957614166662097,JU:-2.0968940258026123,boundary:4.647406603908166e-05
# At epoch 700, time_speed: 1.31s, Max abs error is: 0.0053438544273376465, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.000331988645484671,JU:-2.1224098205566406,boundary:3.8078951547504403e-06
# At epoch 800, time_speed: 1.30s, Max abs error is: 0.0027174949645996094, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0003154848236590624,JU:-1.4582284688949585,boundary:1.4962036402721424e-05
# At epoch 900, time_speed: 1.23s, Max abs error is: 0.003948211669921875, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00022466578229796141,JU:-1.8685656785964966,boundary:2.314329776709201e-06
# At epoch 1000, time_speed: 1.37s, Max abs error is: 0.0021356940269470215, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 2 finish, start to train domain 3*************************************************************
# Epoch 100: pde_loss=0.00039787785499356687, JU_loss=-2.80495023727417, boundary_loss=5.109150151838548e-07
# At epoch 100, time_speed: 5535.69s, Max abs error is: 0.0017522573471069336, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.0003539923927746713, JU_loss=-1.4905428886413574, boundary_loss=5.784893915006251e-07
# At epoch 200, time_speed: 1.29s, Max abs error is: 0.0010536909103393555, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.00035826355451717973, JU_loss=-2.32892107963562, boundary_loss=9.641381666369853e-07
# At epoch 300, time_speed: 1.44s, Max abs error is: 0.0008894205093383789, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.00026331539265811443, JU_loss=-3.1064188480377197, boundary_loss=4.68920688945218e-06
# At epoch 400, time_speed: 1.39s, Max abs error is: 0.0018134713172912598, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.0002646675275173038, JU_loss=-2.7586538791656494, boundary_loss=2.458962455875735e-07
# At epoch 500, time_speed: 1.30s, Max abs error is: 0.0011216402053833008, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.0003733922785613686, JU_loss=-2.64493989944458, boundary_loss=5.654705091728829e-06
# At epoch 600, time_speed: 1.30s, Max abs error is: 0.0018474459648132324, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.0003704249975271523, JU_loss=-1.6722112894058228, boundary_loss=2.7502019861458393e-07
# At epoch 700, time_speed: 1.89s, Max abs error is: 0.0011066794395446777, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.00028235718491487205, JU_loss=-2.5086328983306885, boundary_loss=4.716080752587004e-07
# At epoch 800, time_speed: 1.39s, Max abs error is: 0.0009645819664001465, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.0002833730832207948, JU_loss=-3.3268632888793945, boundary_loss=7.131448910513427e-06
# At epoch 900, time_speed: 1.29s, Max abs error is: 0.0017145276069641113, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.0003388755430933088, JU_loss=-1.6070750951766968, boundary_loss=5.235056232777424e-05
# At epoch 1000, time_speed: 1.22s, Max abs error is: 0.003960629925131798, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 3 finish, start to train domain 4*************************************************************
# Epoch 100: pde_loss=0.00043402169831097126, JU_loss=-0.8454287052154541, boundary_loss=4.6342066184479336e-07
# At epoch 100, time_speed: 5549.70s, Max abs error is: 0.0018846392631530762, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.00022333521337714046, JU_loss=-1.914810299873352, boundary_loss=7.958774972394167e-07
# At epoch 200, time_speed: 1.39s, Max abs error is: 0.002247154712677002, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.00033995459671132267, JU_loss=-2.0229547023773193, boundary_loss=7.172079676820431e-07
# At epoch 300, time_speed: 1.33s, Max abs error is: 0.0021153688430786133, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.0006547093507833779, JU_loss=-1.685888648033142, boundary_loss=3.587550963857211e-05
# At epoch 400, time_speed: 1.40s, Max abs error is: 0.0032724738121032715, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.00041743589099496603, JU_loss=-2.6827352046966553, boundary_loss=6.590029215658433e-07
# At epoch 500, time_speed: 1.69s, Max abs error is: 0.0020062923431396484, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.00029334152350202203, JU_loss=-3.0234575271606445, boundary_loss=3.0467828082691994e-07
# At epoch 600, time_speed: 1.32s, Max abs error is: 0.0016354918479919434, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.0003730511525645852, JU_loss=-2.6679775714874268, boundary_loss=4.6944808218540857e-07
# At epoch 700, time_speed: 1.38s, Max abs error is: 0.0018387436866760254, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.0003519990714266896, JU_loss=-3.031989336013794, boundary_loss=5.36312597887445e-07
# At epoch 800, time_speed: 1.41s, Max abs error is: 0.0015639662742614746, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.0003715897037182003, JU_loss=-2.747098445892334, boundary_loss=9.965693834601552e-07
# At epoch 900, time_speed: 1.39s, Max abs error is: 0.0013619065284729004, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.0002723117358982563, JU_loss=-1.447534203529358, boundary_loss=1.1144138625240885e-06
# At epoch 1000, time_speed: 1.49s, Max abs error is: 0.0012568235397338867, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# *************************************************************train domain 4 finish, start to train domain 1*************************************************************
# start to the 98 steps:
# Epoch 100: pde_loss=0.0003951860126107931, JU_loss=-3.094545602798462, boundary_loss=1.220135800394928e-06
# At epoch 100, time_speed: 5564.49s, Max abs error is: 0.0028780102729797363, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.0003192512958776206, JU_loss=-1.5811562538146973, boundary_loss=5.409978030002094e-07
# At epoch 200, time_speed: 2.14s, Max abs error is: 0.00225752592086792, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.00031723000574856997, JU_loss=-2.557905673980713, boundary_loss=1.57236609084066e-05
# At epoch 300, time_speed: 1.49s, Max abs error is: 0.0034752488136291504, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.00028065103106200695, JU_loss=-3.0108203887939453, boundary_loss=1.5169146081461804e-06
# At epoch 400, time_speed: 1.48s, Max abs error is: 0.0018454790115356445, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.00030530584626831114, JU_loss=-2.281148910522461, boundary_loss=4.0029894421422796e-07
# At epoch 500, time_speed: 1.40s, Max abs error is: 0.0025147199630737305, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.0004863079229835421, JU_loss=-1.819372534751892, boundary_loss=7.643677236046642e-06
# At epoch 600, time_speed: 1.38s, Max abs error is: 0.003287672996520996, best: 0.0008826851844787598
# -----------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 19
#      17 for step in range(steps):
#      18     print(f"start to the {step} steps:")
# ---> 19     xy_values, u_values, maxerror = train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time)
#      20     print("*************************************************************train domain 1 finish, start to train domain 2*************************************************************")
#      21     xy_values, u_values, maxerror = train2(change_weight, weight_pde, weight_JU, weight_boundary, epoch2, opt, u, maxerror, current_time)
#
# Cell In[23], line 29, in train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time, xy_values, u_values)
#      26         maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)
#      28     # 反向传播和优化
# ---> 29     total_loss.backward()
#      30     opt.step()
#      32 # **计算 x=-delta 的 u 值**
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
