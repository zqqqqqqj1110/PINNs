# %%
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
import torch.nn.functional as F
from skopt import BayesSearchCV
from skopt.space import Real
from skopt import gp_minimize
import torch.nn as nn
import seaborn as sns
from scipy.optimize import minimize
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import matplotlib as mpl
from skopt.utils import use_named_args
from tqdm import tqdm
import multiprocessing
import threading

# %%
# 设置GPU设备，如果没有可用的GPU，则使用CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

setup_seed(888888)

print(device)
# Out:
# cpu

# %%
# 基础参数
epochs = 400000    # 训练代数
h = 100    # 画图网格密度
N = 100    # 内点配置点数
N1 = 0.01    # 边界点配置点数
n = 1000    # PDE数据点
top_k = 100  # 前n个残差最大的点
num_new_points = 10  # 以圆心生成的n个点
bias = 0.001   # 圆半径

# %%
class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(2, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.net(x)

# %%
# Loss
loss = torch.nn.MSELoss()
# loss = torch.nn.L1Loss()  #MAE
# loss = torch.nn.SmoothL1Loss(beta=1.0)

# 递归求导
def gradients(u, x, order=1):
    if order == 1:
        return torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u),
                                   create_graph=True,
                                   only_inputs=True, )[0]
    else:
        return gradients(gradients(u, x), x, order=order - 1)

# %% [markdown]
# # 区域1（-1, +delta）

# %%
def point_1(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True) * 1.05 - 1
    y = torch.rand(n, 1, device=device, requires_grad=True) * 2 - 1
    return x, y


def l_ugeq_1(u, n=100):
    # u >= 0
    x, y = point_1(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_1(u, n=100, device=device):
    # 等式项损失
    x, y = point_1(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_1(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_1(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %% [markdown]
# # 区域2（-delta, 1）

# %%
def point_2(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True) * 1.05 - 0.05
    y = torch.rand(n, 1, device=device, requires_grad=True) * 2 - 1
    return x, y


def l_ugeq_2(u, n=100):
    # u >= 0
    x, y = point_2(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_2(u, n=100, device=device):
    # 等式项损失
    x, y = point_2(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_2(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_2(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %%
# 边界函数构建
def l_boundary1(u):
    # 下边界
    x = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = -torch.ones_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary2(u):
    # 上边界
    x = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = torch.ones_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary3(u):
    # 左边界
    y = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = -torch.ones_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary4(u):
    # 右边界
    y = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = torch.ones_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)


def l_boundary5(u):
    # y轴
    y = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = torch.zeros_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary6(u):
    # x轴
    x = torch.arange(-1.001, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = torch.zeros_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

# %% [markdown]
# # 查看情况代码

# %%
def record_loss_and_save_model(u, epoch, maxerror, current_time, h, device):
    """
    每100次迭代记录一次损失并保存模型。

    参数:
    - u: 模型
    - epoch: 当前训练的 epoch 数
    - maxerror: 当前最小的误差
    - current_time: 上一次记录的时间
    - h: 网格划分大小
    - device: 设备
    返回:
    - maxerror: 更新后的最小误差
    - current_time: 更新后的时间
    """
    # 生成网格点
    xc_x = torch.linspace(-1, 1, h, device=device)
    xc_y = torch.linspace(-1, 1, h, device=device)
    xm, ym = torch.meshgrid(xc_x, xc_y)
    xx = xm.reshape(-1, 1)
    yy = ym.reshape(-1, 1)
    xy = torch.cat([xx, yy], dim=1).to(device)

    # 计算预测值和真实值
    u_pred = torch.relu(u(xy))
    u_real = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy))
    u_error = torch.abs(u_pred - u_real)

    # 计算误差网格
    u_pred_fig = u_pred.reshape(h, h)
    u_real_fig = u_real.reshape(h, h)
    u_error_fig = u_error.reshape(h, h)

    # 计算当前最大绝对误差
    max_abs_error = float(torch.max(u_error))
    print(f"At epoch {epoch}, time_speed: {abs(current_time - time.time()):.2f}s, Max abs error is: {max_abs_error}, best: {maxerror}")
    print('-----------------------------------------------------------------------------------------------------------------------')

    # 如果误差更小，则保存模型
    if max_abs_error < maxerror:
        maxerror = max_abs_error
        torch.save(u.state_dict(), 'weights.pth')
        
    torch.save(u.state_dict(), 'weights11.pth')

    # 更新当前时间
    current_time = time.time()

    return maxerror, current_time

# %% [markdown]
# # 区域训练

# %% [markdown]
# ## 区域1（0-0.6）g

# %%
def train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch1):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_1(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_1(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_1(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u) + l_boundary5(u) + l_boundary6(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary

        # 区域交换
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)
            total_loss += change_weight * boundary_loss
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"Epoch {epoch}: pde_loss={pde_loss.item()}, JU_loss={JU_loss.item()}, boundary_loss={loss_boundary.item()}")
            # 记录 maxerror 并保存模型
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)

        # 反向传播和优化
        total_loss.backward()
        opt.step()
    
    print("\n训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值")

    # **计算 x=-delta 的 u 值**
    y_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.02, 0.02, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.01, 0.01, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.005, 0.005, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.002, 0.002, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.001, 0.001, device=device).unsqueeze(1)
    
    x_values = torch.full_like(y_values, 0 - delta)  # 创建 x=0.4 的列向量
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)

    # 用 u 计算这些点的值
    u_values = u(xy_values).detach().cpu().numpy()


    return xy_values, u_values, maxerror

# %% [markdown]
# ## 区域2（0.4-1）g

# %%
def train2(change_weight, weight_pde, weight_JU, weight_boundary, epoch2, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch2):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_2(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_2(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_2(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u) + l_boundary5(u) + l_boundary6(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary
        
        # **如果传入了 xy_values 和 u_values，添加它们作为边界条件
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)  # 计算神经网络的预测值
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)  # MSE损失
            total_loss += change_weight * boundary_loss  # 给边界损失较大权重
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"pde:{pde_loss.item()},JU:{JU_loss.item()},boundary:{loss_boundary.item()}")
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)
        
        # if epoch % 100000 == 0 and epoch != 0:
        #     X, Y = update_dataset(X, Y, inside_loss, x_pde, y_pde, top_k, num_new_points, bias, device)
    
        # 反向传播和优化
        total_loss.backward()
        opt.step()
    
    print("\n训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值")

    # **计算 x=+delta 的 u 值**
    y_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.02, 0.02, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.01, 0.01, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.005, 0.005, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.002, 0.002, device=device).unsqueeze(1)
    # y_values = torch.arange(0, 1.001, 0.001, device=device).unsqueeze(1)
    
    x_values = torch.full_like(y_values, 0 + delta)  # 创建 x=+delta 的列向量
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)

    # **用 u 计算这些点的值**
    u_values = u(xy_values).detach().cpu().numpy()


    return xy_values, u_values, maxerror

# %% [markdown]
# # 训练

# %%
# Training
u = MLP().to(device)
opt = torch.optim.Adam(params=u.parameters(), lr=0.0001)

# 设置初始权重
weight_pde = 6000000000
weight_JU = 2000000
weight_boundary = 1000000000000
change_weight = 2000000
current_time = time.time()
start_time = time.time()
maxerror = 99999999999
epoch2 = epoch1 = 1001
steps = 2000
delta = 0.05

for step in range(steps):
    print(f"start to the {step} steps:")
    xy_values, u_values, maxerror = train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time)
    # if maxerror < 0.001:
    #     end_time = time.time()
    #     print(f"迭代停止步数为：{step+1},时间为：{end_time-start_time}")
    #     break
    print("*************************************************************train domain 1 finish, start to train domain 2*************************************************************")
    xy_values, u_values, maxerror = train2(change_weight, weight_pde, weight_JU, weight_boundary, epoch2, opt, u, maxerror, current_time)
    # if maxerror < 0.001:
    #     end_time = time.time()
    #     print(f"迭代停止步数为：{step+1},时间为：{end_time-start_time}")
    #     break
    print("*************************************************************train domain 2 finish, start to train domain 1*************************************************************")

print("                                                                        END TRAINING")
# Out:
# start to the 0 steps:
# Epoch 100: pde_loss=114.26171112060547, JU_loss=-0.04192660003900528, boundary_loss=0.00030400531250052154
# At epoch 100, time_speed: 2.39s, Max abs error is: 0.9997482299804688, best: 99999999999
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=75.8173599243164, JU_loss=-0.053592558950185776, boundary_loss=0.00043227578862570226
# At epoch 200, time_speed: 1.81s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=82.4888687133789, JU_loss=-0.0838087871670723, boundary_loss=0.0007797694415785372
# At epoch 300, time_speed: 1.96s, Max abs error is: 0.9997482299804688, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=80.93579864501953, JU_loss=-0.13537269830703735, boundary_loss=0.00165573600679636
# At epoch 400, time_speed: 2.20s, Max abs error is: 0.9987258911132812, best: 0.9997482299804688
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=75.25128936767578, JU_loss=-0.27298539876937866, boundary_loss=0.004019852261990309
# At epoch 500, time_speed: 1.81s, Max abs error is: 0.9997482299804688, best: 0.9987258911132812
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=76.09611511230469, JU_loss=-0.7097885608673096, boundary_loss=0.013672485016286373
# At epoch 600, time_speed: 2.03s, Max abs error is: 0.9997482299804688, best: 0.9987258911132812
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=47.68009948730469, JU_loss=-1.3576998710632324, boundary_loss=0.052170395851135254
# At epoch 700, time_speed: 1.79s, Max abs error is: 0.9997482299804688, best: 0.9987258911132812
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=35.20317840576172, JU_loss=-2.3682310581207275, boundary_loss=0.07580331712961197
# At epoch 800, time_speed: 1.88s, Max abs error is: 0.9997482299804688, best: 0.9987258911132812
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=18.222314834594727, JU_loss=-2.2091195583343506, boundary_loss=0.0802329033613205
# At epoch 900, time_speed: 1.30s, Max abs error is: 0.9997482299804688, best: 0.9987258911132812
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=13.760271072387695, JU_loss=-2.9731903076171875, boundary_loss=0.06988412886857986
# At epoch 1000, time_speed: 1.23s, Max abs error is: 0.9997482299804688, best: 0.9987258911132812
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:80.18589782714844,JU:-0.6359676718711853,boundary:0.03223124518990517
# At epoch 100, time_speed: 19.71s, Max abs error is: 0.8945515155792236, best: 0.9987258911132812
# -----------------------------------------------------------------------------------------------------------------------
# pde:46.47539520263672,JU:-1.152998685836792,boundary:0.027689898386597633
# At epoch 200, time_speed: 1.36s, Max abs error is: 0.7703193426132202, best: 0.8945515155792236
# -----------------------------------------------------------------------------------------------------------------------
# pde:38.66634750366211,JU:-1.3234602212905884,boundary:0.020131345838308334
# At epoch 300, time_speed: 1.33s, Max abs error is: 0.5522047281265259, best: 0.7703193426132202
# -----------------------------------------------------------------------------------------------------------------------
# pde:17.837369918823242,JU:-3.103750228881836,boundary:0.018982896581292152
# At epoch 400, time_speed: 1.27s, Max abs error is: 0.382743239402771, best: 0.5522047281265259
# -----------------------------------------------------------------------------------------------------------------------
# pde:12.674163818359375,JU:-1.7198083400726318,boundary:0.021978851407766342
# At epoch 500, time_speed: 1.13s, Max abs error is: 0.3177037239074707, best: 0.382743239402771
# -----------------------------------------------------------------------------------------------------------------------
# pde:8.300236701965332,JU:-1.5253111124038696,boundary:0.022536873817443848
# At epoch 600, time_speed: 1.38s, Max abs error is: 0.35900384187698364, best: 0.3177037239074707
# -----------------------------------------------------------------------------------------------------------------------
# pde:7.680770397186279,JU:-3.1151816844940186,boundary:0.021957961842417717
# At epoch 700, time_speed: 1.21s, Max abs error is: 0.39037102460861206, best: 0.3177037239074707
# -----------------------------------------------------------------------------------------------------------------------
# pde:6.141046047210693,JU:-2.143760919570923,boundary:0.020701434463262558
# At epoch 800, time_speed: 1.20s, Max abs error is: 0.41730594635009766, best: 0.3177037239074707
# -----------------------------------------------------------------------------------------------------------------------
# pde:6.2350568771362305,JU:-2.755648136138916,boundary:0.019490066915750504
# At epoch 900, time_speed: 1.20s, Max abs error is: 0.4331088066101074, best: 0.3177037239074707
# -----------------------------------------------------------------------------------------------------------------------
# pde:4.369246959686279,JU:-2.9835829734802246,boundary:0.017978576943278313
# At epoch 1000, time_speed: 1.31s, Max abs error is: 0.44324496388435364, best: 0.3177037239074707
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 1 steps:
# Epoch 100: pde_loss=3.758720636367798, JU_loss=-2.2954659461975098, boundary_loss=0.022340837866067886
# At epoch 100, time_speed: 32.60s, Max abs error is: 0.1936115324497223, best: 0.3177037239074707
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=4.190896511077881, JU_loss=-3.185821533203125, boundary_loss=0.01804843172430992
# At epoch 200, time_speed: 1.37s, Max abs error is: 0.20075887441635132, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=3.130403518676758, JU_loss=-1.0823912620544434, boundary_loss=0.015027698129415512
# At epoch 300, time_speed: 1.24s, Max abs error is: 0.1946706771850586, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=3.036557912826538, JU_loss=-2.9419925212860107, boundary_loss=0.013659557327628136
# At epoch 400, time_speed: 1.46s, Max abs error is: 0.21146249771118164, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=2.3340189456939697, JU_loss=-1.704444408416748, boundary_loss=0.011761890724301338
# At epoch 500, time_speed: 1.24s, Max abs error is: 0.21896761655807495, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=3.749145269393921, JU_loss=-2.549304485321045, boundary_loss=0.010846135206520557
# At epoch 600, time_speed: 1.36s, Max abs error is: 0.22261595726013184, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=2.612320899963379, JU_loss=-1.8173869848251343, boundary_loss=0.010227827355265617
# At epoch 700, time_speed: 1.31s, Max abs error is: 0.22468119859695435, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=2.6025469303131104, JU_loss=-2.816028118133545, boundary_loss=0.009336506016552448
# At epoch 800, time_speed: 1.31s, Max abs error is: 0.22645443677902222, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=2.564448595046997, JU_loss=-1.021154522895813, boundary_loss=0.008763199672102928
# At epoch 900, time_speed: 2.02s, Max abs error is: 0.22266250848770142, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=1.828782558441162, JU_loss=-1.1180484294891357, boundary_loss=0.008345100097358227
# At epoch 1000, time_speed: 1.97s, Max abs error is: 0.22877824306488037, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:4.953454494476318,JU:-2.7965188026428223,boundary:0.012934248894453049
# At epoch 100, time_speed: 47.71s, Max abs error is: 0.18618617951869965, best: 0.1936115324497223
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.3945152759552,JU:-1.8377234935760498,boundary:0.013331824913620949
# At epoch 200, time_speed: 1.59s, Max abs error is: 0.18645831942558289, best: 0.18618617951869965
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.813836097717285,JU:-3.1462345123291016,boundary:0.012233707122504711
# At epoch 300, time_speed: 1.27s, Max abs error is: 0.1877421736717224, best: 0.18618617951869965
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.9084179401397705,JU:-2.043351411819458,boundary:0.011491375043988228
# At epoch 400, time_speed: 1.62s, Max abs error is: 0.18058806657791138, best: 0.18618617951869965
# -----------------------------------------------------------------------------------------------------------------------
# pde:5.095717430114746,JU:-2.203709363937378,boundary:0.010681696236133575
# At epoch 500, time_speed: 1.27s, Max abs error is: 0.170242041349411, best: 0.18058806657791138
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.925191640853882,JU:-3.4188971519470215,boundary:0.010291962884366512
# At epoch 600, time_speed: 1.30s, Max abs error is: 0.1754453033208847, best: 0.170242041349411
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.3261520862579346,JU:-2.4801077842712402,boundary:0.009675334207713604
# At epoch 700, time_speed: 1.33s, Max abs error is: 0.16688399016857147, best: 0.170242041349411
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.0937552452087402,JU:-2.1904900074005127,boundary:0.009394090622663498
# At epoch 800, time_speed: 1.29s, Max abs error is: 0.1603885293006897, best: 0.16688399016857147
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.9161384105682373,JU:-1.5637158155441284,boundary:0.00908794067800045
# At epoch 900, time_speed: 1.28s, Max abs error is: 0.15772363543510437, best: 0.1603885293006897
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.0239624977111816,JU:-2.2511870861053467,boundary:0.008707839995622635
# At epoch 1000, time_speed: 1.30s, Max abs error is: 0.1662467122077942, best: 0.15772363543510437
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 2 steps:
# Epoch 100: pde_loss=1.502951979637146, JU_loss=-2.313568353652954, boundary_loss=0.008560208603739738
# At epoch 100, time_speed: 61.38s, Max abs error is: 0.1445154845714569, best: 0.15772363543510437
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=1.4814873933792114, JU_loss=-2.407433271408081, boundary_loss=0.0070787291042506695
# At epoch 200, time_speed: 1.50s, Max abs error is: 0.13887713849544525, best: 0.1445154845714569
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=1.3900752067565918, JU_loss=-3.3148844242095947, boundary_loss=0.006201314739882946
# At epoch 300, time_speed: 1.43s, Max abs error is: 0.14938974380493164, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=1.7003114223480225, JU_loss=-2.366816520690918, boundary_loss=0.005815370474010706
# At epoch 400, time_speed: 1.84s, Max abs error is: 0.15629225969314575, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=2.1380438804626465, JU_loss=-2.1119673252105713, boundary_loss=0.0053991712629795074
# At epoch 500, time_speed: 1.87s, Max abs error is: 0.16817104816436768, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=1.6049188375473022, JU_loss=-2.7178478240966797, boundary_loss=0.005232298281043768
# At epoch 600, time_speed: 1.49s, Max abs error is: 0.1768256425857544, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=2.395069122314453, JU_loss=-2.283853530883789, boundary_loss=0.004851307719945908
# At epoch 700, time_speed: 1.32s, Max abs error is: 0.18159335851669312, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=1.6430352926254272, JU_loss=-2.873915910720825, boundary_loss=0.004703332204371691
# At epoch 800, time_speed: 1.30s, Max abs error is: 0.18802708387374878, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=2.0973212718963623, JU_loss=-2.1375532150268555, boundary_loss=0.0043916404247283936
# At epoch 900, time_speed: 1.40s, Max abs error is: 0.189666748046875, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=1.2396719455718994, JU_loss=-2.512192487716675, boundary_loss=0.004249725490808487
# At epoch 1000, time_speed: 1.39s, Max abs error is: 0.1932530403137207, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:3.3099396228790283,JU:-2.311147689819336,boundary:0.008182264864444733
# At epoch 100, time_speed: 76.31s, Max abs error is: 0.1450999677181244, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.6536781787872314,JU:-3.4735267162323,boundary:0.007526986766606569
# At epoch 200, time_speed: 1.27s, Max abs error is: 0.14247673749923706, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.5356175899505615,JU:-1.605940341949463,boundary:0.007340429350733757
# At epoch 300, time_speed: 1.30s, Max abs error is: 0.1502319574356079, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.7434439659118652,JU:-1.3038946390151978,boundary:0.006946433335542679
# At epoch 400, time_speed: 1.21s, Max abs error is: 0.1326364278793335, best: 0.13887713849544525
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.4550673961639404,JU:-1.9726989269256592,boundary:0.006612449884414673
# At epoch 500, time_speed: 1.38s, Max abs error is: 0.13467761874198914, best: 0.1326364278793335
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.264381170272827,JU:-1.4416837692260742,boundary:0.006449723616242409
# At epoch 600, time_speed: 1.22s, Max abs error is: 0.12298139929771423, best: 0.1326364278793335
# -----------------------------------------------------------------------------------------------------------------------
# pde:4.267179012298584,JU:-2.124335527420044,boundary:0.006081744562834501
# At epoch 700, time_speed: 1.41s, Max abs error is: 0.12058787047863007, best: 0.12298139929771423
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.7346291542053223,JU:-1.218930721282959,boundary:0.005971699953079224
# At epoch 800, time_speed: 1.26s, Max abs error is: 0.11166387796401978, best: 0.12058787047863007
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.7910101413726807,JU:-1.487599492073059,boundary:0.005731984041631222
# At epoch 900, time_speed: 1.40s, Max abs error is: 0.11400611698627472, best: 0.11166387796401978
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.530501127243042,JU:-2.4412286281585693,boundary:0.005506825167685747
# At epoch 1000, time_speed: 2.31s, Max abs error is: 0.10406522452831268, best: 0.11166387796401978
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 3 steps:
# Epoch 100: pde_loss=2.0819733142852783, JU_loss=-3.239513874053955, boundary_loss=0.004921063780784607
# At epoch 100, time_speed: 91.20s, Max abs error is: 0.10679934173822403, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.9677430987358093, JU_loss=-2.15010142326355, boundary_loss=0.004247961565852165
# At epoch 200, time_speed: 1.81s, Max abs error is: 0.13209384679794312, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=1.420078992843628, JU_loss=-3.1470160484313965, boundary_loss=0.003877174574881792
# At epoch 300, time_speed: 2.06s, Max abs error is: 0.14616084098815918, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=1.6617937088012695, JU_loss=-2.603163719177246, boundary_loss=0.003657800843939185
# At epoch 400, time_speed: 2.03s, Max abs error is: 0.1590023636817932, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=1.6200789213180542, JU_loss=-3.1894452571868896, boundary_loss=0.0033476445823907852
# At epoch 500, time_speed: 1.89s, Max abs error is: 0.16950422525405884, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.9349761009216309, JU_loss=-2.7111337184906006, boundary_loss=0.0031977177131921053
# At epoch 600, time_speed: 1.59s, Max abs error is: 0.1757340431213379, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.5881207585334778, JU_loss=-1.8410165309906006, boundary_loss=0.0030497689731419086
# At epoch 700, time_speed: 1.50s, Max abs error is: 0.18291932344436646, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.9515683054924011, JU_loss=-2.1946353912353516, boundary_loss=0.002885835710912943
# At epoch 800, time_speed: 1.32s, Max abs error is: 0.19214248657226562, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=1.3032028675079346, JU_loss=-2.1564643383026123, boundary_loss=0.0028145876713097095
# At epoch 900, time_speed: 1.56s, Max abs error is: 0.19445651769638062, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.7852928042411804, JU_loss=-3.0751922130584717, boundary_loss=0.002680516103282571
# At epoch 1000, time_speed: 1.32s, Max abs error is: 0.20393580198287964, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:1.8893530368804932,JU:-2.9923031330108643,boundary:0.005479824263602495
# At epoch 100, time_speed: 107.59s, Max abs error is: 0.12707088887691498, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.285485029220581,JU:-2.4570908546447754,boundary:0.004874708130955696
# At epoch 200, time_speed: 1.80s, Max abs error is: 0.10969063639640808, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.064358711242676,JU:-2.7697243690490723,boundary:0.004537534434348345
# At epoch 300, time_speed: 1.70s, Max abs error is: 0.09560681879520416, best: 0.10406522452831268
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.7973456382751465,JU:-2.2891554832458496,boundary:0.0043869176879525185
# At epoch 400, time_speed: 1.37s, Max abs error is: 0.09429354965686798, best: 0.09560681879520416
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.5705986022949219,JU:-3.502995252609253,boundary:0.004172756336629391
# At epoch 500, time_speed: 1.14s, Max abs error is: 0.0857454240322113, best: 0.09429354965686798
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.8299987316131592,JU:-2.7272374629974365,boundary:0.003895610338076949
# At epoch 600, time_speed: 1.37s, Max abs error is: 0.0814838707447052, best: 0.0857454240322113
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.6337045431137085,JU:-2.2480368614196777,boundary:0.0037925145588815212
# At epoch 700, time_speed: 1.50s, Max abs error is: 0.08095874637365341, best: 0.0814838707447052
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.509437918663025,JU:-3.546901226043701,boundary:0.0036994898691773415
# At epoch 800, time_speed: 1.31s, Max abs error is: 0.08509600162506104, best: 0.08095874637365341
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.4189398288726807,JU:-2.005625009536743,boundary:0.003493888070806861
# At epoch 900, time_speed: 1.28s, Max abs error is: 0.08310574293136597, best: 0.08095874637365341
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.494134783744812,JU:-1.9622290134429932,boundary:0.003382729832082987
# At epoch 1000, time_speed: 1.23s, Max abs error is: 0.08535969257354736, best: 0.08095874637365341
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 4 steps:
# Epoch 100: pde_loss=0.6842852830886841, JU_loss=-2.834240436553955, boundary_loss=0.0028919843025505543
# At epoch 100, time_speed: 121.77s, Max abs error is: 0.0784187912940979, best: 0.08095874637365341
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.4989738464355469, JU_loss=-2.4148993492126465, boundary_loss=0.002537960885092616
# At epoch 200, time_speed: 1.30s, Max abs error is: 0.09467858076095581, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=1.0603041648864746, JU_loss=-1.3377940654754639, boundary_loss=0.0023843522649258375
# At epoch 300, time_speed: 1.23s, Max abs error is: 0.11147040128707886, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=1.0132150650024414, JU_loss=-1.5695359706878662, boundary_loss=0.0021614383440464735
# At epoch 400, time_speed: 1.37s, Max abs error is: 0.12122845649719238, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.873228907585144, JU_loss=-2.711465358734131, boundary_loss=0.0020095854997634888
# At epoch 500, time_speed: 1.40s, Max abs error is: 0.13063061237335205, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.5842797756195068, JU_loss=-2.84906005859375, boundary_loss=0.0019190385937690735
# At epoch 600, time_speed: 1.52s, Max abs error is: 0.1390172839164734, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.5956189036369324, JU_loss=-2.0983994007110596, boundary_loss=0.001804133877158165
# At epoch 700, time_speed: 1.80s, Max abs error is: 0.14403671026229858, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.5642711520195007, JU_loss=-3.0617763996124268, boundary_loss=0.0017141005955636501
# At epoch 800, time_speed: 1.88s, Max abs error is: 0.1541072130203247, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.4946697950363159, JU_loss=-1.9244259595870972, boundary_loss=0.0016424927162006497
# At epoch 900, time_speed: 1.82s, Max abs error is: 0.1555020809173584, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.4835539758205414, JU_loss=-2.977858304977417, boundary_loss=0.0015871019568294287
# At epoch 1000, time_speed: 1.88s, Max abs error is: 0.1650458574295044, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:1.278451681137085,JU:-2.5908026695251465,boundary:0.0030275227036327124
# At epoch 100, time_speed: 137.49s, Max abs error is: 0.07770400494337082, best: 0.0784187912940979
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.2839844226837158,JU:-2.7925374507904053,boundary:0.0027983335312455893
# At epoch 200, time_speed: 1.50s, Max abs error is: 0.07590506225824356, best: 0.07770400494337082
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.8614108562469482,JU:-1.7184624671936035,boundary:0.0027777093928307295
# At epoch 300, time_speed: 1.89s, Max abs error is: 0.06878401339054108, best: 0.07590506225824356
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.4552063941955566,JU:-2.7016172409057617,boundary:0.002480443101376295
# At epoch 400, time_speed: 1.80s, Max abs error is: 0.06388068944215775, best: 0.06878401339054108
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.9551942944526672,JU:-2.0627481937408447,boundary:0.0024395303335040808
# At epoch 500, time_speed: 1.60s, Max abs error is: 0.06255929172039032, best: 0.06388068944215775
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.9856444001197815,JU:-1.9932633638381958,boundary:0.0022536718752235174
# At epoch 600, time_speed: 1.39s, Max abs error is: 0.05694255232810974, best: 0.06255929172039032
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.7838914394378662,JU:-3.0131890773773193,boundary:0.0022523878142237663
# At epoch 700, time_speed: 1.43s, Max abs error is: 0.05994872748851776, best: 0.05694255232810974
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.6209607124328613,JU:-2.682015895843506,boundary:0.0020887190476059914
# At epoch 800, time_speed: 1.36s, Max abs error is: 0.05834859609603882, best: 0.05694255232810974
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.7201471328735352,JU:-1.6368587017059326,boundary:0.002024377230554819
# At epoch 900, time_speed: 1.21s, Max abs error is: 0.05875366926193237, best: 0.05694255232810974
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.5620867609977722,JU:-2.006943464279175,boundary:0.0019072964787483215
# At epoch 1000, time_speed: 1.32s, Max abs error is: 0.055787742137908936, best: 0.05694255232810974
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 5 steps:
# Epoch 100: pde_loss=0.777091383934021, JU_loss=-2.470900297164917, boundary_loss=0.001580620533786714
# At epoch 100, time_speed: 152.28s, Max abs error is: 0.06473642587661743, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.5636739730834961, JU_loss=-2.7486412525177, boundary_loss=0.0014213125687092543
# At epoch 200, time_speed: 1.41s, Max abs error is: 0.07924509048461914, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.6553108096122742, JU_loss=-2.205429792404175, boundary_loss=0.001237069838680327
# At epoch 300, time_speed: 1.79s, Max abs error is: 0.08433747291564941, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.7808539867401123, JU_loss=-2.6489648818969727, boundary_loss=0.0011988094775006175
# At epoch 400, time_speed: 1.39s, Max abs error is: 0.09379535913467407, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.37547263503074646, JU_loss=-2.1510109901428223, boundary_loss=0.001197309698909521
# At epoch 500, time_speed: 1.32s, Max abs error is: 0.09998553991317749, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.8227910399436951, JU_loss=-1.5402470827102661, boundary_loss=0.0010800259187817574
# At epoch 600, time_speed: 1.20s, Max abs error is: 0.10288161039352417, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.3788944482803345, JU_loss=-1.233283281326294, boundary_loss=0.001068399753421545
# At epoch 700, time_speed: 1.31s, Max abs error is: 0.10814881324768066, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.2682289481163025, JU_loss=-2.674807071685791, boundary_loss=0.0010750072542577982
# At epoch 800, time_speed: 1.29s, Max abs error is: 0.11568784713745117, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.32241055369377136, JU_loss=-3.2288546562194824, boundary_loss=0.0009747360600158572
# At epoch 900, time_speed: 1.29s, Max abs error is: 0.11182332038879395, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.43878763914108276, JU_loss=-3.2468903064727783, boundary_loss=0.0009630303247831762
# At epoch 1000, time_speed: 1.29s, Max abs error is: 0.11329144239425659, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.8868420124053955,JU:-2.1981911659240723,boundary:0.001637822249904275
# At epoch 100, time_speed: 165.88s, Max abs error is: 0.05408111959695816, best: 0.055787742137908936
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.9552410840988159,JU:-1.4081283807754517,boundary:0.0015800949186086655
# At epoch 200, time_speed: 1.22s, Max abs error is: 0.05323577672243118, best: 0.05408111959695816
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.1306707859039307,JU:-1.7127406597137451,boundary:0.0015042084269225597
# At epoch 300, time_speed: 1.41s, Max abs error is: 0.052022360265254974, best: 0.05323577672243118
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.7399992942810059,JU:-2.0752828121185303,boundary:0.001392727717757225
# At epoch 400, time_speed: 1.27s, Max abs error is: 0.04603097587823868, best: 0.052022360265254974
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.013462781906128,JU:-2.8362016677856445,boundary:0.001398935099132359
# At epoch 500, time_speed: 1.89s, Max abs error is: 0.04792090505361557, best: 0.04603097587823868
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.7003700137138367,JU:-1.6360831260681152,boundary:0.001339285634458065
# At epoch 600, time_speed: 1.34s, Max abs error is: 0.046470485627651215, best: 0.04603097587823868
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.6360499262809753,JU:-2.0692341327667236,boundary:0.0012384930159896612
# At epoch 700, time_speed: 1.22s, Max abs error is: 0.04423035681247711, best: 0.04603097587823868
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.7105526924133301,JU:-1.5573333501815796,boundary:0.0011704608332365751
# At epoch 800, time_speed: 1.22s, Max abs error is: 0.04256410896778107, best: 0.04423035681247711
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.8346425890922546,JU:-1.9699831008911133,boundary:0.0011057009687647223
# At epoch 900, time_speed: 1.31s, Max abs error is: 0.040049850940704346, best: 0.04256410896778107
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.9940834045410156,JU:-1.6984341144561768,boundary:0.0010790735250338912
# At epoch 1000, time_speed: 1.26s, Max abs error is: 0.041549503803253174, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 6 steps:
# Epoch 100: pde_loss=0.530398428440094, JU_loss=-3.214813232421875, boundary_loss=0.0008391450974158943
# At epoch 100, time_speed: 179.28s, Max abs error is: 0.05379462242126465, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.3852483332157135, JU_loss=-1.783484697341919, boundary_loss=0.0008057357044890523
# At epoch 200, time_speed: 1.21s, Max abs error is: 0.059320688247680664, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.31323185563087463, JU_loss=-1.4340689182281494, boundary_loss=0.000733738299459219
# At epoch 300, time_speed: 1.31s, Max abs error is: 0.06532877683639526, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.3218795657157898, JU_loss=-2.3005831241607666, boundary_loss=0.0006949320086278021
# At epoch 400, time_speed: 1.38s, Max abs error is: 0.07160913944244385, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.2753819525241852, JU_loss=-1.5071747303009033, boundary_loss=0.0007127849967218935
# At epoch 500, time_speed: 1.79s, Max abs error is: 0.07348799705505371, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.20167182385921478, JU_loss=-2.323086738586426, boundary_loss=0.0006482782773673534
# At epoch 600, time_speed: 1.81s, Max abs error is: 0.07537627220153809, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.2251633256673813, JU_loss=-2.3770759105682373, boundary_loss=0.0006933387485332787
# At epoch 700, time_speed: 1.39s, Max abs error is: 0.07155698537826538, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.3049585521221161, JU_loss=-1.285903811454773, boundary_loss=0.0006091895629651845
# At epoch 800, time_speed: 1.30s, Max abs error is: 0.08206808567047119, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.35377347469329834, JU_loss=-2.8651680946350098, boundary_loss=0.0006359964609146118
# At epoch 900, time_speed: 1.29s, Max abs error is: 0.07882601022720337, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.24659854173660278, JU_loss=-3.236088752746582, boundary_loss=0.0005890819011256099
# At epoch 1000, time_speed: 2.01s, Max abs error is: 0.08197915554046631, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:1.0445733070373535,JU:-1.8329930305480957,boundary:0.0009691151208244264
# At epoch 100, time_speed: 194.78s, Max abs error is: 0.041535764932632446, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.8474003076553345,JU:-2.056823253631592,boundary:0.0008442017715424299
# At epoch 200, time_speed: 1.91s, Max abs error is: 0.03971266746520996, best: 0.040049850940704346
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.9062297940254211,JU:-2.32981276512146,boundary:0.0008323817164637148
# At epoch 300, time_speed: 1.80s, Max abs error is: 0.037743665277957916, best: 0.03971266746520996
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.37575817108154297,JU:-2.6827096939086914,boundary:0.0008053258061408997
# At epoch 400, time_speed: 1.88s, Max abs error is: 0.0398995578289032, best: 0.037743665277957916
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.9296283721923828,JU:-1.115699291229248,boundary:0.0008028566371649504
# At epoch 500, time_speed: 1.92s, Max abs error is: 0.04074566811323166, best: 0.037743665277957916
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.5015630722045898,JU:-1.9348903894424438,boundary:0.0007364058401435614
# At epoch 600, time_speed: 1.97s, Max abs error is: 0.03194236755371094, best: 0.037743665277957916
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.5229670405387878,JU:-2.4469192028045654,boundary:0.0006857243133708835
# At epoch 700, time_speed: 1.83s, Max abs error is: 0.03215190768241882, best: 0.03194236755371094
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.5730936527252197,JU:-2.371234655380249,boundary:0.0006209531566128135
# At epoch 800, time_speed: 1.30s, Max abs error is: 0.03085261583328247, best: 0.03194236755371094
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.32126036286354065,JU:-1.995222806930542,boundary:0.0006179595948196948
# At epoch 900, time_speed: 1.29s, Max abs error is: 0.03617445379495621, best: 0.03085261583328247
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.2866044342517853,JU:-1.7359334230422974,boundary:0.0005833679460920393
# At epoch 1000, time_speed: 1.27s, Max abs error is: 0.03102189302444458, best: 0.03085261583328247
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 7 steps:
# Epoch 100: pde_loss=0.36948761343955994, JU_loss=-3.0399749279022217, boundary_loss=0.0004673181101679802
# At epoch 100, time_speed: 211.89s, Max abs error is: 0.03873491287231445, best: 0.03085261583328247
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.2649150788784027, JU_loss=-3.0555267333984375, boundary_loss=0.0004688178887590766
# At epoch 200, time_speed: 1.98s, Max abs error is: 0.045626819133758545, best: 0.03085261583328247
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.26838919520378113, JU_loss=-2.042029619216919, boundary_loss=0.0004524133400991559
# At epoch 300, time_speed: 1.43s, Max abs error is: 0.05233651399612427, best: 0.03085261583328247
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.2375100553035736, JU_loss=-3.305068016052246, boundary_loss=0.0004336260899435729
# At epoch 400, time_speed: 1.39s, Max abs error is: 0.048830270767211914, best: 0.03085261583328247
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.33224910497665405, JU_loss=-2.1708688735961914, boundary_loss=0.000424528174335137
# At epoch 500, time_speed: 1.29s, Max abs error is: 0.051796555519104004, best: 0.03085261583328247
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.18875473737716675, JU_loss=-2.5761022567749023, boundary_loss=0.00040650131995789707
# ...
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.0035721769090741873, JU_loss=-2.023277997970581, boundary_loss=6.118908459029626e-06
# At epoch 400, time_speed: 1.28s, Max abs error is: 0.002467907965183258, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.0026578842662274837, JU_loss=-2.121190071105957, boundary_loss=0.00016866215446498245
# At epoch 500, time_speed: 1.20s, Max abs error is: 0.007422804832458496, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.004337257239967585, JU_loss=-2.350137710571289, boundary_loss=7.555284355476033e-06
# At epoch 600, time_speed: 1.30s, Max abs error is: 0.0020028352737426758, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.002314202953130007, JU_loss=-3.046766757965088, boundary_loss=3.7432000681292266e-06
# At epoch 700, time_speed: 1.29s, Max abs error is: 0.001574631780385971, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.00462225079536438, JU_loss=-2.2626986503601074, boundary_loss=3.6582882785296533e-06
# At epoch 800, time_speed: 1.21s, Max abs error is: 0.0018572807312011719, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.0038596498779952526, JU_loss=-2.6736156940460205, boundary_loss=2.4958171707112342e-06
# At epoch 900, time_speed: 1.22s, Max abs error is: 0.00202295184135437, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.005646544508635998, JU_loss=-1.8817777633666992, boundary_loss=4.775968136527808e-06
# At epoch 1000, time_speed: 1.49s, Max abs error is: 0.0018269717693328857, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.0027228309772908688,JU:-2.862894058227539,boundary:5.846519798069494e-06
# At epoch 100, time_speed: 6456.50s, Max abs error is: 0.001835837960243225, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0020178318955004215,JU:-2.2900240421295166,boundary:0.00018387011368758976
# At epoch 200, time_speed: 1.28s, Max abs error is: 0.007495880126953125, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.003387374570593238,JU:-1.8910186290740967,boundary:1.0436474440211896e-06
# At epoch 300, time_speed: 1.23s, Max abs error is: 0.0012307167053222656, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0026247806381434202,JU:-2.2050297260284424,boundary:1.2323890814514016e-06
# At epoch 400, time_speed: 1.56s, Max abs error is: 0.0012350082397460938, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.002489920472726226,JU:-1.6086840629577637,boundary:2.6054985937662423e-06
# At epoch 500, time_speed: 1.30s, Max abs error is: 0.002061605453491211, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00265986449085176,JU:-2.2127413749694824,boundary:1.9507720935507677e-05
# At epoch 600, time_speed: 1.22s, Max abs error is: 0.0037096738815307617, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.003538566641509533,JU:-2.462118625640869,boundary:7.128427387215197e-05
# At epoch 700, time_speed: 1.21s, Max abs error is: 0.005540937185287476, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0034014242701232433,JU:-1.8679825067520142,boundary:1.548663135508832e-06
# At epoch 800, time_speed: 1.49s, Max abs error is: 0.001264035701751709, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0021519912406802177,JU:-1.7741265296936035,boundary:0.0009043584577739239
# At epoch 900, time_speed: 1.28s, Max abs error is: 0.01593376323580742, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0018221039790660143,JU:-1.3687782287597656,boundary:9.427369604964042e-07
# At epoch 1000, time_speed: 1.30s, Max abs error is: 0.0012049078941345215, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 217 steps:
# Epoch 100: pde_loss=0.002897839294746518, JU_loss=-1.9838004112243652, boundary_loss=5.2285275160102174e-05
# At epoch 100, time_speed: 6470.08s, Max abs error is: 0.00465315580368042, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.0033857214730232954, JU_loss=-1.8876888751983643, boundary_loss=0.00011193138197995722
# At epoch 200, time_speed: 1.33s, Max abs error is: 0.006182253360748291, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.003266658866778016, JU_loss=-2.301145553588867, boundary_loss=1.465812420065049e-05
# At epoch 300, time_speed: 1.29s, Max abs error is: 0.002481672912836075, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.0028085876256227493, JU_loss=-2.7773654460906982, boundary_loss=1.1712510286088218e-06
# At epoch 400, time_speed: 1.28s, Max abs error is: 0.0013721883296966553, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.003426696639508009, JU_loss=-3.2125277519226074, boundary_loss=5.507673449756112e-06
# At epoch 500, time_speed: 1.23s, Max abs error is: 0.0021194361615926027, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.00350013910792768, JU_loss=-1.7876877784729004, boundary_loss=2.9126879326213384e-06
# At epoch 600, time_speed: 1.38s, Max abs error is: 0.002539936453104019, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.003714856458827853, JU_loss=-2.3938894271850586, boundary_loss=4.708660708274692e-05
# At epoch 700, time_speed: 1.22s, Max abs error is: 0.004113197326660156, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.002775982953608036, JU_loss=-3.156503200531006, boundary_loss=3.5583034332375973e-05
# At epoch 800, time_speed: 1.28s, Max abs error is: 0.0036610066890716553, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.0023770921397954226, JU_loss=-2.536496877670288, boundary_loss=6.8201302383386064e-06
# At epoch 900, time_speed: 1.59s, Max abs error is: 0.0025013089179992676, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.003547741798684001, JU_loss=-1.9475479125976562, boundary_loss=8.792463631834835e-06
# At epoch 1000, time_speed: 1.30s, Max abs error is: 0.0031598806381225586, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.0025850851088762283,JU:-3.0714221000671387,boundary:5.8796424127649516e-05
# At epoch 100, time_speed: 6483.27s, Max abs error is: 0.0043678879737854, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.001998252933844924,JU:-1.7489402294158936,boundary:1.6626545402687043e-05
# At epoch 200, time_speed: 1.22s, Max abs error is: 0.0036086738109588623, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.002396938158199191,JU:-2.791456937789917,boundary:0.00018582434859126806
# At epoch 300, time_speed: 1.37s, Max abs error is: 0.00924437865614891, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.002299034036695957,JU:-3.141728401184082,boundary:1.6041482012951747e-05
# At epoch 400, time_speed: 1.31s, Max abs error is: 0.0033933520317077637, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0015902315499261022,JU:-2.6109979152679443,boundary:1.4392162484000437e-06
# At epoch 500, time_speed: 1.23s, Max abs error is: 0.0020567774772644043, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0023190616630017757,JU:-1.697837471961975,boundary:1.439871539332671e-06
# At epoch 600, time_speed: 1.27s, Max abs error is: 0.0015578269958496094, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0024078551214188337,JU:-2.1856653690338135,boundary:0.000611691502854228
# At epoch 700, time_speed: 1.59s, Max abs error is: 0.013021266087889671, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.002759141381829977,JU:-2.392591714859009,boundary:2.2866650397190824e-05
# At epoch 800, time_speed: 1.21s, Max abs error is: 0.0037782900035381317, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0021722898818552494,JU:-2.0596392154693604,boundary:2.0615823359548813e-06
# At epoch 900, time_speed: 1.30s, Max abs error is: 0.0020534396171569824, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.002421111101284623,JU:-3.0706090927124023,boundary:0.00030152511317282915
# At epoch 1000, time_speed: 1.21s, Max abs error is: 0.009667754173278809, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 218 steps:
# Epoch 100: pde_loss=0.0030605699867010117, JU_loss=-1.8542506694793701, boundary_loss=0.00024497488630004227
# At epoch 100, time_speed: 6496.30s, Max abs error is: 0.009548783302307129, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.0023948578163981438, JU_loss=-1.899653673171997, boundary_loss=2.209234708061558e-06
# At epoch 200, time_speed: 1.20s, Max abs error is: 0.001506716012954712, best: 0.0009773366618901491
# -----------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 19
#      17 for step in range(steps):
#      18     print(f"start to the {step} steps:")
# ---> 19     xy_values, u_values, maxerror = train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time)
#      20     # if maxerror < 0.001:
#      21     #     end_time = time.time()
#      22     #     print(f"迭代停止步数为：{step+1},时间为：{end_time-start_time}")
#      23     #     break
#      24     print("*************************************************************train domain 1 finish, start to train domain 2*************************************************************")
#
# Cell In[16], line 7, in train1(change_weight, weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time, xy_values, u_values)
#       4 opt.zero_grad()
#       6 # 计算各个损失函数并获取点
# ----> 7 pde_loss, llos_pde, x_pde, y_pde = l_pde_1(u)
#       8 JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_1(u)
#       9 ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_1(u)
#
# Cell In[15], line 29, in l_pde_1(u, n, device)
#      26 uxy = u(torch.cat([x, y], dim=1))
#      28 # 确保梯度计算返回每个点的值
# ---> 29 grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
#      30 grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度
#      32 # 计算每个点的损失
#
# Cell In[5], line 13, in gradients(u, x, order)
#       9     return torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u),
#      10                                create_graph=True,
#      11                                only_inputs=True, )[0]
#      12 else:
# ---> 13     return gradients(gradients(u, x), x, order=order - 1)
#
# Cell In[5], line 9, in gradients(u, x, order)
#       7 def gradients(u, x, order=1):
#       8     if order == 1:
# ----> 9         return torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u),
#      10                                    create_graph=True,
#      11                                    only_inputs=True, )[0]
#      12     else:
#      13         return gradients(gradients(u, x), x, order=order - 1)
#
# File ~/miniconda3/lib/python3.8/site-packages/torch/autograd/__init__.py:303, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     301     return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     302 else:
# --> 303     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     304         t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     305         allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:
