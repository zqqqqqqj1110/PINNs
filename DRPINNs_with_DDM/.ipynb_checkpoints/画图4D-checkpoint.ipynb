# %%
# !pip install scikit-optimize
# !pip install seaborn

# %%
import torch
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# 设置GPU设备，如果没有可用的GPU，则使用CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

setup_seed(888888)

print(device)
# Out:
# cpu

# %%
# 基础参数
h = 100    # 画图网格密度
N = 1000    # 内点配置点数
N1 = 0.01    # 边界点配置点数
N2 = 1000    # PDE数据点

# %%
class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(2, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.net(x)

# %%
# 定义模型并加载权重
u = MLP().to(device)
u.load_state_dict(torch.load('weights_4D.pth', map_location=device))
u.eval()  # 设置模型为评估模式

# 定义第n象限的网格点
h = 500  # 网格的点数，调整以改变分辨率
xc = torch.linspace(-1, 1, h, device=device)
yc = torch.linspace(-1, 1, h, device=device)
xm, ym = torch.meshgrid(xc, yc)
xx = xm.reshape(-1, 1)
yy = ym.reshape(-1, 1)
xy = torch.cat([xx, yy], dim=1).to(device)

# 使用模型对网格点进行预测
with torch.no_grad():  # 禁用梯度计算，以提高预测速度
    predictions = torch.relu(u(xy))
# Out:
# /root/miniconda3/lib/python3.8/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# 计算解析解
analytical_solution = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy)).to(device)

# 计算绝对误差
absolute_error = torch.abs(predictions - analytical_solution)

# 将预测值、解析解和绝对误差重新整形为网格形状
predictions = predictions.cpu().numpy().reshape(h, h)
analytical_solution = analytical_solution.cpu().numpy().reshape(h, h)
absolute_error = absolute_error.cpu().numpy().reshape(h, h)

# 绘制预测值的3D图形
fig = plt.figure(figsize=(18, 6))

# 预测值图像
ax1 = fig.add_subplot(131, projection='3d')
ax1.plot_surface(xm.cpu().numpy(), ym.cpu().numpy(), predictions, cmap='viridis')
ax1.set_title('Predictions')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Prediction')

# 解析解图像
ax2 = fig.add_subplot(132, projection='3d')
ax2.plot_surface(xm.cpu().numpy(), ym.cpu().numpy(), analytical_solution, cmap='viridis')
ax2.set_title('Analytical Solution')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Solution')

# 绝对误差图像
ax3 = fig.add_subplot(133, projection='3d')
ax3.plot_surface(xm.cpu().numpy(), ym.cpu().numpy(), absolute_error, cmap='viridis')
ax3.set_title('Absolute Error')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
ax3.set_zlabel('Error')

plt.show()

# %%
# 绝对误差图像
fig = plt.figure(figsize=(18, 6))
ax3 = fig.add_subplot(131, projection='3d')
ax3.plot_surface(xm.cpu().numpy(), ym.cpu().numpy(), absolute_error, cmap='viridis')
ax3.set_xlabel('X')
ax3.set_ylabel('Y')
ax3.set_zlabel('Error')

# 保存绝对误差图像
fig.savefig('absolute_error_4domain_3d.png', dpi=300)
plt.clf()  # 清除当前图像以便下次绘制

plt.show()


# 绘制2D误差图
fig, ax = plt.subplots(figsize=(8, 6))
c = ax.imshow(absolute_error, extent=[1, 0, -1, 0], origin='lower', cmap='viridis')
fig.colorbar(c, ax=ax)
ax.set_xlabel('X')
ax.set_ylabel('Y')

# 保存2D误差图像
fig.savefig('absolute_error_4domain_2d.png', dpi=300)
plt.show()

# %% [markdown]
# ## 第一象限

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

# 使用模型对网格点进行预测
with torch.no_grad():
    predictions = torch.relu(u(xy))  # 仍是 PyTorch Tensor

# 计算解析解
analytical_solution = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy)).to(device)

# 计算误差
absolute_error_tensor = torch.abs(predictions - analytical_solution)

# 转换为 NumPy 数组以便绘图
error_array = absolute_error_tensor.cpu().numpy().reshape(h, h)

# **选取 (x, y) ∈ (-0.05, 1) × (0,1) 的区域**
xcoords = xc.cpu().numpy()  # 获取 x 坐标
ycoords = yc.cpu().numpy()  # 获取 y 坐标
col_idx = np.where(xcoords >= -0.05)[0]  # 取 x >= -0.05 的索引
row_idx = np.where(ycoords >= 0)[0]  # 取 y >= 0 的索引

# **筛选数据**
masked_error_region = np.full_like(error_array, np.nan)  # 初始化为 NaN
masked_error_region[np.ix_(row_idx, col_idx)] = error_array[np.ix_(row_idx, col_idx)]  # 保留目标区域的数据

# **找到最大误差值**
max_error = np.nanmax(np.abs(masked_error_region))

### **绘制误差分布图**
fig, ax = plt.subplots(figsize=(6, 5))

im = ax.imshow(
    masked_error_region,
    extent=[-1, 1, -1, 1],
    origin='lower',
    cmap='Reds',  # 颜色映射
    aspect='auto',
    norm=Normalize(vmin=0, vmax=max_error)  # 仅显示正误差
)

# **添加分界线**
ax.axvline(-0.05, color='k', linestyle='-', linewidth=1.0)  # x = -0.05
ax.axhline(0, color='k', linestyle='-', linewidth=1.0)  # y = 0

# **颜色条**
cbar = fig.colorbar(im, ax=ax, shrink=0.8)

# **调整坐标轴标签**
ax.set_xticks([-0.05, 0.5, 1])
ax.set_xticklabels(['-0.05', '0.5', '1'])
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels(['0', '0.5', '1'])

# **保存并展示图像**
plt.savefig("region1_absolute_error.png", dpi=300)
plt.show()

# %% [markdown]
# ## 第二象限

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

# 使用模型对网格点进行预测
with torch.no_grad():
    predictions = torch.relu(u(xy))  # 仍是 PyTorch Tensor

# 计算解析解
analytical_solution = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy)).to(device)

# 计算误差
absolute_error_tensor = torch.abs(predictions - analytical_solution)

# 转换为 NumPy 数组以便绘图
error_array = absolute_error_tensor.cpu().numpy().reshape(h, h)

# **选取 (x, y) ∈ (-1, 0) × (-0.05,1) 的区域**
xcoords = xc.cpu().numpy()  # 获取 x 坐标
ycoords = yc.cpu().numpy()  # 获取 y 坐标
col_idx = np.where(xcoords < 0)[0]  # 取 x < 0 的索引
row_idx = np.where(ycoords >= -0.05)[0]  # 取 y >= -0.05 的索引

# **筛选数据**
masked_error_region = np.full_like(error_array, np.nan)  # 初始化为 NaN
masked_error_region[np.ix_(row_idx, col_idx)] = error_array[np.ix_(row_idx, col_idx)]  # 保留目标区域的数据

# **找到最大误差值**
max_error = np.nanmax(np.abs(masked_error_region))

### **绘制误差分布图（蓝色）**
fig, ax = plt.subplots(figsize=(6, 5))

im = ax.imshow(
    masked_error_region,
    extent=[-1, 1, -1, 1],
    origin='lower',
    cmap='Blues',  # 只使用蓝色
    aspect='auto',
    norm=Normalize(vmin=0, vmax=max_error)  # 仅显示正误差
)

# **添加分界线**
ax.axvline(0, color='k', linestyle='-', linewidth=1.0)  # x = 0
ax.axhline(-0.05, color='k', linestyle='-', linewidth=1.0)  # y = -0.05

# **颜色条**
cbar = fig.colorbar(im, ax=ax, shrink=0.8)

# **调整坐标轴标签**
ax.set_xticks([-1, -0.5, 0])
ax.set_xticklabels(['-1', '-0.5', '0'])
ax.set_yticks([-0.05, 0.5, 1])
ax.set_yticklabels(['-0.05', '0.5', '1'])

# **保存并展示图像**
plt.savefig("region2_absolute_error.png", dpi=300)
plt.show()

# %% [markdown]
# ## 第三象限

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

# 使用模型对网格点进行预测
with torch.no_grad():
    predictions = torch.relu(u(xy))  # 仍是 PyTorch Tensor

# 计算解析解
analytical_solution = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy)).to(device)

# 计算误差
absolute_error_tensor = torch.abs(predictions - analytical_solution)

# 转换为 NumPy 数组以便绘图
error_array = absolute_error_tensor.cpu().numpy().reshape(h, h)

# **选取 (x, y) ∈ (-1, 0.05) × (-1,0) 的区域**
xcoords = xc.cpu().numpy()  # 获取 x 坐标
ycoords = yc.cpu().numpy()  # 获取 y 坐标
col_idx = np.where(xcoords < 0.05)[0]  # 取 x < 0.05 的索引
row_idx = np.where(ycoords < 0)[0]  # 取 y < 0 的索引

# **筛选数据**
masked_error_region = np.full_like(error_array, np.nan)  # 初始化为 NaN
masked_error_region[np.ix_(row_idx, col_idx)] = error_array[np.ix_(row_idx, col_idx)]  # 保留目标区域的数据

# **找到最大误差值**
max_error = np.nanmax(np.abs(masked_error_region))

### **绘制误差分布图（紫色）**
fig, ax = plt.subplots(figsize=(6, 5))

im = ax.imshow(
    masked_error_region,
    extent=[-1, 1, -1, 1],
    origin='lower',
    cmap='Purples',  # 只使用紫色
    aspect='auto',
    norm=Normalize(vmin=0, vmax=max_error)  # 仅显示正误差
)

# **添加分界线**
ax.axvline(0.05, color='k', linestyle='-', linewidth=1.0)  # x = 0.05
ax.axhline(0, color='k', linestyle='-', linewidth=1.0)  # y = 0

# **颜色条**
cbar = fig.colorbar(im, ax=ax, shrink=0.8)

# **调整坐标轴标签**
ax.set_xticks([-1, -0.5, 0, 0.05])
ax.set_xticklabels(['-1', '-0.5', '0', '0.05'])
ax.set_yticks([-1, -0.5, 0])
ax.set_yticklabels(['-1', '-0.5', '0'])

# **保存并展示图像**
plt.savefig("region3_absolute_error.png", dpi=300)
plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

# 使用模型对网格点进行预测
with torch.no_grad():
    predictions = torch.relu(u(xy))  # 仍是 PyTorch Tensor

# 计算解析解
analytical_solution = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy)).to(device)

# 计算误差
absolute_error_tensor = torch.abs(predictions - analytical_solution)

# 转换为 NumPy 数组以便绘图
error_array = absolute_error_tensor.cpu().numpy().reshape(h, h)

# **选取 (x, y) ∈ (0,1) × (-1,0.05) 的区域**
xcoords = xc.cpu().numpy()  # 获取 x 坐标
ycoords = yc.cpu().numpy()  # 获取 y 坐标
col_idx = np.where(xcoords >= 0)[0]  # 取 x >= 0 的索引
row_idx = np.where(ycoords < 0.05)[0]  # 取 y < 0.05 的索引

# **筛选数据**
masked_error_region = np.full_like(error_array, np.nan)  # 初始化为 NaN
masked_error_region[np.ix_(row_idx, col_idx)] = error_array[np.ix_(row_idx, col_idx)]  # 保留目标区域的数据

# **找到最大误差值**
max_error = np.nanmax(np.abs(masked_error_region))

### **绘制误差分布图（橙色）**
fig, ax = plt.subplots(figsize=(6, 5))

im = ax.imshow(
    masked_error_region,
    extent=[-1, 1, -1, 1],
    origin='lower',
    cmap='Oranges',  # 只使用橙色
    aspect='auto',
    norm=Normalize(vmin=0, vmax=max_error)  # 仅显示正误差
)

# **添加分界线**
ax.axvline(0, color='k', linestyle='-', linewidth=1.0)  # x = 0
ax.axhline(0.05, color='k', linestyle='-', linewidth=1.0)  # y = 0.05

# **颜色条**
cbar = fig.colorbar(im, ax=ax, shrink=0.8)

# **调整坐标轴标签**
ax.set_xticks([0, 0.5, 1])
ax.set_xticklabels(['0', '0.5', '1'])
ax.set_yticks([-1, -0.5, 0, 0.05])
ax.set_yticklabels(['-1', '-0.5', '0', '0.05'])

# **保存并展示图像**
plt.savefig("region4_absolute_error.png", dpi=300)
plt.show()
