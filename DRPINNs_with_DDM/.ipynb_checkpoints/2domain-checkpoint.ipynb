# %%
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
import torch.nn.functional as F
from skopt import BayesSearchCV
from skopt.space import Real
from skopt import gp_minimize
import torch.nn as nn
import seaborn as sns
from scipy.optimize import minimize
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import matplotlib as mpl
from skopt.utils import use_named_args
from tqdm import tqdm
import multiprocessing
import threading

# %%
# 设置GPU设备，如果没有可用的GPU，则使用CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def setup_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

setup_seed(888888)

print(device)
# Out:
# cpu

# %%
# 基础参数
epochs = 400000    # 训练代数
h = 100    # 画图网格密度
N = 100    # 内点配置点数
N1 = 0.01    # 边界点配置点数
n = 1000    # PDE数据点
top_k = 100  # 前n个残差最大的点
num_new_points = 10  # 以圆心生成的n个点
bias = 0.001   # 圆半径

# %%
class MLP(torch.nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.net = torch.nn.Sequential(
            torch.nn.Linear(2, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 32),
            torch.nn.Tanh(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, x):
        return self.net(x)

# %%
# Loss
loss = torch.nn.MSELoss()
# loss = torch.nn.L1Loss()  #MAE
# loss = torch.nn.SmoothL1Loss(beta=1.0)

# 递归求导
def gradients(u, x, order=1):
    if order == 1:
        return torch.autograd.grad(u, x, grad_outputs=torch.ones_like(u),
                                   create_graph=True,
                                   only_inputs=True, )[0]
    else:
        return gradients(gradients(u, x), x, order=order - 1)

# %% [markdown]
# # 区域1（0-0.6）

# %%
def point_1(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True) * 0.6
    y = torch.rand(n, 1, device=device, requires_grad=True)
    return x, y


def l_ugeq_1(u, n=100):
    # u >= 0
    x, y = point_1(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_1(u, n=100, device=device):
    # 等式项损失
    x, y = point_1(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_1(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_1(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %% [markdown]
# # 区域2（0.4-1）

# %%
def point_2(n=100, device=device):
    x = torch.rand(n, 1, device=device, requires_grad=True) * 0.6 + 0.4
    y = torch.rand(n, 1, device=device, requires_grad=True)
    return x, y


def l_ugeq_2(u, n=100):
    # u >= 0
    x, y = point_2(n, device)
    cond = torch.zeros_like(y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    llos = torch.relu(-uxy)
    ugeq_loss = 100 * torch.sum(llos)
    
    # 返回每个点的损失值
    return ugeq_loss, llos, x, y

def l_pde_2(u, n=100, device=device):
    # 等式项损失
    x, y = point_2(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)
    
    # 计算损失
    uxy = u(torch.cat([x, y], dim=1))
    
    # 确保梯度计算返回每个点的值
    grad_x2 = gradients(uxy, x, 2)  # 对 x 计算二阶梯度
    grad_y2 = gradients(uxy, y, 2)  # 对 y 计算二阶梯度

    # 计算每个点的损失
    loss_value = -grad_x2 - grad_y2  # 假设这里是 PDE 中的计算
    loss_value = loss_value - cond   # 计算 PDE 的残差
    pde_loss = loss(-gradients(uxy, x, 2) - gradients(uxy, y, 2)- cond, torch.zeros_like(cond))

    # 返回每个点的损失值
    return pde_loss, loss_value, x, y

def l_JU_2(u, n=100, device=device):
    """
    计算每个点的 JU 损失值和整体的 JU 损失（通过蒙特卡罗积分近似）
    
    参数：
    - u: 神经网络
    - n: 采样点的数量
    - device: 设备（"cuda" 或 "cpu"）
    
    返回：
    - JU_loss: 总的目标函数值（通过积分近似）
    - llos_JU: 每个点的损失值（对应每个采样点）
    - x, y: 对应每个点的坐标
    """
    # 随机采样点
    x, y = point_2(n, device)
    cond = 2 * torch.pi**2 * torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

    # 计算 u 和其梯度
    uxy = u(torch.cat([x, y], dim=1))
    grad_x = gradients(uxy, x, 1)
    grad_y = gradients(uxy, y, 1)
    
    # 每个点的损失值
    llos_JU = 0.5 * (grad_x**2 + grad_y**2) - cond * uxy  # 每个点对应的损失值
    p1 = 0.5 * (grad_x**2 + grad_y**2)
    p2 = cond * uxy

    # 使用蒙特卡罗积分近似整体损失
    JU_loss = llos_JU.mean()  # 取所有点的平均值作为积分的近似

    return JU_loss, llos_JU, x, y, p1, p2

# %%
# 边界函数构建
def l_boundary1(u): # 上边界
    # 取点
    x = torch.arange(0, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = torch.ones_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    # 计算
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary2(u):  # 右边界
    # 取点
    y = torch.arange(0, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = torch.ones_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    # 计算
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary3(u):  # 左边界
    # 取点
    y = torch.arange(0, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    x = torch.zeros_like(y, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    # 计算
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

def l_boundary4(u):  # 下边界
    # 取点
    x = torch.arange(0, 1.001, N1, device=device, requires_grad=True).view(-1, 1)
    y = torch.zeros_like(x, device=device, requires_grad=True)
    cond = torch.zeros_like(x, device=device)
    # 计算
    uxy = u(torch.cat([x, y], dim=1))
    return loss(uxy, cond)

# %% [markdown]
# # 查看情况代码

# %%
def record_loss_and_save_model(u, epoch, maxerror, current_time, h, device):
    """
    每100次迭代记录一次损失并保存模型。

    参数:
    - u: 模型
    - epoch: 当前训练的 epoch 数
    - maxerror: 当前最小的误差
    - current_time: 上一次记录的时间
    - h: 网格划分大小
    - device: 设备
    返回:
    - maxerror: 更新后的最小误差
    - current_time: 更新后的时间
    """
    # 生成网格点
    xc_x = torch.linspace(0, 1, h, device=device)
    xc_y = torch.linspace(0, 1, h, device=device)
    xm, ym = torch.meshgrid(xc_x, xc_y)
    xx = xm.reshape(-1, 1)
    yy = ym.reshape(-1, 1)
    xy = torch.cat([xx, yy], dim=1).to(device)

    # 计算预测值和真实值
    u_pred = u(xy)
    u_real = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy))
    u_error = torch.abs(u_pred - u_real)

    # 计算误差网格
    u_pred_fig = u_pred.reshape(h, h)
    u_real_fig = u_real.reshape(h, h)
    u_error_fig = u_error.reshape(h, h)

    # 计算当前最大绝对误差
    max_abs_error = float(torch.max(u_error))
    print(f"At epoch {epoch}, time_speed: {abs(current_time - time.time()):.2f}s, Max abs error is: {max_abs_error}, best: {maxerror}")
    print('-----------------------------------------------------------------------------------------------------------------------')

    # 如果误差更小，则保存模型
    if max_abs_error < maxerror:
        maxerror = max_abs_error
        torch.save(u.state_dict(), 'weights11.pth')

    # 更新当前时间
    current_time = time.time()

    return maxerror, current_time

# %%
def train1(weight_pde, weight_JU, weight_boundary):
    # 计算各个损失函数并获取点
    pde_loss, llos_pde, x_pde, y_pde = l_pde(u)
    JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU(u)
    ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq(u)
    
    inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
    loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u)
    
    # 计算加权总损失
    total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary

# %% [markdown]
# # 区域训练

# %% [markdown]
# ## 区域1（0-0.6）

# %%
def train1(weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch1):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_1(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_1(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_1(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary

        # 区域交换
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)  # 计算神经网络的预测值
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)  # MSE损失
            total_loss += 10000 * boundary_loss  # 给边界损失较大权重
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"Epoch {epoch}: pde_loss={pde_loss.item()}, JU_loss={JU_loss.item()}, boundary_loss={loss_boundary.item()}")
            # 记录 maxerror 并保存模型
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)

        # 反向传播和优化
        total_loss.backward()
        opt.step()
    
    print("\n训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值")

    # **计算 x=0.6 的 u 值**
    y_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1)  # 生成 y=[0, 0.05, ..., 1]
    x_values = torch.full_like(y_values, 0.6)  # 创建 x=0.6 的列向量
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)  # 拼接 (x,y)

    # **用 u 计算这些点的值**
    u_values = u(xy_values).detach().cpu().numpy()

    # # **打印结果**
    # print("\n计算结果 (x=0.6, y, u(x,y)):")
    # for y_val, u_val in zip(y_values.cpu().numpy(), u_values):
    #     print(f"x=0.6, y={y_val[0]:.2f}, u={u_val[0]:.6f}")

    return xy_values, u_values, maxerror  # 返回这些点用于区域2训练

# %% [markdown]
# ## 区域2（0.4-1）

# %%
def train2(weight_pde, weight_JU, weight_boundary, epoch2, opt, u, maxerror, current_time, xy_values=None, u_values=None):
    
    for epoch in range(epoch2):
        opt.zero_grad()
    
        # 计算各个损失函数并获取点
        pde_loss, llos_pde, x_pde, y_pde = l_pde_2(u)
        JU_loss, llos_JU, x_JU, y_JU, p1, p2 = l_JU_2(u)
        ugeq_loss, llos_ugeq, x_ugeq, y_ugeq = l_ugeq_2(u)
    
        inside_loss = weight_pde * llos_pde + weight_JU * llos_JU + 6000 * llos_ugeq
        loss_boundary = l_boundary1(u) +  l_boundary2(u) + l_boundary3(u) + l_boundary4(u)
    
        # 计算加权总损失
        total_loss = weight_pde * pde_loss + weight_JU * JU_loss + 600 * ugeq_loss + weight_boundary * loss_boundary
        
        # **如果传入了 xy_values 和 u_values，添加它们作为边界条件
        if xy_values is not None and u_values is not None:
            u_pred_boundary = u(xy_values)  # 计算神经网络的预测值
            boundary_loss = torch.mean((u_pred_boundary - torch.tensor(u_values, device=xy_values.device))**2)  # MSE损失
            total_loss += 10000 * boundary_loss  # 给边界损失较大权重
        # 每100次迭代记录一次损失
        if epoch % 100 == 0 and epoch != 0:
            print(f"pde:{pde_loss.item()},JU:{JU_loss.item()},boundary:{loss_boundary.item()}")
            maxerror, current_time = record_loss_and_save_model(u, epoch, maxerror, current_time, h, device)
        
        # if epoch % 100000 == 0 and epoch != 0:
        #     X, Y = update_dataset(X, Y, inside_loss, x_pde, y_pde, top_k, num_new_points, bias, device)
    
        # 反向传播和优化
        total_loss.backward()
        opt.step()
    
    print("\n训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值")

    # **计算 x=0.4 的 u 值**
    y_values = torch.arange(0, 1.05, 0.05, device=device).unsqueeze(1)  # 生成 y=[0, 0.05, ..., 1]
    x_values = torch.full_like(y_values, 0.4)  # 创建 x=0.4 的列向量
    xy_values = torch.cat([x_values, y_values], dim=1).to(device)  # 拼接 (x,y)

    # **用 u 计算这些点的值**
    u_values = u(xy_values).detach().cpu().numpy()

    # # **打印结果**
    # print("\n计算结果 (x=0.4, y, u(x,y)):")
    # for y_val, u_val in zip(y_values.cpu().numpy(), u_values):
    #     print(f"x=0.6, y={y_val[0]:.2f}, u={u_val[0]:.6f}")

    return xy_values, u_values, maxerror  # 返回这些点用于区域1训练

# %% [markdown]
# ## 查看情况

# %%
def record_loss_and_save_model(u, epoch, maxerror, current_time, h, device):
    """
    每100次迭代记录一次损失并保存模型。

    参数:
    - u: 模型
    - epoch: 当前训练的 epoch 数
    - maxerror: 当前最小的误差
    - current_time: 上一次记录的时间
    - h: 网格划分大小
    - device: 设备
    返回:
    - maxerror: 更新后的最小误差
    - current_time: 更新后的时间
    """
    # 生成网格点
    xc_x = torch.linspace(0, 1, h, device=device)
    xc_y = torch.linspace(0, 1, h, device=device)
    xm, ym = torch.meshgrid(xc_x, xc_y)
    xx = xm.reshape(-1, 1)
    yy = ym.reshape(-1, 1)
    xy = torch.cat([xx, yy], dim=1).to(device)

    # 计算预测值和真实值
    u_pred = u(xy)
    u_real = torch.relu(torch.sin(torch.pi * xx) * torch.sin(torch.pi * yy))
    u_error = torch.abs(u_pred - u_real)

    # 计算误差网格
    u_pred_fig = u_pred.reshape(h, h)
    u_real_fig = u_real.reshape(h, h)
    u_error_fig = u_error.reshape(h, h)

    # 计算当前最大绝对误差
    max_abs_error = float(torch.max(u_error))
    print(f"At epoch {epoch}, time_speed: {abs(current_time - time.time()):.2f}s, Max abs error is: {max_abs_error}, best: {maxerror}")
    print('-----------------------------------------------------------------------------------------------------------------------')

    # 如果误差更小，则保存模型
    if max_abs_error < maxerror:
        maxerror = max_abs_error
        torch.save(u.state_dict(), 'weights.pth')

    # 更新当前时间
    current_time = time.time()

    return maxerror, current_time

# %% [markdown]
# # 训练

# %%
# Training
u = MLP().to(device)
opt = torch.optim.Adam(params=u.parameters(), lr=0.0001)

# 设置初始权重
weight_pde = 600000
weight_JU = 20000
weight_boundary = 1000000000
current_time = time.time()
maxerror = 99999999999
epoch2 = epoch1 = 1001
steps = 20

for step in range(steps):
    print(f"start to the {step} steps:")
    xy_values, u_values, maxerror = train1(weight_pde, weight_JU, weight_boundary, epoch1, opt, u, maxerror, current_time)
    print("*************************************************************train domain 1 finish, start to train domain 2*************************************************************")
    xy_values, u_values, maxerror = train2(weight_pde, weight_JU, weight_boundary, epoch2, opt, u, maxerror, current_time)
    print("*************************************************************train domain 2 finish, start to train domain 1*************************************************************")

print("                                                                        END TRAINING")
# Out:
# start to the 0 steps:
# Epoch 100: pde_loss=126.56600952148438, JU_loss=-0.0186994019895792, boundary_loss=1.4262944205256645e-05
# At epoch 100, time_speed: 2.74s, Max abs error is: 0.9968642592430115, best: 99999999999
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=102.25338745117188, JU_loss=-0.06656572222709656, boundary_loss=3.066068165935576e-05
# At epoch 200, time_speed: 1.70s, Max abs error is: 0.9894356727600098, best: 0.9968642592430115
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=92.61554718017578, JU_loss=-0.24905642867088318, boundary_loss=0.0002051216142717749
# At epoch 300, time_speed: 1.71s, Max abs error is: 0.9654062986373901, best: 0.9894356727600098
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=68.6989974975586, JU_loss=-0.7762911319732666, boundary_loss=0.0021317012142390013
# At epoch 400, time_speed: 1.68s, Max abs error is: 0.8799808025360107, best: 0.9654062986373901
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=71.31163787841797, JU_loss=-1.4192802906036377, boundary_loss=0.008863760158419609
# At epoch 500, time_speed: 1.70s, Max abs error is: 0.7337669134140015, best: 0.8799808025360107
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=49.197303771972656, JU_loss=-2.139467716217041, boundary_loss=0.012181087397038937
# At epoch 600, time_speed: 1.81s, Max abs error is: 0.6558230519294739, best: 0.7337669134140015
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=50.221641540527344, JU_loss=-2.219494581222534, boundary_loss=0.012911416590213776
# At epoch 700, time_speed: 1.48s, Max abs error is: 0.5785634517669678, best: 0.6558230519294739
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=24.679492950439453, JU_loss=-2.2221922874450684, boundary_loss=0.012125369161367416
# At epoch 800, time_speed: 1.13s, Max abs error is: 0.4514203667640686, best: 0.5785634517669678
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=16.492919921875, JU_loss=-2.4263486862182617, boundary_loss=0.008170033805072308
# At epoch 900, time_speed: 1.20s, Max abs error is: 0.32303565740585327, best: 0.4514203667640686
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=9.272385597229004, JU_loss=-2.6374120712280273, boundary_loss=0.004575470462441444
# At epoch 1000, time_speed: 1.29s, Max abs error is: 0.2513536214828491, best: 0.32303565740585327
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:9.732077598571777,JU:-2.053739309310913,boundary:0.004329761490225792
# At epoch 100, time_speed: 17.53s, Max abs error is: 0.15116918087005615, best: 0.2513536214828491
# -----------------------------------------------------------------------------------------------------------------------
# pde:6.893490791320801,JU:-3.4166901111602783,boundary:0.0028005382046103477
# At epoch 200, time_speed: 1.11s, Max abs error is: 0.18703734874725342, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
# pde:6.59307861328125,JU:-3.6061017513275146,boundary:0.002068482805043459
# At epoch 300, time_speed: 1.10s, Max abs error is: 0.22061151266098022, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
# pde:6.375030994415283,JU:-2.668443202972412,boundary:0.001670518540777266
# At epoch 400, time_speed: 1.51s, Max abs error is: 0.232896625995636, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
# pde:5.371149063110352,JU:-3.3678901195526123,boundary:0.0013796529965475202
# At epoch 500, time_speed: 1.57s, Max abs error is: 0.23137140274047852, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
# pde:5.011000156402588,JU:-3.144341468811035,boundary:0.001169385970570147
# At epoch 600, time_speed: 1.04s, Max abs error is: 0.2235071063041687, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
# pde:3.9964194297790527,JU:-1.8108322620391846,boundary:0.000980342156253755
# At epoch 700, time_speed: 2.78s, Max abs error is: 0.218244731426239, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.8655169010162354,JU:-3.046093702316284,boundary:0.0008480422548018396
# At epoch 800, time_speed: 1.68s, Max abs error is: 0.20984631776809692, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.975029945373535,JU:-2.4921798706054688,boundary:0.0007805674686096609
# At epoch 900, time_speed: 1.71s, Max abs error is: 0.2002962827682495, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
# pde:2.8256375789642334,JU:-2.5018222332000732,boundary:0.0006974617135711014
# At epoch 1000, time_speed: 1.91s, Max abs error is: 0.19406664371490479, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 1 steps:
# Epoch 100: pde_loss=4.607194423675537, JU_loss=-2.422642707824707, boundary_loss=0.0008759624324738979
# At epoch 100, time_speed: 33.31s, Max abs error is: 0.09642612934112549, best: 0.15116918087005615
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=3.780665636062622, JU_loss=-3.541337013244629, boundary_loss=0.0006759848911315203
# At epoch 200, time_speed: 1.10s, Max abs error is: 0.12273430824279785, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=2.306734085083008, JU_loss=-3.4867148399353027, boundary_loss=0.0005791895091533661
# At epoch 300, time_speed: 1.13s, Max abs error is: 0.13389217853546143, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=1.8248344659805298, JU_loss=-2.2289834022521973, boundary_loss=0.0005234383279457688
# At epoch 400, time_speed: 1.17s, Max abs error is: 0.1401817798614502, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=2.2440590858459473, JU_loss=-2.342951536178589, boundary_loss=0.00046915386337786913
# At epoch 500, time_speed: 1.10s, Max abs error is: 0.14041614532470703, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=1.367790937423706, JU_loss=-3.263352155685425, boundary_loss=0.0004312012461014092
# At epoch 600, time_speed: 1.09s, Max abs error is: 0.14025098085403442, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=1.648820400238037, JU_loss=-3.358983039855957, boundary_loss=0.00039365864358842373
# At epoch 700, time_speed: 1.40s, Max abs error is: 0.144727885723114, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=1.5180637836456299, JU_loss=-2.4913651943206787, boundary_loss=0.0003586678358260542
# At epoch 800, time_speed: 2.00s, Max abs error is: 0.13965672254562378, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=1.4056766033172607, JU_loss=-2.3486411571502686, boundary_loss=0.0003159718180540949
# At epoch 900, time_speed: 1.70s, Max abs error is: 0.14110881090164185, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.9062609076499939, JU_loss=-2.732539653778076, boundary_loss=0.00029168222681619227
# At epoch 1000, time_speed: 1.92s, Max abs error is: 0.14247727394104004, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:1.53061842918396,JU:-3.8032138347625732,boundary:0.0004188807506579906
# At epoch 100, time_speed: 47.73s, Max abs error is: 0.08992421627044678, best: 0.09642612934112549
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.5680022239685059,JU:-3.3122241497039795,boundary:0.00033339965739287436
# At epoch 200, time_speed: 1.80s, Max abs error is: 0.09292292594909668, best: 0.08992421627044678
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.8454186916351318,JU:-3.8930230140686035,boundary:0.0003026859776582569
# At epoch 300, time_speed: 1.90s, Max abs error is: 0.08656573295593262, best: 0.08992421627044678
# -----------------------------------------------------------------------------------------------------------------------
# pde:1.1334730386734009,JU:-3.5926544666290283,boundary:0.00026881106896325946
# At epoch 400, time_speed: 2.08s, Max abs error is: 0.0828864574432373, best: 0.08656573295593262
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.7536248564720154,JU:-2.723325729370117,boundary:0.00024790249881334603
# At epoch 500, time_speed: 1.80s, Max abs error is: 0.07942873239517212, best: 0.0828864574432373
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.8585627675056458,JU:-2.9367098808288574,boundary:0.0002223897899966687
# At epoch 600, time_speed: 1.73s, Max abs error is: 0.07302910089492798, best: 0.07942873239517212
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.646594762802124,JU:-2.6183583736419678,boundary:0.0002088675246341154
# At epoch 700, time_speed: 1.70s, Max abs error is: 0.0711355209350586, best: 0.07302910089492798
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.5239452719688416,JU:-3.2594077587127686,boundary:0.00019966693071182817
# At epoch 800, time_speed: 1.73s, Max abs error is: 0.0667223334312439, best: 0.0711355209350586
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.6788871884346008,JU:-2.485971689224243,boundary:0.00024704565294086933
# At epoch 900, time_speed: 1.69s, Max abs error is: 0.06955575942993164, best: 0.0667223334312439
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.5747888684272766,JU:-3.3514716625213623,boundary:0.000183845404535532
# At epoch 1000, time_speed: 1.20s, Max abs error is: 0.06105303764343262, best: 0.0667223334312439
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 2 steps:
# Epoch 100: pde_loss=0.8183343410491943, JU_loss=-2.792675256729126, boundary_loss=0.00016941121430136263
# At epoch 100, time_speed: 64.63s, Max abs error is: 0.03335011005401611, best: 0.06105303764343262
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.5848098397254944, JU_loss=-1.6315709352493286, boundary_loss=0.00014691089745610952
# At epoch 200, time_speed: 1.28s, Max abs error is: 0.04007679224014282, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.8036904335021973, JU_loss=-4.34197473526001, boundary_loss=0.00013356732961256057
# At epoch 300, time_speed: 1.23s, Max abs error is: 0.03855019807815552, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.9009147882461548, JU_loss=-3.4644837379455566, boundary_loss=0.00011760540655814111
# At epoch 400, time_speed: 1.18s, Max abs error is: 0.04142874479293823, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.6026908159255981, JU_loss=-2.796053171157837, boundary_loss=0.00010255671077175066
# At epoch 500, time_speed: 1.12s, Max abs error is: 0.039697110652923584, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.6492905616760254, JU_loss=-3.1752166748046875, boundary_loss=9.132360719377175e-05
# At epoch 600, time_speed: 1.20s, Max abs error is: 0.039881229400634766, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.7109113335609436, JU_loss=-3.516782522201538, boundary_loss=8.402695675613359e-05
# At epoch 700, time_speed: 1.11s, Max abs error is: 0.04058098793029785, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.7009586095809937, JU_loss=-4.379812717437744, boundary_loss=7.96788081061095e-05
# At epoch 800, time_speed: 1.10s, Max abs error is: 0.04403889179229736, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.2929897606372833, JU_loss=-3.694685697555542, boundary_loss=7.135435589589179e-05
# At epoch 900, time_speed: 1.11s, Max abs error is: 0.045063018798828125, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.32318946719169617, JU_loss=-2.422673225402832, boundary_loss=6.704959378112108e-05
# At epoch 1000, time_speed: 1.28s, Max abs error is: 0.04468768835067749, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.39729130268096924,JU:-2.603214740753174,boundary:9.2872760433238e-05
# At epoch 100, time_speed: 76.43s, Max abs error is: 0.033039987087249756, best: 0.03335011005401611
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.38102808594703674,JU:-3.1093761920928955,boundary:7.744953472865745e-05
# At epoch 200, time_speed: 1.21s, Max abs error is: 0.03290235996246338, best: 0.033039987087249756
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.692679226398468,JU:-3.7196505069732666,boundary:8.240780152846128e-05
# At epoch 300, time_speed: 1.11s, Max abs error is: 0.028575539588928223, best: 0.03290235996246338
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.44496220350265503,JU:-4.3985915184021,boundary:7.416724838549271e-05
# At epoch 400, time_speed: 1.03s, Max abs error is: 0.02837425470352173, best: 0.028575539588928223
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.4685739278793335,JU:-3.9408798217773438,boundary:6.649066926911473e-05
# At epoch 500, time_speed: 1.28s, Max abs error is: 0.02208268642425537, best: 0.02837425470352173
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.4208100438117981,JU:-3.2353627681732178,boundary:6.183481309562922e-05
# At epoch 600, time_speed: 1.13s, Max abs error is: 0.02286672592163086, best: 0.02208268642425537
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.3453659415245056,JU:-3.0140082836151123,boundary:7.282001752173528e-05
# At epoch 700, time_speed: 1.17s, Max abs error is: 0.0237276554107666, best: 0.02208268642425537
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.27084195613861084,JU:-4.512907028198242,boundary:4.952195376972668e-05
# At epoch 800, time_speed: 1.09s, Max abs error is: 0.020173877477645874, best: 0.02208268642425537
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.25479692220687866,JU:-2.6669952869415283,boundary:4.5999258873052895e-05
# At epoch 900, time_speed: 1.14s, Max abs error is: 0.019649028778076172, best: 0.020173877477645874
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.23474282026290894,JU:-2.6688451766967773,boundary:5.049707760917954e-05
# At epoch 1000, time_speed: 1.16s, Max abs error is: 0.017773449420928955, best: 0.019649028778076172
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 3 steps:
# Epoch 100: pde_loss=0.3323507606983185, JU_loss=-2.149963617324829, boundary_loss=4.895023084827699e-05
# At epoch 100, time_speed: 88.74s, Max abs error is: 0.013984158635139465, best: 0.017773449420928955
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.24222174286842346, JU_loss=-2.1313321590423584, boundary_loss=4.0038379665929824e-05
# At epoch 200, time_speed: 1.20s, Max abs error is: 0.0144570991396904, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.23435884714126587, JU_loss=-2.4724974632263184, boundary_loss=4.581315442919731e-05
# At epoch 300, time_speed: 1.28s, Max abs error is: 0.014699548482894897, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.23383884131908417, JU_loss=-2.144242286682129, boundary_loss=4.765284393215552e-05
# At epoch 400, time_speed: 1.20s, Max abs error is: 0.016594409942626953, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.35951367020606995, JU_loss=-2.027709484100342, boundary_loss=3.5912631574319676e-05
# At epoch 500, time_speed: 1.11s, Max abs error is: 0.015668153762817383, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.23788665235042572, JU_loss=-2.349029779434204, boundary_loss=3.161012500640936e-05
# At epoch 600, time_speed: 1.12s, Max abs error is: 0.014776676893234253, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.2329496443271637, JU_loss=-3.0355608463287354, boundary_loss=3.1053383281687275e-05
# At epoch 700, time_speed: 1.26s, Max abs error is: 0.015332132577896118, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.1962837278842926, JU_loss=-3.184890031814575, boundary_loss=4.8758694902062416e-05
# At epoch 800, time_speed: 1.14s, Max abs error is: 0.019519895315170288, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.2644176185131073, JU_loss=-3.538625478744507, boundary_loss=2.8255646611796692e-05
# At epoch 900, time_speed: 1.28s, Max abs error is: 0.01667693257331848, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.2024117112159729, JU_loss=-3.325021743774414, boundary_loss=4.355669079814106e-05
# At epoch 1000, time_speed: 1.09s, Max abs error is: 0.01992928981781006, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.47518280148506165,JU:-2.783243179321289,boundary:3.9498765545431525e-05
# At epoch 100, time_speed: 100.55s, Max abs error is: 0.01719251275062561, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.32990673184394836,JU:-3.5790343284606934,boundary:3.35092336172238e-05
# At epoch 200, time_speed: 1.19s, Max abs error is: 0.016395211219787598, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.33049309253692627,JU:-4.319615364074707,boundary:3.2400479540228844e-05
# At epoch 300, time_speed: 1.18s, Max abs error is: 0.017343670129776, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.32185906171798706,JU:-4.006037712097168,boundary:3.0223185603972524e-05
# At epoch 400, time_speed: 1.12s, Max abs error is: 0.015191137790679932, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.16706188023090363,JU:-3.3274528980255127,boundary:2.522175054764375e-05
# At epoch 500, time_speed: 1.12s, Max abs error is: 0.016638368368148804, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.2710329592227936,JU:-3.080254554748535,boundary:2.267136915179435e-05
# At epoch 600, time_speed: 1.28s, Max abs error is: 0.01500210165977478, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.2132481336593628,JU:-3.4329869747161865,boundary:2.3337190214078873e-05
# At epoch 700, time_speed: 1.12s, Max abs error is: 0.015519022941589355, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.20538808405399323,JU:-2.668832778930664,boundary:1.9679884644574486e-05
# At epoch 800, time_speed: 1.30s, Max abs error is: 0.016303598880767822, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.22376114130020142,JU:-3.9557383060455322,boundary:2.028690869337879e-05
# At epoch 900, time_speed: 1.21s, Max abs error is: 0.014009684324264526, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.33709651231765747,JU:-2.9423820972442627,boundary:2.1328291040845215e-05
# At epoch 1000, time_speed: 1.21s, Max abs error is: 0.01656097173690796, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 4 steps:
# Epoch 100: pde_loss=0.344695121049881, JU_loss=-2.429300308227539, boundary_loss=2.396011768723838e-05
# At epoch 100, time_speed: 112.44s, Max abs error is: 0.010836146771907806, best: 0.013984158635139465
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.254757821559906, JU_loss=-4.0107927322387695, boundary_loss=2.6946343496092595e-05
# At epoch 200, time_speed: 1.19s, Max abs error is: 0.010084003210067749, best: 0.010836146771907806
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.2789122760295868, JU_loss=-3.610647201538086, boundary_loss=2.0730745745822787e-05
# At epoch 300, time_speed: 1.12s, Max abs error is: 0.010870605707168579, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.18009254336357117, JU_loss=-3.316150426864624, boundary_loss=1.880721356428694e-05
# At epoch 400, time_speed: 1.28s, Max abs error is: 0.011339813470840454, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.305968314409256, JU_loss=-3.6298656463623047, boundary_loss=2.068892899842467e-05
# At epoch 500, time_speed: 1.19s, Max abs error is: 0.012402325868606567, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.2153974026441574, JU_loss=-2.875673294067383, boundary_loss=2.0992292775190435e-05
# At epoch 600, time_speed: 1.12s, Max abs error is: 0.012760162353515625, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.1508159041404724, JU_loss=-2.816410779953003, boundary_loss=1.6784892068244517e-05
# At epoch 700, time_speed: 1.37s, Max abs error is: 0.012283772230148315, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.22935444116592407, JU_loss=-3.0431041717529297, boundary_loss=1.7410595319233835e-05
# At epoch 800, time_speed: 1.21s, Max abs error is: 0.013155996799468994, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.23845906555652618, JU_loss=-3.230381488800049, boundary_loss=1.6541467630304396e-05
# At epoch 900, time_speed: 1.19s, Max abs error is: 0.013503104448318481, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.16014857590198517, JU_loss=-2.9028384685516357, boundary_loss=1.5195952073554508e-05
# At epoch 1000, time_speed: 1.12s, Max abs error is: 0.013734102249145508, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.2255147099494934,JU:-3.614584445953369,boundary:2.3021682864055037e-05
# At epoch 100, time_speed: 124.42s, Max abs error is: 0.013176798820495605, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.16415652632713318,JU:-2.7070178985595703,boundary:2.0808227418456227e-05
# At epoch 200, time_speed: 1.23s, Max abs error is: 0.014913350343704224, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.2748510241508484,JU:-2.2953107357025146,boundary:2.1404748622444458e-05
# At epoch 300, time_speed: 1.27s, Max abs error is: 0.012623816728591919, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.21198134124279022,JU:-3.538633346557617,boundary:2.177628266508691e-05
# At epoch 400, time_speed: 1.21s, Max abs error is: 0.012658089399337769, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.21575836837291718,JU:-2.3886306285858154,boundary:1.7860127627500333e-05
# At epoch 500, time_speed: 1.30s, Max abs error is: 0.012455910444259644, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.17685478925704956,JU:-2.3813352584838867,boundary:1.6635609426884912e-05
# At epoch 600, time_speed: 1.19s, Max abs error is: 0.012403160333633423, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.17044076323509216,JU:-3.6204400062561035,boundary:2.988686173921451e-05
# At epoch 700, time_speed: 1.18s, Max abs error is: 0.011172711849212646, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.29130804538726807,JU:-3.8995742797851562,boundary:1.3275126548251137e-05
# At epoch 800, time_speed: 1.14s, Max abs error is: 0.01425844430923462, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.16420312225818634,JU:-2.443669319152832,boundary:1.0523574928811286e-05
# At epoch 900, time_speed: 1.17s, Max abs error is: 0.012962520122528076, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.18835094571113586,JU:-3.4879369735717773,boundary:1.1552397154446226e-05
# At epoch 1000, time_speed: 1.20s, Max abs error is: 0.013616174459457397, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 5 steps:
# Epoch 100: pde_loss=0.1933736801147461, JU_loss=-2.550778865814209, boundary_loss=1.5690040527260862e-05
# At epoch 100, time_speed: 136.53s, Max abs error is: 0.00921611487865448, best: 0.010084003210067749
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.19933277368545532, JU_loss=-3.069790840148926, boundary_loss=1.484749373048544e-05
# At epoch 200, time_speed: 1.20s, Max abs error is: 0.009366512298583984, best: 0.00921611487865448
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.13306647539138794, JU_loss=-2.873772621154785, boundary_loss=2.3811264327378012e-05
# At epoch 300, time_speed: 1.12s, Max abs error is: 0.007992923259735107, best: 0.00921611487865448
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.10434871912002563, JU_loss=-1.8162657022476196, boundary_loss=1.787122164387256e-05
# At epoch 400, time_speed: 1.21s, Max abs error is: 0.011799722909927368, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.12170688807964325, JU_loss=-3.9266059398651123, boundary_loss=1.2829445040551946e-05
# At epoch 500, time_speed: 1.21s, Max abs error is: 0.011505812406539917, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.11066998541355133, JU_loss=-2.652305841445923, boundary_loss=1.2396169950079639e-05
# At epoch 600, time_speed: 1.31s, Max abs error is: 0.011673539876937866, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.12502963840961456, JU_loss=-2.9888741970062256, boundary_loss=1.925535616464913e-05
# At epoch 700, time_speed: 1.68s, Max abs error is: 0.00985834002494812, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.15894536674022675, JU_loss=-2.335538387298584, boundary_loss=1.1881362297572196e-05
# At epoch 800, time_speed: 1.52s, Max abs error is: 0.011211395263671875, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.08477360755205154, JU_loss=-1.685671329498291, boundary_loss=9.252518793800846e-05
# At epoch 900, time_speed: 1.27s, Max abs error is: 0.017203480005264282, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.08925972133874893, JU_loss=-3.744863986968994, boundary_loss=1.1583885680011008e-05
# At epoch 1000, time_speed: 1.19s, Max abs error is: 0.012812376022338867, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.1614394187927246,JU:-2.7890524864196777,boundary:2.0307790691731498e-05
# At epoch 100, time_speed: 149.71s, Max abs error is: 0.010634750127792358, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.1474803388118744,JU:-3.6146018505096436,boundary:1.3102831871947274e-05
# At epoch 200, time_speed: 1.23s, Max abs error is: 0.011912941932678223, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.15844163298606873,JU:-2.9140210151672363,boundary:1.141762641054811e-05
# At epoch 300, time_speed: 1.28s, Max abs error is: 0.013084828853607178, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.26798567175865173,JU:-3.298341751098633,boundary:1.808372871892061e-05
# At epoch 400, time_speed: 1.20s, Max abs error is: 0.010404139757156372, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.13360577821731567,JU:-3.491422653198242,boundary:6.497535650851205e-05
# At epoch 500, time_speed: 1.19s, Max abs error is: 0.00786331295967102, best: 0.007992923259735107
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.10318323969841003,JU:-2.7417232990264893,boundary:8.403434549109079e-06
# At epoch 600, time_speed: 1.23s, Max abs error is: 0.012544304132461548, best: 0.00786331295967102
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.07977786660194397,JU:-3.095705270767212,boundary:8.07838932814775e-06
# At epoch 700, time_speed: 1.20s, Max abs error is: 0.012069493532180786, best: 0.00786331295967102
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.15931853652000427,JU:-2.523996353149414,boundary:8.410244845435955e-06
# At epoch 800, time_speed: 1.20s, Max abs error is: 0.011015892028808594, best: 0.00786331295967102
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.07937708497047424,JU:-3.624541997909546,boundary:6.980067610129481e-06
# At epoch 900, time_speed: 1.12s, Max abs error is: 0.012086451053619385, best: 0.00786331295967102
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.16941261291503906,JU:-3.6410205364227295,boundary:1.5062310012581293e-05
# At epoch 1000, time_speed: 1.39s, Max abs error is: 0.013889491558074951, best: 0.00786331295967102
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 6 steps:
# Epoch 100: pde_loss=0.16339439153671265, JU_loss=-3.4639296531677246, boundary_loss=1.5000612620497122e-05
# At epoch 100, time_speed: 161.95s, Max abs error is: 0.009296178817749023, best: 0.00786331295967102
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.12692822515964508, JU_loss=-3.4135913848876953, boundary_loss=2.1111080059199594e-05
# At epoch 200, time_speed: 1.21s, Max abs error is: 0.006201028823852539, best: 0.00786331295967102
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.10378383845090866, JU_loss=-2.9844930171966553, boundary_loss=1.1699077731464058e-05
# At epoch 300, time_speed: 1.12s, Max abs error is: 0.009884536266326904, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.09400593489408493, JU_loss=-2.714184045791626, boundary_loss=9.319573109678458e-06
# At epoch 400, time_speed: 1.23s, Max abs error is: 0.009052157402038574, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.13066762685775757, JU_loss=-2.7997357845306396, boundary_loss=7.979091606102884e-06
# At epoch 500, time_speed: 1.27s, Max abs error is: 0.009800463914871216, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.1542549729347229, JU_loss=-2.002864122390747, boundary_loss=8.387877642235253e-06
# At epoch 600, time_speed: 1.23s, Max abs error is: 0.010124623775482178, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.09872600436210632, JU_loss=-2.8456003665924072, boundary_loss=8.3120303315809e-06
# At epoch 700, time_speed: 1.26s, Max abs error is: 0.009673148393630981, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.12855786085128784, JU_loss=-2.4670650959014893, boundary_loss=8.22442689241143e-06
# At epoch 800, time_speed: 1.43s, Max abs error is: 0.010967522859573364, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.09028449654579163, JU_loss=-4.227753162384033, boundary_loss=1.1339782759023365e-05
# At epoch 900, time_speed: 1.27s, Max abs error is: 0.009926944971084595, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.09035242348909378, JU_loss=-3.1041316986083984, boundary_loss=8.174861250154208e-06
# At epoch 1000, time_speed: 1.22s, Max abs error is: 0.010147809982299805, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.14740777015686035,JU:-3.5915181636810303,boundary:1.1859719961648807e-05
# At epoch 100, time_speed: 174.44s, Max abs error is: 0.009497493505477905, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0772266834974289,JU:-4.1576762199401855,boundary:9.79776268650312e-06
# At epoch 200, time_speed: 1.30s, Max abs error is: 0.010264039039611816, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.14258107542991638,JU:-2.5278470516204834,boundary:7.572404228994856e-06
# At epoch 300, time_speed: 1.20s, Max abs error is: 0.009331196546554565, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.1470828801393509,JU:-1.8418687582015991,boundary:6.654031494690571e-06
# At epoch 400, time_speed: 1.20s, Max abs error is: 0.010113358497619629, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.22763900458812714,JU:-2.3309807777404785,boundary:6.536613909702282e-06
# At epoch 500, time_speed: 1.17s, Max abs error is: 0.009565979242324829, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.16299602389335632,JU:-3.4801459312438965,boundary:8.458419870294165e-06
# At epoch 600, time_speed: 1.33s, Max abs error is: 0.011399030685424805, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.11562956869602203,JU:-2.7624542713165283,boundary:7.085253309924155e-05
# At epoch 700, time_speed: 1.19s, Max abs error is: 0.014949440956115723, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.08249762654304504,JU:-4.058846950531006,boundary:1.1528344657563139e-05
# At epoch 800, time_speed: 1.18s, Max abs error is: 0.009000778198242188, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.08490757644176483,JU:-3.5366251468658447,boundary:5.113073257234646e-06
# At epoch 900, time_speed: 1.12s, Max abs error is: 0.010239660739898682, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.057386599481105804,JU:-2.1942131519317627,boundary:5.959813279332593e-06
# At epoch 1000, time_speed: 1.29s, Max abs error is: 0.009560078382492065, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 7 steps:
# Epoch 100: pde_loss=0.1502009779214859, JU_loss=-3.7643027305603027, boundary_loss=7.662738426006399e-06
# At epoch 100, time_speed: 186.64s, Max abs error is: 0.006260961294174194, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.09866301715373993, JU_loss=-3.146782636642456, boundary_loss=1.121129207604099e-05
# At epoch 200, time_speed: 1.47s, Max abs error is: 0.005975812673568726, best: 0.006201028823852539
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.06504781544208527, JU_loss=-4.357855319976807, boundary_loss=7.363605254795402e-05
# At epoch 300, time_speed: 1.11s, Max abs error is: 0.006557956337928772, best: 0.005975812673568726
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.06974118947982788, JU_loss=-4.434922695159912, boundary_loss=6.11761788604781e-06
# At epoch 400, time_speed: 1.21s, Max abs error is: 0.0083695650100708, best: 0.005975812673568726
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.050151702016592026, JU_loss=-3.5310285091400146, boundary_loss=1.5281562809832394e-05
# ...
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0070980992168188095,JU:-2.0092248916625977,boundary:1.9798708308371715e-05
# At epoch 400, time_speed: 1.21s, Max abs error is: 0.0036397501826286316, best: 0.0012777075171470642
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00965905748307705,JU:-2.696906805038452,boundary:7.088137408572948e-06
# At epoch 500, time_speed: 1.09s, Max abs error is: 0.002509087324142456, best: 0.0012777075171470642
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.010144186206161976,JU:-3.925166130065918,boundary:1.9494634670991218e-06
# At epoch 600, time_speed: 1.11s, Max abs error is: 0.001614995300769806, best: 0.0012777075171470642
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.020500516518950462,JU:-2.885122299194336,boundary:6.554140327352798e-06
# At epoch 700, time_speed: 1.09s, Max abs error is: 0.0024048611521720886, best: 0.0012777075171470642
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.03397045284509659,JU:-3.3609015941619873,boundary:7.2996426752069965e-06
# At epoch 800, time_speed: 1.10s, Max abs error is: 0.002475723624229431, best: 0.0012777075171470642
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.014613861218094826,JU:-3.4067025184631348,boundary:8.262598498731677e-07
# At epoch 900, time_speed: 1.62s, Max abs error is: 0.0012939795851707458, best: 0.0012777075171470642
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.015184503048658371,JU:-3.1464617252349854,boundary:9.070870419236599e-07
# At epoch 1000, time_speed: 1.68s, Max abs error is: 0.0014224350452423096, best: 0.0012777075171470642
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 18 steps:
# Epoch 100: pde_loss=0.006697949022054672, JU_loss=-3.6184167861938477, boundary_loss=6.729302413077676e-07
# At epoch 100, time_speed: 460.12s, Max abs error is: 0.001135304570198059, best: 0.0012777075171470642
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.005220525898039341, JU_loss=-3.870110511779785, boundary_loss=2.1737446331826504e-06
# At epoch 200, time_speed: 1.20s, Max abs error is: 0.0017728060483932495, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.004925562534481287, JU_loss=-2.7126245498657227, boundary_loss=1.2785149010596797e-06
# At epoch 300, time_speed: 1.10s, Max abs error is: 0.0017004907131195068, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.012880368158221245, JU_loss=-3.0866668224334717, boundary_loss=8.367305781575851e-07
# At epoch 400, time_speed: 1.10s, Max abs error is: 0.0016228705644607544, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.00763273797929287, JU_loss=-3.9393866062164307, boundary_loss=5.802487521577859e-07
# At epoch 500, time_speed: 1.10s, Max abs error is: 0.001257479190826416, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.005450516473501921, JU_loss=-4.393336296081543, boundary_loss=2.177646138079581e-06
# At epoch 600, time_speed: 1.11s, Max abs error is: 0.002049654722213745, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.0035721042659133673, JU_loss=-3.318057060241699, boundary_loss=3.1533568289887626e-06
# At epoch 700, time_speed: 1.09s, Max abs error is: 0.002439156174659729, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.003627956844866276, JU_loss=-3.299518346786499, boundary_loss=2.6996558517566882e-05
# At epoch 800, time_speed: 1.10s, Max abs error is: 0.003636598587036133, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.004258973989635706, JU_loss=-3.1413469314575195, boundary_loss=1.640990376472473e-05
# At epoch 900, time_speed: 1.02s, Max abs error is: 0.0031003355979919434, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.0042348019778728485, JU_loss=-3.760394811630249, boundary_loss=2.3199950192065444e-06
# At epoch 1000, time_speed: 1.28s, Max abs error is: 0.0022433102130889893, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.015462863259017467,JU:-2.6314196586608887,boundary:5.420580691861687e-06
# At epoch 100, time_speed: 471.42s, Max abs error is: 0.0020132437348365784, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.02262982353568077,JU:-4.250293731689453,boundary:7.115626772247197e-07
# At epoch 200, time_speed: 1.03s, Max abs error is: 0.0013159215450286865, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00908505916595459,JU:-3.578540325164795,boundary:1.990570490306709e-05
# At epoch 300, time_speed: 1.08s, Max abs error is: 0.0034949183464050293, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.027293963357806206,JU:-2.6266937255859375,boundary:1.3947523029855802e-06
# At epoch 400, time_speed: 1.10s, Max abs error is: 0.0015281960368156433, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.019599253311753273,JU:-3.107311725616455,boundary:4.852180154557573e-06
# At epoch 500, time_speed: 1.18s, Max abs error is: 0.0020221099257469177, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.03773128613829613,JU:-2.4281554222106934,boundary:9.467568133914028e-07
# At epoch 600, time_speed: 1.10s, Max abs error is: 0.0015334486961364746, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00966583751142025,JU:-4.75203800201416,boundary:9.387405270899762e-07
# At epoch 700, time_speed: 1.50s, Max abs error is: 0.0012143850326538086, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.02060895599424839,JU:-4.263842582702637,boundary:9.024903192766942e-06
# At epoch 800, time_speed: 1.81s, Max abs error is: 0.002677321434020996, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.017215434461832047,JU:-4.082645893096924,boundary:7.670068043807987e-06
# At epoch 900, time_speed: 1.71s, Max abs error is: 0.002515263855457306, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.01867353729903698,JU:-3.8243796825408936,boundary:1.1606526641116943e-05
# At epoch 1000, time_speed: 1.17s, Max abs error is: 0.0028122812509536743, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
# start to the 19 steps:
# Epoch 100: pde_loss=0.0082075335085392, JU_loss=-2.5332062244415283, boundary_loss=6.680777460132958e-07
# At epoch 100, time_speed: 484.31s, Max abs error is: 0.0010643601417541504, best: 0.001135304570198059
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 200: pde_loss=0.011881167069077492, JU_loss=-3.224677324295044, boundary_loss=8.324473128595855e-07
# At epoch 200, time_speed: 1.13s, Max abs error is: 0.0010503530502319336, best: 0.0010643601417541504
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 300: pde_loss=0.004733591806143522, JU_loss=-2.6584861278533936, boundary_loss=5.701281224901322e-06
# At epoch 300, time_speed: 1.18s, Max abs error is: 0.0021340250968933105, best: 0.0010503530502319336
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 400: pde_loss=0.005041528958827257, JU_loss=-3.0104432106018066, boundary_loss=6.289520229074697e-07
# At epoch 400, time_speed: 1.11s, Max abs error is: 0.001007080078125, best: 0.0010503530502319336
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 500: pde_loss=0.00693596713244915, JU_loss=-3.3912193775177, boundary_loss=6.644084464824118e-07
# At epoch 500, time_speed: 1.18s, Max abs error is: 0.0009951293468475342, best: 0.001007080078125
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 600: pde_loss=0.004462545737624168, JU_loss=-2.101840019226074, boundary_loss=9.639359177526785e-07
# At epoch 600, time_speed: 1.20s, Max abs error is: 0.0015437602996826172, best: 0.0009951293468475342
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 700: pde_loss=0.003334911074489355, JU_loss=-2.827369451522827, boundary_loss=6.998773187660845e-07
# At epoch 700, time_speed: 1.22s, Max abs error is: 0.0009714663028717041, best: 0.0009951293468475342
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 800: pde_loss=0.010845261625945568, JU_loss=-3.44655704498291, boundary_loss=3.632057996583171e-06
# At epoch 800, time_speed: 1.10s, Max abs error is: 0.0023023486137390137, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 900: pde_loss=0.0030371269676834345, JU_loss=-2.8322360515594482, boundary_loss=3.0549821531167254e-05
# At epoch 900, time_speed: 1.17s, Max abs error is: 0.004707157611846924, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# Epoch 1000: pde_loss=0.0032554524950683117, JU_loss=-2.7689168453216553, boundary_loss=5.70601116578473e-07
# At epoch 1000, time_speed: 1.10s, Max abs error is: 0.001171991229057312, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.6, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 1 finish, start to train domain 2*************************************************************
# pde:0.010344828478991985,JU:-3.9806268215179443,boundary:7.927386036499229e-07
# At epoch 100, time_speed: 495.91s, Max abs error is: 0.0014658942818641663, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.02532445825636387,JU:-4.004654407501221,boundary:8.369255510842777e-07
# At epoch 200, time_speed: 1.11s, Max abs error is: 0.0012331455945968628, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.00942403357475996,JU:-2.691441297531128,boundary:6.851121838735708e-07
# At epoch 300, time_speed: 1.12s, Max abs error is: 0.0012737438082695007, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.020540006458759308,JU:-3.0057449340820312,boundary:7.425206831612741e-07
# At epoch 400, time_speed: 1.17s, Max abs error is: 0.0013358145952224731, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.011272639036178589,JU:-4.345536231994629,boundary:4.567690211843001e-06
# At epoch 500, time_speed: 1.31s, Max abs error is: 0.0019674748182296753, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.019610963761806488,JU:-3.598848581314087,boundary:5.281247285893187e-05
# At epoch 600, time_speed: 1.12s, Max abs error is: 0.005324944853782654, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.008342914283275604,JU:-1.659495234489441,boundary:5.911486005061306e-05
# At epoch 700, time_speed: 1.11s, Max abs error is: 0.005551427602767944, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.0179347712546587,JU:-2.5914218425750732,boundary:1.5453452988367644e-06
# At epoch 800, time_speed: 1.09s, Max abs error is: 0.0015706494450569153, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.005721059627830982,JU:-3.0610437393188477,boundary:3.6211258702678606e-06
# At epoch 900, time_speed: 1.18s, Max abs error is: 0.0018059834837913513, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
# pde:0.012299418449401855,JU:-4.474898815155029,boundary:8.320192250721448e-07
# At epoch 1000, time_speed: 1.19s, Max abs error is: 0.001203283667564392, best: 0.0009714663028717041
# -----------------------------------------------------------------------------------------------------------------------
#
# 训练完成，开始计算 x=0.4, y=0, 0.05, ..., 1 的 u 值
# *************************************************************train domain 2 finish, start to train domain 1*************************************************************
#                                                                         END TRAINING
